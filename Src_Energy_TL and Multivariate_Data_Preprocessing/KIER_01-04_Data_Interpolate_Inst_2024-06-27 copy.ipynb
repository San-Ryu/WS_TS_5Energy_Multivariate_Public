# %% [markdown]
# ### Code Hist.

# %% [markdown]
# - CODE : KIER Data_전처리 (결측 제거)
# - DATE
# &ensp; 2023-10-12 Created
# &ensp; 2023-11-21 Code 최신화
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 기존 모듈화된 함수 사용
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 기존 KIER 변환 관련 코드를 모두 통합
# &ensp; 2024-01-19 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선, Raw로 저장
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) HOT (온수 사용량) 전용 Code 작성
# &ensp; 2024-01-30 Code 개선 후 백업
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (미완)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 백업 후 코드 최적화
# &ensp; 2024-02-05 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (Method 02 1차 완성)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; A. 순시값을 보간하는 방법은 3가지로 제안 가능
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) 단순 Linear 보간 (앞뒤 평균치)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; [Not Recommanded] 매우 긴 구간의 결측을 커버하기에 부적절
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; (양 끝이 0인 경우, 해당 구간을 제대로 보간 불가)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b) 직전 주 동일시간 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 직전 주의 데이터가 존재하지 않을 경우 보간 불가
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;(데이터 상 첫 주 케이스 등)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1) 해당 동일년도/동일월/동일요일/동일시간의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 과정이 조금 복잡해짐
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-2) 해당 동일 일시의 348 세대의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1보다 기대되는 적용 데이터량이 많음.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 한파/폭염/우천 등 예외적인 날씨에 따른 사용량 변동의 영향이 적어질 것으로 판단.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; B. 순시값을 보간하기 전 단계
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) Resample시, 시간이 NaN인 구간은 그 간격에서 비어있는 행이다.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-1) 시점 n의 적산량이 0이고 시점 n + 1의 적산량이 정상 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-2) 시점 n의 순시량이 음수인 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &ensp; 2024-02-07 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 결측 처리 부분 정확도 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) Raw Data 상 결측치가 15% 이상일 경우, 해당 데이터를 사용하지 않는 부분 추가
#
# - DESC
# &ensp; : int_Domain 코드의 변경에 따라,
# &emsp; KIER 에너지 사용량 데이터를 동/층/세대별로 분리
#
# &emsp; 또한, Raw Data과 세대별 데이터 추출 단계에서,
# &emsp; 아래와 같은 작업 진행
#
# &emsp; [수행 작업]
# &emsp; 1) Date Column에 대한 유효성 검사 및 이상 Data에 대한 소거
# &emsp; 1-1) Datetime 유효성 확인
# &emsp; 1-2) Datetime 이상치 제거
# &emsp; 2) HOUSE_ID_HO의 해시값을 int_house_num으로 변경 (용량 절감 목적)
# - DATA
# 1) Period :
# 2) Interval :
# - Link
# &ensp; :

# %% [markdown]
# ## 01. Code

# %% [markdown]
# ### 01-01. Init

# %% [markdown]
# #### 01-01-01. Init_Module Import

# %% [markdown]
# #### Module import

# %%
#region Basic_Import
## Basic
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.path.dirname(os.path.abspath('__file__'))
import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))

import warnings
warnings.filterwarnings('ignore')

import numpy as np, pandas as pd
from pandas import DataFrame, Series

import math, random

## Datetime
import time
import datetime as dt
from datetime import datetime, date, timedelta

import glob
from glob import glob
import requests
import json

## 시각화
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from scipy import stats

# K-Means 알고리즘
from sklearn.cluster import KMeans, MiniBatchKMeans

# CLustering 알고리즘의 성능 평가 측도
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score, adjusted_rand_score, silhouette_score, rand_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics.cluster import contingency_matrix

## 정규화
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import metrics

import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus

from selenium import webdriver
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

from tqdm.notebook import tqdm
import tqdm

## Init.
pd.options.display.float_format = '{:.10f}'.format
#endregion Basic_Import

# %%
## Import_DL
str_tar = "tf"
## For Torch
if str_tar == "torch":
    import torch
    import torch.nn as nn
    from torch.nn.utils import weight_norm
    print("Torch Imported")
## For TF
elif str_tar == "tf":
    import tensorflow as tf
    import tensorflow_addons as tfa
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    from keras.models import Sequential, load_model
    from keras_flops import get_flops
    print("Tensorflow Imported")
else:
    print("Error : Cannot be used except for Keywords")
    print(" : torch / tf")
# Out:
# Tensorflow Imported

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    print('Using GPU')
    tf.config.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
else : 
  print('Using CPU')
# Out:
# Using GPU

# %%
## Import_Local
from Src_Dev_Common import DEV_Common_Data_Datetime as com_date
# from Src_Dev_Common import DEV_KASI_Holiday as com_Holi
# from Src_Dev_Common import DEV_Common_Data_Analysis as com_Analysis
from Src_Dev_Common import DEV_Common_Data_Preprocessing as com_Prep
# from Src_Dev_Common import DEV_Common_Model as com_Model
# from Src_Dev_Common import DEV_Common_Data_Visualization as com_Visual
# from Src_Dev_Common import DEV_KMA_Weather_ASOS as com_ASOS
# from Src_Dev_Common import DEV_KDHC_Usage as com_KDHC
# from Src_Dev_Common import DEV_KIER_Usage as com_KIER

# %% [markdown]
# ### 01-01-02. Config (Directory, Params)

# %%
## Init_config
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = "1"
random.seed(SEED)

# %%
## Define Todate str
str_now_ymd = pd.datetime.now().date()
str_now_y, str_now_m, str_now_d = pd.datetime.now().year, pd.datetime.now().month, pd.datetime.now().day
str_now_hr, str_now_min = pd.datetime.now().hour, pd.datetime.now().minute

print(pd.datetime.now())
print(str(str_now_y) + " / " + str(str_now_m)  + " / " + str(str_now_d))
print(str(str_now_hr) + " : " + str(str_now_min))
# Out:
# 2024-07-04 16:40:45.620292
# 2024 / 7 / 4
# 16 : 40

# %%
## Dict_Domain
dict_domain = {0:"ELEC", 1:"HEAT", 2:"WATER", 3:"HOT_HEAT", 4:"HOT_FLOW", 5:"GAS"} ## GAS는 사용하지 않음.
int_domain = 1
str_domain = str(dict_domain[int_domain])

dict_col_accu = {0 : "ACTUAL_ACCU_EFF" ## ELEC
                 , 1 : "ACCU_HEAT" ## HEAT
                 , 2 : "ACCU_FLOW" ## WATER
                 , 3 : "ACCU_HEAT" ## HOT 열량
                 , 4 : "ACCU_FLOW" ## HOT 유량
                 , 5 : "ACCU_FLOW" ## GAS
                 }
str_col_accu = str(str_domain + "_" + str(dict_col_accu[int_domain]))

dict_col_inst = {0 : "INST_EFF" ## ELEC_INST_EFF
                , 1 : "INST_HEAT" ## HEAT_INST_HEAT
                , 2 : "INST_FLOW" ## WATER_INST_FLOW
                , 3 : "INST" ## HOT_HEAT_INST
                , 4 : "INST" ## HOT_FLOW_INST
                , 5 : "INST_FLOW" ## GAS_INST_FLOW
                } 
str_col_inst = str(str_domain + "_" + str(dict_col_inst[int_domain]))

## Directory Root
str_dirData = "../data/data_Energy_KIER/"
str_dir_raw = '../data/data_Energy_KIER/KIER_0_Raw/'
str_dirName_bld = '../data/data_Energy_KIER/KIER_1_BLD/'
str_dirName_h = '../data/data_Energy_KIER/KIER_2_H_' + str_domain + '/'

## File
str_fileRaw = str('KIER_RAW_' + str_domain + '_2024-06-07.csv')
str_fileRaw_hList = str('KIER_hList_Common.csv') 

print(str(os.listdir(str_dirData)) + "\n")
print(os.listdir(str_dirName_h))
# Out:
# ['.ipynb_checkpoints', 'BS_CONFIGURATION_202309251452.csv', 'DATE_1M_2023-10-20.csv', 'KIER 전처리 현황_2024-06-25.xlsx', 'KIER_0_Raw', 'KIER_1_BLD', 'KIER_2_H_ELEC', 'KIER_2_H_GAS', 'KIER_2_H_HEAT', 'KIER_2_H_HOT_FLOW', 'KIER_2_H_HOT_HEAT', 'KIER_2_H_WATER', 'KIER_ASOS_WEATHER_DAILY_202309251521.csv', 'KIER_ASOS_WEATHER_HOUR_202309251521.csv', 'KIER_DATA_OLD', 'KIER_ETC', 'KIER_hList_Comparison_2024-06-26.xlsx', 'KIER_List_Table_Column_2023-09-25.xlsx', 'KIER_Query_2023-09-25.txt', 'KMA_ASOS_119_2010_2023_1st_to CSV.csv', '[IITP] 데이터 테이블 정리 (공유 원본).docx']
#
# ['KIER_HEAT_561-1-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-1-1_INST_01_10min.csv', 'KIER_HEAT_561-1-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-1-2_INST_01_10min.csv', 'KIER_HEAT_561-1-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-1-3_INST_01_10min.csv', 'KIER_HEAT_561-1-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-1-4_INST_01_10min.csv', 'KIER_HEAT_561-10-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-10-1_INST_01_10min.csv', 'KIER_HEAT_561-10-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-10-2_INST_01_10min.csv', 'KIER_HEAT_561-10-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-10-3_INST_01_10min.csv', 'KIER_HEAT_561-10-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-10-4_INST_01_10min.csv', 'KIER_HEAT_561-11-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-11-1_INST_01_10min.csv', 'KIER_HEAT_561-11-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-11-2_INST_01_10min.csv', 'KIER_HEAT_561-11-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-11-3_INST_01_10min.csv', 'KIER_HEAT_561-11-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-11-4_INST_01_10min.csv', 'KIER_HEAT_561-12-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-12-1_INST_01_10min.csv', 'KIER_HEAT_561-12-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-12-2_INST_01_10min.csv', 'KIER_HEAT_561-12-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-12-3_INST_01_10min.csv', 'KIER_HEAT_561-12-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-12-4_INST_01_10min.csv', 'KIER_HEAT_561-13-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-13-1_INST_01_10min.csv', 'KIER_HEAT_561-13-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-13-2_INST_01_10min.csv', 'KIER_HEAT_561-13-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-13-3_INST_01_10min.csv', 'KIER_HEAT_561-13-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-13-4_INST_01_10min.csv', 'KIER_HEAT_561-14-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-14-1_INST_01_10min.csv', 'KIER_HEAT_561-14-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-14-2_INST_01_10min.csv', 'KIER_HEAT_561-14-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-14-3_INST_01_10min.csv', 'KIER_HEAT_561-14-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-14-4_INST_01_10min.csv', 'KIER_HEAT_561-15-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-15-1_INST_01_10min.csv', 'KIER_HEAT_561-15-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-15-2_INST_01_10min.csv', 'KIER_HEAT_561-15-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-15-3_INST_01_10min.csv', 'KIER_HEAT_561-15-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-15-4_INST_01_10min.csv', 'KIER_HEAT_561-16-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-16-1_INST_01_10min.csv', 'KIER_HEAT_561-16-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-16-2_INST_01_10min.csv', 'KIER_HEAT_561-16-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-16-3_INST_01_10min.csv', 'KIER_HEAT_561-16-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-16-4_INST_01_10min.csv', 'KIER_HEAT_561-17-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-17-1_INST_01_10min.csv', 'KIER_HEAT_561-17-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-17-2_INST_01_10min.csv', 'KIER_HEAT_561-17-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-17-3_INST_01_10min.csv', 'KIER_HEAT_561-17-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-17-4_INST_01_10min.csv', 'KIER_HEAT_561-18-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-18-1_INST_01_10min.csv', 'KIER_HEAT_561-18-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-18-2_INST_01_10min.csv', 'KIER_HEAT_561-18-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-18-3_INST_01_10min.csv', 'KIER_HEAT_561-18-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-18-4_INST_01_10min.csv', 'KIER_HEAT_561-2-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-2-1_INST_01_10min.csv', 'KIER_HEAT_561-2-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-2-2_INST_01_10min.csv', 'KIER_HEAT_561-2-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-2-3_INST_01_10min.csv', 'KIER_HEAT_561-2-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-2-4_INST_01_10min.csv', 'KIER_HEAT_561-3-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-3-1_INST_01_10min.csv', 'KIER_HEAT_561-3-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-3-2_INST_01_10min.csv', 'KIER_HEAT_561-3-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-3-3_INST_01_10min.csv', 'KIER_HEAT_561-3-4_ACCU_01_Raw.csv', 'KIER_HEAT_561-3-4_INST_01_10min.csv', 'KIER_HEAT_561-4-1_ACCU_01_Raw.csv', 'KIER_HEAT_561-4-1_INST_01_10min.csv', 'KIER_HEAT_561-4-2_ACCU_01_Raw.csv', 'KIER_HEAT_561-4-2_INST_01_10min.csv', 'KIER_HEAT_561-4-3_ACCU_01_Raw.csv', 'KIER_HEAT_561-4-3_INST_01_10min.csv', 'KIER_HEAT_561-4-4_ACCU_01_Raw.csv', 'KIER_HEAT_561 ...

# %%
## "KIER_01-01_Data_hList.ipynb"로부터 만들어진 Bld/F/H List
df_kier_hList = pd.read_csv(str_dir_raw + str_fileRaw_hList, index_col = 0)
list_h_id = df_kier_hList['HOUSE_ID'].drop_duplicates()
print(df_kier_hList.shape, " /// ", df_kier_hList.columns)
df_kier_hList
# Out:
# (348, 5)  ///  Index(['HOUSE_ID_DONG', 'HOUSE_ID_HO_PRE', 'HOUSE_ID_HO_INT', 'HOUSE_ID',
#        'HOUSE_ID_HO'],
#       dtype='object')
#      HOUSE_ID_DONG  HOUSE_ID_HO_PRE  HOUSE_ID_HO_INT  HOUSE_ID  \
# 1              561                1                1   561-1-1
# 2              561                1                2   561-1-2
# 3              561                1                3   561-1-3
# 4              561                1                4   561-1-4
# 5              561                2                1   561-2-1
# ..             ...              ...              ...       ...
# 344            563               23                2  563-23-2
# 345            563               23                3  563-23-3
# 346            563               23                4  563-23-4
# 347            563               24                1  563-24-1
# 348            563               24                2  563-24-2
#
#                                       HOUSE_ID_HO
# 1    NkI4M0EzNDYxQTE1MDJERjM4NURERTcyRjdGQTJDMDU=
# 2    ODBEOTE0QzZCMjg5RUMzNTRBQjM1NjE0RDNBNDE0NzU=
# 3    QTUwRUJDQTlBMkZENUQyNjg0RDRGREVFMTNGNDI3NUY=
# 4    RkRCQzY4OTlCMTRDQjgzNUZBREE3Njc2MkM2MUM2QjI=
# 5    MTQxNkQ1RDAzOTE5NTM5RUM3MzlDQkY3RTI2NERCQTM=
# ..                                            ...
# 344  QkJCQjQwOThFNjgwNjUwQzJGRUJFNDlCNTREOEUxNDU=
# 345  QUJENzFFMEFDRjM4MjY3NTRDQzJCRjdDNUQ3ODA0N0Y=
# 346  RUVENzZDNTc4MUY4NDg5MUREQjZEOUM1M0Q2RjYzMDE=
# 347  NEVENDc1OTFFNDBBRjBDQzkzMTlEMDgzMkMzMkZFQTg=
# 348  ODgwNDU1RUU0RUQ2OTQxQTBGMEI3MTE3NTkxODYxQ0U=
#
# [348 rows x 5 columns]

# %% [markdown]
# ## 01-02. Data Load (df_raw)

# %% [markdown]
# ### 01-02-01. KIER (Energy Usage)

# %% [markdown]
# ### 순시사용량

# %%
str_file = str('KIER_' + str_domain + '_INST_01_10min.csv')
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)
df_tmp['METER_DATE'] = pd.to_datetime(df_tmp['METER_DATE'])

list_tar_col = df_tmp.columns[0:]
df_tmp = df_tmp.reset_index()[list_tar_col] ## reset_index로 인해 발생한 index행 제거

# %%
## 정상적인 Time Period 외의 데이터는 삭제 (2022-07-17 ~ 2024-06-05)
df_period_tmp = pd.read_csv(str_dir_raw + "KIER_TIME_PERIOD.csv", index_col = 0)
df_period_tmp['METER_DATE'] = pd.to_datetime(df_period_tmp['METER_DATE'])

df_tmp = pd.merge(df_period_tmp['METER_DATE'], df_tmp, on = ['METER_DATE'], how = "left")
df_tmp
# Out:
#                METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0     2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1     2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2     2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3     2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4     2022-07-17 23:40:00          Sunday  2022      7   17    23      40
# ...                   ...             ...   ...    ...  ...   ...     ...
# 99166 2024-06-05 14:40:00       Wednesday  2024      6    5    14      40
# 99167 2024-06-05 14:50:00       Wednesday  2024      6    5    14      50
# 99168 2024-06-05 15:00:00       Wednesday  2024      6    5    15       0
# 99169 2024-06-05 15:10:00       Wednesday  2024      6    5    15      10
# 99170 2024-06-05 15:20:00       Wednesday  2024      6    5    15      20
#
#        code_day_of_the_week  HEAT_INST_HEAT_561-1-1  HEAT_INST_HEAT_561-1-2  \
# 0                         6                     NaN                     NaN
# 1                         6                     NaN                     NaN
# 2                         6                     NaN                     NaN
# 3                         6                     NaN                     NaN
# 4                         6                     NaN                     NaN
# ...                     ...                     ...                     ...
# 99166                     2                     NaN                     NaN
# 99167                     2                     NaN                     NaN
# 99168                     2                     NaN                     NaN
# 99169                     2                     NaN                     NaN
# 99170                     2                     NaN                     NaN
#
#        ...  HEAT_INST_HEAT_563-22-5  HEAT_INST_HEAT_563-22-6  \
# 0      ...                      NaN                      NaN
# 1      ...                      NaN                      NaN
# 2      ...                      NaN                      NaN
# 3      ...                      NaN                      NaN
# 4      ...                      NaN                      NaN
# ...    ...                      ...                      ...
# 99166  ...                      NaN                      NaN
# 99167  ...                      NaN                      NaN
# 99168  ...                      NaN                      NaN
# 99169  ...                      NaN                      NaN
# 99170  ...                      NaN                      NaN
#
#        HEAT_INST_HEAT_563-23-1  HEAT_INST_HEAT_563-23-2  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 99166                      NaN                      NaN
# 99167                      NaN                      NaN
# 99168                      NaN                      NaN
# 99169                      NaN                      NaN
# 99170                      NaN                      NaN
#
#        HEAT_INST_HEAT_563-23-3  HEAT_INST_HEAT_563-23-4  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 99166                      NaN                      NaN
# 99167                      NaN                      NaN
# 99168                      NaN                      NaN
# 99169                      NaN                      NaN
# 99170                      NaN                      NaN
#
#        HEAT_INST_HEAT_563-24-1  HEAT_INST_HEAT_563-24-2   MEAN_OF_INST  \
# 0                          NaN                      NaN 345.8333333333
# 1                          NaN                      NaN 347.5000000000
# 2                          NaN                      NaN 349.1666666667
# 3                          NaN                      NaN 350.8333333333
# 4                          NaN                      NaN 352.5000000000
# ...                        ...                      ...            ...
# 99166                      NaN                      NaN 348.5000000000
# 99167                      NaN                      NaN 350.1666666667
# 99168                      NaN                      NaN 342.0000000000
# 99169                      NaN                      NaN 343.6666666667
# 99170                      NaN                      NaN 345.3333333333
#
#           SUM_OF_INST
# 0     2075.0000000000
# 1     2085.0000000000
# 2     2095.0000000000
# 3     2105.0000000000
# 4     2115.0000000000
# ...               ...
# 99166 2091.0000000000
# 99167 2101.0000000000
# 99168 2052.0000000000
# 99169 2062.0000000000
# 99170 2072.0000000000
#
# [99171 rows x 358 columns]

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Mean of Instantaneous Usage in ' + str_domain, fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'HEAT_INST_HEAT_561-1-1',
#        'HEAT_INST_HEAT_561-1-2',
#        ...
#        'HEAT_INST_HEAT_563-22-5', 'HEAT_INST_HEAT_563-22-6',
#        'HEAT_INST_HEAT_563-23-1', 'HEAT_INST_HEAT_563-23-2',
#        'HEAT_INST_HEAT_563-23-3', 'HEAT_INST_HEAT_563-23-4',
#        'HEAT_INST_HEAT_563-24-1', 'HEAT_INST_HEAT_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                     0
# day_of_the_week                0
# YEAR                           0
# MONTH                          0
# DAY                            0
#                            ...
# HEAT_INST_HEAT_563-23-4    57372
# HEAT_INST_HEAT_563-24-1    58065
# HEAT_INST_HEAT_563-24-2    57398
# MEAN_OF_INST                   0
# SUM_OF_INST                    0
# Length: 358, dtype: int64

# %%
## 순시사용량이 음수인 경우 삭제
cnt_minus = 0
list_col_usage = list(df_tmp.columns[8:-2])

for i in range(0, len(df_tmp)) : 
    for col_tar in list_col_usage:
        if df_tmp[col_tar][i] < 0 : 
            print(col_tar, ' ///', df_tmp[col_tar][i])
            print(df_tmp[col_tar][i])
            cnt_minus = cnt_minus + 1
            df_tmp[col_tar][i] = np.nan

print(cnt_minus)

## 순시 사용량의 합계 및 평균 Column을 갱신
df_tmp['MEAN_OF_INST'] = df_tmp[list_col_usage].mean(axis = 1)
df_tmp['SUM_OF_INST'] = df_tmp[list_col_usage].sum(axis = 1)
# Out:
# 0

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage in certain household', fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'HEAT_INST_HEAT_561-1-1',
#        'HEAT_INST_HEAT_561-1-2',
#        ...
#        'HEAT_INST_HEAT_563-22-5', 'HEAT_INST_HEAT_563-22-6',
#        'HEAT_INST_HEAT_563-23-1', 'HEAT_INST_HEAT_563-23-2',
#        'HEAT_INST_HEAT_563-23-3', 'HEAT_INST_HEAT_563-23-4',
#        'HEAT_INST_HEAT_563-24-1', 'HEAT_INST_HEAT_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                     0
# day_of_the_week                0
# YEAR                           0
# MONTH                          0
# DAY                            0
#                            ...
# HEAT_INST_HEAT_563-23-4    57372
# HEAT_INST_HEAT_563-24-1    58065
# HEAT_INST_HEAT_563-24-2    57398
# MEAN_OF_INST               56589
# SUM_OF_INST                    0
# Length: 358, dtype: int64

# %%
# df_tmp[['METER_DATE', 'MEAN_OF_INST', 'SUM_OF_INST']].to_csv(str_dir_raw + "KIER_TIME_PERIOD.csv")

# %%
df_usage = df_tmp[list(df_tmp.columns[8:])]
df_usage
# Out:
#        HEAT_INST_HEAT_561-1-1  HEAT_INST_HEAT_561-1-2  HEAT_INST_HEAT_561-1-3  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 99166                     NaN                     NaN                     NaN
# 99167                     NaN                     NaN                     NaN
# 99168                     NaN                     NaN                     NaN
# 99169                     NaN                     NaN                     NaN
# 99170                     NaN                     NaN                     NaN
#
#        HEAT_INST_HEAT_561-1-4  HEAT_INST_HEAT_561-2-1  HEAT_INST_HEAT_561-2-2  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 99166                     NaN                     NaN                     NaN
# 99167                     NaN                     NaN                     NaN
# 99168                     NaN                     NaN                     NaN
# 99169                     NaN                     NaN                     NaN
# 99170                     NaN                     NaN                     NaN
#
#        HEAT_INST_HEAT_561-2-3  HEAT_INST_HEAT_561-2-4  HEAT_INST_HEAT_561-3-1  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 99166                     NaN                     NaN                     NaN
# 99167                     NaN                     NaN                     NaN
# 99168                     NaN                     NaN                     NaN
# 99169                     NaN                     NaN                     NaN
# 99170                     NaN                     NaN                     NaN
#
#        HEAT_INST_HEAT_561-3-2  ...  HEAT_INST_HEAT_563-22-5  \
# 0                         NaN  ...                      NaN
# 1                         NaN  ...                      NaN
# 2                         NaN  ...                      NaN
# 3                         NaN  ...                      NaN
# 4                         NaN  ...                      NaN
# ...                       ...  ...                      ...
# 99166                     NaN  ...                      NaN
# 99167                     NaN  ...                      NaN
# 99168                     NaN  ...                      NaN
# 99169                     NaN  ...                      NaN
# 99170                     NaN  ...                      NaN
#
#        HEAT_INST_HEAT_563-22-6  HEAT_INST_HEAT_563-23-1  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 99166                      NaN                      NaN
# 99167                      NaN                      NaN
# 99168                      NaN                      NaN
# 99169                      NaN                      NaN
# 99170                      NaN                      NaN
#
#        HEAT_INST_HEAT_563-23-2  HEAT_INST_HEAT_563-23-3  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 99166                      NaN                      NaN
# 99167                      NaN                      NaN
# 99168                      NaN                      NaN
# 99169                      NaN                      NaN
# 99170                      NaN                      NaN
#
#        HEAT_INST_HEAT_563-23-4  HEAT_INST_HEAT_563-24-1  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 99166                      NaN                      NaN
# 99167                      NaN                      NaN
# 99168                      NaN                      NaN
# 99169                      NaN                      NaN
# 99170                      NaN                      NaN
#
#        HEAT_INST_HEAT_563-24-2  MEAN_OF_INST  SUM_OF_INST
# 0                          NaN           NaN 0.0000000000
# 1                          NaN           NaN 0.0000000000
# 2                          NaN           NaN 0.0000000000
# 3                          NaN           NaN 0.0000000000
# 4                          NaN           NaN 0.0000000000
# ...                        ...           ...          ...
# 99166                      NaN           NaN 0.0000000000
# 99167                      NaN           NaN 0.0000000000
# 99168                      NaN           NaN 0.0000000000
# 99169                      NaN           NaN 0.0000000000
# 99170                      NaN           NaN 0.0000000000
#
# [99171 rows x 350 columns]

# %% [markdown]
# #### 1차 보간 : 평균 대치법 (동일 시간대 전체 세대의 평균 순시 사용량)

# %%
for i in range(0, len(df_usage)) : df_usage.loc[i] = df_usage.loc[i].fillna(df_usage['MEAN_OF_INST'].loc[i])

## 마지막값이 0이므로 제외
df_usage = df_usage[:-1]
## 순시 사용량의 합계 및 평균 Column을 갱신
df_usage['MEAN_OF_INST'] = df_usage[list_col_usage].mean(axis = 1)
df_usage['SUM_OF_INST'] = df_usage[list_col_usage].sum(axis = 1)

for col_tar in list_col_usage : df_tmp[col_tar] = df_usage[col_tar]

str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp.to_csv(str_dirName_h + str_file)

print(df_tmp.isna().sum())
print(df_tmp.head(5))
plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + 'Usage : 1st - Mean of Inst', fontsize=30)
plt.show()
# Out:
# METER_DATE                     0
# day_of_the_week                0
# YEAR                           0
# MONTH                          0
# DAY                            0
#                            ...
# HEAT_INST_HEAT_563-23-4    56589
# HEAT_INST_HEAT_563-24-1    56589
# HEAT_INST_HEAT_563-24-2    56589
# MEAN_OF_INST               56589
# SUM_OF_INST                    0
# Length: 358, dtype: int64
#            METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0 2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1 2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2 2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3 2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4 2022-07-17 23:40:00          Sunday  2022      7   17    23      40
#
#    code_day_of_the_week  HEAT_INST_HEAT_561-1-1  HEAT_INST_HEAT_561-1-2  ...  \
# 0                     6                     NaN                     NaN  ...
# 1                     6                     NaN                     NaN  ...
# 2                     6                     NaN                     NaN  ...
# 3                     6                     NaN                     NaN  ...
# 4                     6                     NaN                     NaN  ...
#
#    HEAT_INST_HEAT_563-22-5  HEAT_INST_HEAT_563-22-6  HEAT_INST_HEAT_563-23-1  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    HEAT_INST_HEAT_563-23-2  HEAT_INST_HEAT_563-23-3  HEAT_INST_HEAT_563-23-4  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#    HEAT_INST_HEAT_563-24-1  HEAT_INST_HEAT_563-24-2  MEAN_OF_INST  SUM_OF_INST
# 0                      NaN                      NaN           NaN 0.0000000000
# 1                      NaN                      NaN           NaN 0.0000000000
# 2                      NaN                      NaN           NaN 0.0000000000
# 3                      NaN                      NaN           NaN 0.0000000000
# 4                      NaN                      NaN           NaN 0.0000000000
#
# [5 rows x 358 columns]

# %%
str_file = 'KIER_' + str_domain + '_INST_02_MeanInterpolated.csv'
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 2차 보간 : 선형 보간

# %% [markdown]
# 모든 값이 NaN이어서 평균 순시 사용량이 계산되지 않은 경우 존재 (ELEC 기준 약 1,372건)
# 해당 부분은 단순 선형 보간을 진행

# %%
## 사용량 컬럼에 대한 2차 보간 진행 (선형 보간)
df_linear_tmp, df_spline_tmp, df_polynomial_tmp, df_cubic_tmp = df_tmp.copy(), df_tmp.copy(), df_tmp.copy(), df_tmp.copy()
df_linear_tmp['MEAN_OF_INST'] = df_linear_tmp['MEAN_OF_INST'].interpolate('linear')
df_spline_tmp['MEAN_OF_INST'] = df_spline_tmp['MEAN_OF_INST'].interpolate('spline', order = 3) ## 3차 다항식 스플라인
# df_polynomial_tmp['MEAN_OF_INST'] = df_polynomial_tmp['MEAN_OF_INST'].interpolate('polynomian')
# df_cubic_tmp['MEAN_OF_INST'] = df_cubic_tmp['MEAN_OF_INST'].interpolate('cubicspline')

str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp.to_csv(str_dirName_h + str_file)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp.to_csv(str_dirName_h + str_file)

# %%
plt.figure(figsize=(20,4))
plt.plot(df_linear_tmp['METER_DATE'], df_linear_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-01 Linear', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.plot(df_spline_tmp['METER_DATE'], df_spline_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-02 Spline', fontsize=30)
plt.show()

# %%
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 이상치 제거 : IQR 방식으로 이상치 완화

# %%
## 여기서 IQR방식으로 전처리
list_col_usage = list(df_tmp.columns[8:-2])
for tar_col in list_col_usage:
    print(tar_col)
    df_h_tmp = df_tmp[['METER_DATE', tar_col]].copy()
    df_h_tmp = com_Prep.del_outlier_Usages(df_h_tmp, tar_col, 10)
    df_tmp[tar_col] = df_h_tmp[tar_col]
# Out:
# HEAT_INST_HEAT_561-1-1
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 762
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 621
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 562
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 514
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 483
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 466
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 441
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 414
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 397
# ===============  IQR Range ===============
# 0.0009999999999974999
# 0.000399999999999
# 0.000399999999999
# nan
# 0.0
# -0.0005999999999985
# ===============  IQR Range ===============
# cnt_outlier = 384
# 5044
# HEAT_INST_HEAT_561-1-2
# ===============  IQR Range ===============
# 0.00010067164179100027
# 4.026865671640011e-05
# 4.026865671640011e-05
# nan
# 0.0
# -6.040298507460016e-05
# ===============  IQR Range ===============
# cnt_outlier = 4020
# ===============  IQR Range ===============
# 8.794407615163994e-05
# 3.517763046065597e-05
# 3.517763046065597e-05
# nan
# 0.0
# -5.276644569098396e-05
# ===============  IQR Range ===============
# cnt_outlier = 4055
# ===============  IQR Range ===============
# 8.779587040458187e-05
# 3.511834816183275e-05
# 3.511834816183275e-05
# nan
# 0.0
# -5.2677522242749124e-05
# ===============  IQR Range ===============
# cnt_outlier = 4049
# ===============  IQR Range ===============
# 8.725919732442027e-05
# 3.4903678929768106e-05
# 3.4903678929768106e-05
# nan
# 0.0
# -5.235551839465216e-05
# ===============  IQR Range ===============
# cnt_outlier = 4050
# ===============  IQR Range ===============
# 8.614963942306611e-05
# 3.445985576922645e-05
# 3.445985576922645e-05
# nan
# 0.0
# -5.168978365383967e-05
# ===============  IQR Range ===============
# cnt_outlier = 4052
# ===============  IQR Range ===============
# 8.610409007352542e-05
# 3.444163602941017e-05
# 3.444163602941017e-05
# nan
# 0.0
# -5.166245404411525e-05
# ===============  IQR Range ===============
# cnt_outlier = 4051
# ===============  IQR Range ===============
# 8.584558823525001e-05
# 3.43382352941e-05
# 3.43382352941e-05
# nan
# 0.0
# -5.150735294115e-05
# ===============  IQR Range ===============
# cnt_outlier = 4050
# ===============  IQR Range ===============
# 8.58233647936458e-05
# 3.432934591745832e-05
# 3.432934591745832e-05
# nan
# 0.0
# -5.1494018876187484e-05
# ===============  IQR Range ===============
# cnt_outlier = 4051
# ===============  IQR Range ===============
# 8.563264757290357e-05
# 3.425305902916143e-05
# 3.425305902916143e-05
# nan
# 0.0
# -5.137958854374214e-05
# ===============  IQR Range ===============
# cnt_outlier = 4049
# ===============  IQR Range ===============
# 8.522791448160069e-05
# 3.409116579264028e-05
# 3.409116579264028e-05
# nan
# 0.0
# -5.113674868896042e-05
# ===============  IQR Range ===============
# cnt_outlier = 4051
# 39634
# HEAT_INST_HEAT_561-1-3
# ===============  IQR Range ===============
# 9.120232485772519e-05
# 3.648092994309008e-05
# 3.648092994309008e-05
# nan
# 0.0
# -5.472139491463512e-05
# ===============  IQR Range ===============
# cnt_outlier = 4006
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3917
# 22891
# HEAT_INST_HEAT_561-1-4
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 9
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 9
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 8
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.0020000000000040003
# 0.0008000000000016
# 0.0008000000000016
# nan
# 0.0
# -0.0012000000000024
# ===============  IQR Range ===============
# cnt_outlier = 7
# 87
# HEAT_INST_HEAT_561-2-1
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 7
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 6
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.00175000000000025
# 0.0007000000000001
# 0.0007000000000001
# nan
# 0.0
# -0.00105000000000015
# ===============  IQR Range ===============
# cnt_outlier = 5
# 61
# HEAT_INST_HEAT_561-2-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2994
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2967
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2965
# 29681
# HEAT_INST_HEAT_561-2-3
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# 106
# HEAT_INST_HEAT_561-2-4
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 60
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 55
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 53
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 47
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 45
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 42
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 39
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 38
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 37
# ===============  IQR Range ===============
# 0.0010000000000020002
# 0.0004000000000008
# 0.0004000000000008
# nan
# 0.0
# -0.0006000000000012
# ===============  IQR Range ===============
# cnt_outlier = 36
# 452
# HEAT_INST_HEAT_561-3-1
# ===============  IQR Range ===============
# 5.9073056852521567e-05
# 2.3629222741008628e-05
# 2.3629222741008628e-05
# nan
# 0.0
# -3.544383411151294e-05
# ===============  IQR Range ===============
# cnt_outlier = 2750
# ===============  IQR Range ===============
# 5.54733727810417e-05
# 2.218934911241668e-05
# 2.218934911241668e-05
# nan
# 0.0
# -3.328402366862502e-05
# ===============  IQR Range ===============
# cnt_outlier = 2762
# ===============  IQR Range ===============
# 5.5231795567604e-05
# 2.20927182270416e-05
# 2.20927182270416e-05
# nan
# 0.0
# -3.31390773405624e-05
# ===============  IQR Range ===============
# cnt_outlier = 2760
# ===============  IQR Range ===============
# 5.522388059698075e-05
# 2.20895522387923e-05
# 2.20895522387923e-05
# nan
# 0.0
# -3.313432835818845e-05
# ===============  IQR Range ===============
# cnt_outlier = 2737
# ===============  IQR Range ===============
# 5.5221782652995396e-05
# 2.208871306119816e-05
# 2.208871306119816e-05
# nan
# 0.0
# -3.313306959179724e-05
# ===============  IQR Range ===============
# cnt_outlier = 2693
# ===============  IQR Range ===============
# 5.495952509439633e-05
# 2.1983810037758532e-05
# 2.1983810037758532e-05
# nan
# 0.0
# -3.29757150566378e-05
# ===============  IQR Range ===============
# cnt_outlier = 2684
# ===============  IQR Range ===============
# 5.488836393319209e-05
# 2.1955345573276835e-05
# 2.1955345573276835e-05
# nan
# 0.0
# -3.293301835991525e-05
# ===============  IQR Range ===============
# cnt_outlier = 2684
# ===============  IQR Range ===============
# 5.484678217120195e-05
# 2.193871286848078e-05
# 2.193871286848078e-05
# nan
# 0.0
# -3.290806930272117e-05
# ===============  IQR Range ===============
# cnt_outlier = 2669
# ===============  IQR Range ===============
# 5.484678217120195e-05
# 2.193871286848078e-05
# 2.193871286848078e-05
# nan
# 0.0
# -3.290806930272117e-05
# ===============  IQR Range ===============
# cnt_outlier = 2661
# ===============  IQR Range ===============
# 5.4716131133289986e-05
# 2.1886452453315994e-05
# 2.1886452453315994e-05
# nan
# 0.0
# -3.282967867997399e-05
# ===============  IQR Range ===============
# cnt_outlier = 2658
# 24835
# HEAT_INST_HEAT_561-3-2
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 210
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 136
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 117
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 115
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 114
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 111
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 104
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 101
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 97
# ===============  IQR Range ===============
# 0.0007499999999982501
# 0.0002999999999993
# 0.0002999999999993
# nan
# 0.0
# -0.00044999999999895005
# ===============  IQR Range ===============
# cnt_outlier = 93
# 1198
# HEAT_INST_HEAT_561-3-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2672
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2659
# 26603
# HEAT_INST_HEAT_561-3-4
# ===============  IQR Range ===============
# 7.250531829316029e-05
# 2.9002127317264114e-05
# 2.9002127317264114e-05
# nan
# 0.0
# -4.350319097589617e-05
# ===============  IQR Range ===============
# cnt_outlier = 2667
# ===============  IQR Range ===============
# 6.986908783782609e-05
# 2.794763513513043e-05
# 2.794763513513043e-05
# nan
# 0.0
# -4.192145270269565e-05
# ===============  IQR Range ===============
# cnt_outlier = 2616
# ===============  IQR Range ===============
# 6.797583081573764e-05
# 2.719033232629506e-05
# 2.719033232629506e-05
# nan
# 0.0
# -4.078549848944259e-05
# ===============  IQR Range ===============
# cnt_outlier = 2581
# ===============  IQR Range ===============
# 6.79635163536122e-05
# 2.7185406541444882e-05
# 2.7185406541444882e-05
# nan
# 0.0
# -4.077810981216732e-05
# ===============  IQR Range ===============
# cnt_outlier = 2457
# ===============  IQR Range ===============
# 6.79635163536122e-05
# 2.7185406541444882e-05
# 2.7185406541444882e-05
# nan
# 0.0
# -4.077810981216732e-05
# ===============  IQR Range ===============
# cnt_outlier = 2241
# ===============  IQR Range ===============
# 6.79635163536122e-05
# 2.7185406541444882e-05
# 2.7185406541444882e-05
# nan
# 0.0
# -4.077810981216732e-05
# ===============  IQR Range ===============
# cnt_outlier = 2090
# ===============  IQR Range ===============
# 6.79635163536122e-05
# 2.7185406541444882e-05
# 2.7185406541444882e-05
# nan
# 0.0
# -4.077810981216732e-05
# ===============  IQR Range ===============
# cnt_outlier = 1942
# ===============  IQR Range ===============
# 6.79635163536122e-05
# 2.7185406541444882e-05
# 2.7185406541444882e-05
# nan
# 0.0
# -4.077810981216732e-05
# ===============  IQR Range ===============
# cnt_outlier = 1721
# ===============  IQR Range ===============
# 6.792748215444437e-05
# 2.717099286177775e-05
# 2.717099286177775e-05
# nan
# 0.0
# -4.0756489292666626e-05
# ===============  IQR Range ===============
# cnt_outlier = 1687
# ===============  IQR Range ===============
# 6.792748215444437e-05
# 2.717099286177775e-05
# 2.717099286177775e-05
# nan
# 0.0
# -4.0756489292666626e-05
# ===============  IQR Range ===============
# cnt_outlier = 1640
# 19190
# HEAT_INST_HEAT_561-4-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1562
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1553
# 15539
# HEAT_INST_HEAT_561-4-2
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.001749999999998
# 0.0006999999999992
# 0.0006999999999992
# nan
# 0.0
# -0.0010499999999988
# ===============  IQR Range ===============
# cnt_outlier = 11
# 121
# HEAT_INST_HEAT_561-4-3
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 730
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 633
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 574
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 535
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 501
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 481
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 447
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 411
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 381
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 355
# 5048
# HEAT_INST_HEAT_561-4-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3281
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3256
# 32585
# HEAT_INST_HEAT_561-5-1
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0019999999999997502
# 0.0007999999999999
# 0.0007999999999999
# nan
# 0.0
# -0.00119999999999985
# ===============  IQR Range ===============
# cnt_outlier = 10
# 111
# HEAT_INST_HEAT_561-5-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2634
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2625
# 26259
# HEAT_INST_HEAT_561-5-3
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2167
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 1616
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 1332
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 1176
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 1078
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 1008
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 956
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 919
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 890
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 860
# 12002
# HEAT_INST_HEAT_561-5-4
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 10
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 6
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 6
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 6
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 6
# 84
# HEAT_INST_HEAT_561-6-1
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# 119
# HEAT_INST_HEAT_561-6-2
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1588
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1495
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1436
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1389
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1357
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1325
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1298
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1277
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1253
# ===============  IQR Range ===============
# 0.0007500000000025
# 0.000300000000001
# 0.000300000000001
# nan
# 0.0
# -0.0004500000000015
# ===============  IQR Range ===============
# cnt_outlier = 1237
# 13655
# HEAT_INST_HEAT_561-6-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2037
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2028
# 20289
# HEAT_INST_HEAT_561-6-4
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 81
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 74
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 73
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 69
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 66
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 65
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 62
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 61
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 60
# ===============  IQR Range ===============
# 0.0005000000000010001
# 0.0002000000000004
# 0.0002000000000004
# nan
# 0.0
# -0.0003000000000006
# ===============  IQR Range ===============
# cnt_outlier = 58
# 669
# HEAT_INST_HEAT_561-7-1
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 3683
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 3585
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 3492
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 3391
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 3253
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 3132
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 3028
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 2935
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 2876
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 2842
# 32217
# HEAT_INST_HEAT_561-7-2
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.0015000000000007499
# 0.0006000000000003
# 0.0006000000000003
# nan
# 0.0
# -0.0009000000000004499
# ===============  IQR Range ===============
# cnt_outlier = 11
# 119
# HEAT_INST_HEAT_561-7-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2443
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2420
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2420
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2420
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2420
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# ...
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2399
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2278
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2210
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2160
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2117
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2068
# ===============  IQR Range ===============
# 0.0004999999999987499
# 0.0001999999999995
# 0.0001999999999995
# nan
# 0.0
# -0.00029999999999925
# ===============  IQR Range ===============
# cnt_outlier = 2025
# 23300
# HEAT_INST_HEAT_563-22-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2520
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2452
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2450
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2449
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2448
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2447
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2446
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2446
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2446
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2446
# 24550
# HEAT_INST_HEAT_563-22-5
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 941
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 56
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 28
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 18
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 17
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 17
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 15
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.00024999999999941735
# 9.999999999976694e-05
# 9.999999999976694e-05
# nan
# 0.0
# -0.0001499999999996504
# ===============  IQR Range ===============
# cnt_outlier = 11
# 1126
# HEAT_INST_HEAT_563-22-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2085
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2071
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2070
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2069
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2068
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2067
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2066
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2065
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2064
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2063
# 20688
# HEAT_INST_HEAT_563-23-1
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 5
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 4
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 3
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 3
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 3
# ===============  IQR Range ===============
# 0.002499999999994
# 0.0009999999999976
# 0.0009999999999976
# nan
# 0.0
# -0.0014999999999964
# ===============  IQR Range ===============
# cnt_outlier = 3
# 41
# HEAT_INST_HEAT_563-23-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3211
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3191
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3190
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3189
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3188
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3188
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3188
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3188
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3188
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3188
# 31909
# HEAT_INST_HEAT_563-23-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2184
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2168
# 21696
# HEAT_INST_HEAT_563-23-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2956
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2931
# 29335
# HEAT_INST_HEAT_563-24-1
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 13
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 11
# ===============  IQR Range ===============
# 0.002249999999999
# 0.0008999999999996
# 0.0008999999999996
# nan
# 0.0
# -0.0013499999999994
# ===============  IQR Range ===============
# cnt_outlier = 11
# 121
# HEAT_INST_HEAT_563-24-2
# ===============  IQR Range ===============
# 0.00033187385381165376
# 0.0001327495415246615
# 0.0001327495415246615
# nan
# 0.0
# -0.00019912431228699223
# ===============  IQR Range ===============
# cnt_outlier = 4011
# ===============  IQR Range ===============
# 0.0003012862341220261
# 0.00012051449364881043
# 0.00012051449364881043
# nan
# 0.0
# -0.00018077174047321566
# ===============  IQR Range ===============
# cnt_outlier = 3984
# ===============  IQR Range ===============
# 0.0003012862341220261
# 0.00012051449364881043
# 0.00012051449364881043
# nan
# 0.0
# -0.00018077174047321566
# ===============  IQR Range ===============
# cnt_outlier = 3968
# ===============  IQR Range ===============
# 0.0003012862341220261
# 0.00012051449364881043
# 0.00012051449364881043
# nan
# 0.0
# -0.00018077174047321566
# ===============  IQR Range ===============
# cnt_outlier = 3957
# ===============  IQR Range ===============
# 0.0003012862341220261
# 0.00012051449364881043
# 0.00012051449364881043
# nan
# 0.0
# -0.00018077174047321566
# ===============  IQR Range ===============
# cnt_outlier = 3946
# ===============  IQR Range ===============
# 0.0003012862341220261
# 0.00012051449364881043
# 0.00012051449364881043
# nan
# 0.0
# -0.00018077174047321566
# ===============  IQR Range ===============
# cnt_outlier = 3926
# ===============  IQR Range ===============
# 0.0003012862341220261
# 0.00012051449364881043
# 0.00012051449364881043
# nan
# 0.0
# -0.00018077174047321566
# ===============  IQR Range ===============
# cnt_outlier = 3898
# ===============  IQR Range ===============
# 0.000300495859018234
# 0.00012019834360729361
# 0.00012019834360729361
# nan
# 0.0
# -0.0001802975154109404
# ===============  IQR Range ===============
# cnt_outlier = 3884
# ===============  IQR Range ===============
# 0.000300495859018234
# 0.00012019834360729361
# 0.00012019834360729361
# nan
# 0.0
# -0.0001802975154109404
# ===============  IQR Range ===============
# cnt_outlier = 3878
# ===============  IQR Range ===============
# 0.000300495859018234
# 0.00012019834360729361
# 0.00012019834360729361
# nan
# 0.0
# -0.0001802975154109404
# ===============  IQR Range ===============
# cnt_outlier = 3873
# 37347

# %%
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp.to_csv(str_dirName_h + str_file)

# %%
str_file = 'KIER_' + str_domain + '_INST_01_10min.csv'
df_tmp_00 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp_01 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_tmp_0201 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_tmp_0202 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp_03 = pd.read_csv(str_dirName_h + str_file, index_col = 0)

period_tmp = df_tmp_0201['METER_DATE']
period_tmp
# Out:
# 0        2022-07-17 23:00:00
# 1        2022-07-17 23:10:00
# 2        2022-07-17 23:20:00
# 3        2022-07-17 23:30:00
# 4        2022-07-17 23:40:00
#                 ...
# 99164    2024-06-05 14:20:00
# 99165    2024-06-05 14:30:00
# 99166    2024-06-05 14:40:00
# 99167    2024-06-05 14:50:00
# 99168    2024-06-05 15:00:00
# Name: METER_DATE, Length: 99169, dtype: object

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_01[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
df_tmp_01.columns
# Out:
# Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'HEAT_INST_HEAT_561-1-1',
#        'HEAT_INST_HEAT_561-1-2',
#        ...
#        'HEAT_INST_HEAT_563-22-5', 'HEAT_INST_HEAT_563-22-6',
#        'HEAT_INST_HEAT_563-23-1', 'HEAT_INST_HEAT_563-23-2',
#        'HEAT_INST_HEAT_563-23-3', 'HEAT_INST_HEAT_563-23-4',
#        'HEAT_INST_HEAT_563-24-1', 'HEAT_INST_HEAT_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)

# %%
tar_col = 'SUM_OF_INST'

fig, ax1 = plt.subplots(figsize = (30,5))
usage_A = df_tmp_01[tar_col].copy()[:-1]
usage_B = df_tmp_0201[tar_col].copy()[:-1]
ax1.plot(period_tmp, usage_A, color = 'red')
ax1.plot(period_tmp, usage_B, color = 'red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 7
#       5 usage_B = df_tmp_0201[tar_col].copy()[:-1]
#       6 ax1.plot(period_tmp, usage_A, color = 'red')
# ----> 7 ax1.plot(period_tmp, usage_B, color = 'red')
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (99169,) and (99168,)

# %%
list_tar_col = df_tmp.columns[1:]
for tar_col in list_tar_col:
    print(tar_col)
    df_tmp[tar_col] = com_Prep.del_outlier_Usages(df_tmp, tar_col)

# %%
df_tmp

# %%
## 합계 순시량 다시 계산 
list_col = df_tmp.columns[7:-2]

df_kier_Calc = df_tmp[list_col]
df_kier_extract = df_tmp
df_kier_extract['SUM_OF_INST'] = df_kier_Calc.sum(axis = 1)

str_file = 'KIER_' + str_domain + '_INST_10MIN_MEANINTERPOLATED.csv'       
df_kier_extract.to_csv(str_dirName_h + str_file)

# %%
df_tmp.info()

# %%
# pd.set_option("display.max_columns", 999)
# # pd.set_option("display.max_seq_items", None)
# pd.set_option("display.max_rows", None)

# df_tmp.isnull().sum()

# %%
df_kier_extract
