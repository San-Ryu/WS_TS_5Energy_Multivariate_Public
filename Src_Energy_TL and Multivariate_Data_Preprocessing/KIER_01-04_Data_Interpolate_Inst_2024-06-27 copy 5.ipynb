# %% [markdown]
# ### Code Hist.

# %% [markdown]
# - CODE : KIER Data_전처리 (결측 제거)
# - DATE
# &ensp; 2023-10-12 Created
# &ensp; 2023-11-21 Code 최신화
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 기존 모듈화된 함수 사용
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 기존 KIER 변환 관련 코드를 모두 통합
# &ensp; 2024-01-19 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선, Raw로 저장
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) HOT (온수 사용량) 전용 Code 작성
# &ensp; 2024-01-30 Code 개선 후 백업
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (미완)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 백업 후 코드 최적화
# &ensp; 2024-02-05 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (Method 02 1차 완성)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; A. 순시값을 보간하는 방법은 3가지로 제안 가능
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) 단순 Linear 보간 (앞뒤 평균치)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; [Not Recommanded] 매우 긴 구간의 결측을 커버하기에 부적절
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; (양 끝이 0인 경우, 해당 구간을 제대로 보간 불가)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b) 직전 주 동일시간 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 직전 주의 데이터가 존재하지 않을 경우 보간 불가
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;(데이터 상 첫 주 케이스 등)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1) 해당 동일년도/동일월/동일요일/동일시간의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 과정이 조금 복잡해짐
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-2) 해당 동일 일시의 348 세대의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1보다 기대되는 적용 데이터량이 많음.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 한파/폭염/우천 등 예외적인 날씨에 따른 사용량 변동의 영향이 적어질 것으로 판단.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; B. 순시값을 보간하기 전 단계
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) Resample시, 시간이 NaN인 구간은 그 간격에서 비어있는 행이다.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-1) 시점 n의 적산량이 0이고 시점 n + 1의 적산량이 정상 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-2) 시점 n의 순시량이 음수인 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &ensp; 2024-02-07 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 결측 처리 부분 정확도 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) Raw Data 상 결측치가 15% 이상일 경우, 해당 데이터를 사용하지 않는 부분 추가
#
# - DESC
# &ensp; : int_Domain 코드의 변경에 따라,
# &emsp; KIER 에너지 사용량 데이터를 동/층/세대별로 분리
#
# &emsp; 또한, Raw Data과 세대별 데이터 추출 단계에서,
# &emsp; 아래와 같은 작업 진행
#
# &emsp; [수행 작업]
# &emsp; 1) Date Column에 대한 유효성 검사 및 이상 Data에 대한 소거
# &emsp; 1-1) Datetime 유효성 확인
# &emsp; 1-2) Datetime 이상치 제거
# &emsp; 2) HOUSE_ID_HO의 해시값을 int_house_num으로 변경 (용량 절감 목적)
# - DATA
# 1) Period :
# 2) Interval :
# - Link
# &ensp; :

# %% [markdown]
# ## 01. Code

# %% [markdown]
# ### 01-01. Init

# %% [markdown]
# #### 01-01-01. Init_Module Import

# %% [markdown]
# #### Module import

# %%
#region Basic_Import
## Basic
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.path.dirname(os.path.abspath('__file__'))
import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))

import warnings
warnings.filterwarnings('ignore')

import numpy as np, pandas as pd
from pandas import DataFrame, Series

import math, random

## Datetime
import time
import datetime as dt
from datetime import datetime, date, timedelta

import glob
from glob import glob
import requests
import json

## 시각화
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from scipy import stats

# K-Means 알고리즘
from sklearn.cluster import KMeans, MiniBatchKMeans

# CLustering 알고리즘의 성능 평가 측도
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score, adjusted_rand_score, silhouette_score, rand_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics.cluster import contingency_matrix

## 정규화
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import metrics

import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus

from selenium import webdriver
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

from tqdm.notebook import tqdm
import tqdm

## Init.
pd.options.display.float_format = '{:.10f}'.format
#endregion Basic_Import

# %%
## Import_DL
str_tar = "tf"
## For Torch
if str_tar == "torch":
    import torch
    import torch.nn as nn
    from torch.nn.utils import weight_norm
    print("Torch Imported")
## For TF
elif str_tar == "tf":
    import tensorflow as tf
    import tensorflow_addons as tfa
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    from keras.models import Sequential, load_model
    from keras_flops import get_flops
    print("Tensorflow Imported")
else:
    print("Error : Cannot be used except for Keywords")
    print(" : torch / tf")
# Out:
# Tensorflow Imported

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    print('Using GPU')
    tf.config.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
else : 
  print('Using CPU')
# Out:
# Using GPU

# %%
## Import_Local
from Src_Dev_Common import DEV_Common_Data_Datetime as com_date
# from Src_Dev_Common import DEV_KASI_Holiday as com_Holi
# from Src_Dev_Common import DEV_Common_Data_Analysis as com_Analysis
from Src_Dev_Common import DEV_Common_Data_Preprocessing as com_Prep
# from Src_Dev_Common import DEV_Common_Model as com_Model
# from Src_Dev_Common import DEV_Common_Data_Visualization as com_Visual
# from Src_Dev_Common import DEV_KMA_Weather_ASOS as com_ASOS
# from Src_Dev_Common import DEV_KDHC_Usage as com_KDHC
# from Src_Dev_Common import DEV_KIER_Usage as com_KIER

# %% [markdown]
# ### 01-01-02. Config (Directory, Params)

# %%
## Init_config
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = "1"
random.seed(SEED)

# %%
## Define Todate str
str_now_ymd = pd.datetime.now().date()
str_now_y, str_now_m, str_now_d = pd.datetime.now().year, pd.datetime.now().month, pd.datetime.now().day
str_now_hr, str_now_min = pd.datetime.now().hour, pd.datetime.now().minute

print(pd.datetime.now())
print(str(str_now_y) + " / " + str(str_now_m)  + " / " + str(str_now_d))
print(str(str_now_hr) + " : " + str(str_now_min))
# Out:
# 2024-07-04 13:19:58.326937
# 2024 / 7 / 4
# 13 : 19

# %%
## Dict_Domain
dict_domain = {0:"ELEC", 1:"HEAT", 2:"WATER", 3:"HOT_HEAT", 4:"HOT_FLOW", 5:"GAS"} ## GAS는 사용하지 않음.
int_domain = 5
str_domain = str(dict_domain[int_domain])

dict_col_accu = {0 : "ACTUAL_ACCU_EFF" ## ELEC
                 , 1 : "ACCU_HEAT" ## HEAT
                 , 2 : "ACCU_FLOW" ## WATER
                 , 3 : "ACCU_HEAT" ## HOT 열량
                 , 4 : "ACCU_FLOW" ## HOT 유량
                 , 5 : "ACCU_FLOW" ## GAS
                 }
str_col_accu = str(str_domain + "_" + str(dict_col_accu[int_domain]))

dict_col_inst = {0 : "INST_EFF" ## ELEC_INST_EFF
                , 1 : "INST_HEAT" ## HEAT_INST_HEAT
                , 2 : "INST_FLOW" ## WATER_INST_FLOW
                , 3 : "INST" ## HOT_HEAT_INST
                , 4 : "INST" ## HOT_FLOW_INST
                , 5 : "INST_FLOW" ## GAS_INST_FLOW
                } 
str_col_inst = str(str_domain + "_" + str(dict_col_inst[int_domain]))

## Directory Root
str_dirData = "../data/data_Energy_KIER/"
str_dir_raw = '../data/data_Energy_KIER/KIER_0_Raw/'
str_dirName_bld = '../data/data_Energy_KIER/KIER_1_BLD/'
str_dirName_h = '../data/data_Energy_KIER/KIER_2_H_' + str_domain + '/'

## File
str_fileRaw = str('KIER_RAW_' + str_domain + '_2024-06-07.csv')
str_fileRaw_hList = str('KIER_hList_Common.csv') 

print(str(os.listdir(str_dirData)) + "\n")
print(os.listdir(str_dirName_h))
# Out:
# ['.ipynb_checkpoints', 'BS_CONFIGURATION_202309251452.csv', 'DATE_1M_2023-10-20.csv', 'KIER 전처리 현황_2024-06-25.xlsx', 'KIER_0_Raw', 'KIER_1_BLD', 'KIER_2_H_ELEC', 'KIER_2_H_GAS', 'KIER_2_H_HEAT', 'KIER_2_H_HOT_FLOW', 'KIER_2_H_HOT_HEAT', 'KIER_2_H_WATER', 'KIER_ASOS_WEATHER_DAILY_202309251521.csv', 'KIER_ASOS_WEATHER_HOUR_202309251521.csv', 'KIER_DATA_OLD', 'KIER_ETC', 'KIER_hList_Comparison_2024-06-26.xlsx', 'KIER_List_Table_Column_2023-09-25.xlsx', 'KIER_Query_2023-09-25.txt', 'KMA_ASOS_119_2010_2023_1st_to CSV.csv', '[IITP] 데이터 테이블 정리 (공유 원본).docx']
#
# ['KIER_GAS_561-1-1_ACCU_01_Raw.csv', 'KIER_GAS_561-1-1_INST_01_10min.csv', 'KIER_GAS_561-1-2_ACCU_01_Raw.csv', 'KIER_GAS_561-1-2_INST_01_10min.csv', 'KIER_GAS_561-1-3_ACCU_01_Raw.csv', 'KIER_GAS_561-1-3_INST_01_10min.csv', 'KIER_GAS_561-1-4_ACCU_01_Raw.csv', 'KIER_GAS_561-1-4_INST_01_10min.csv', 'KIER_GAS_561-10-1_ACCU_01_Raw.csv', 'KIER_GAS_561-10-1_INST_01_10min.csv', 'KIER_GAS_561-10-2_ACCU_01_Raw.csv', 'KIER_GAS_561-10-2_INST_01_10min.csv', 'KIER_GAS_561-10-3_ACCU_01_Raw.csv', 'KIER_GAS_561-10-3_INST_01_10min.csv', 'KIER_GAS_561-10-4_ACCU_01_Raw.csv', 'KIER_GAS_561-10-4_INST_01_10min.csv', 'KIER_GAS_561-11-1_ACCU_01_Raw.csv', 'KIER_GAS_561-11-1_INST_01_10min.csv', 'KIER_GAS_561-11-2_ACCU_01_Raw.csv', 'KIER_GAS_561-11-2_INST_01_10min.csv', 'KIER_GAS_561-11-3_ACCU_01_Raw.csv', 'KIER_GAS_561-11-3_INST_01_10min.csv', 'KIER_GAS_561-11-4_ACCU_01_Raw.csv', 'KIER_GAS_561-11-4_INST_01_10min.csv', 'KIER_GAS_561-12-1_ACCU_01_Raw.csv', 'KIER_GAS_561-12-1_INST_01_10min.csv', 'KIER_GAS_561-12-2_ACCU_01_Raw.csv', 'KIER_GAS_561-12-2_INST_01_10min.csv', 'KIER_GAS_561-12-3_ACCU_01_Raw.csv', 'KIER_GAS_561-12-3_INST_01_10min.csv', 'KIER_GAS_561-12-4_ACCU_01_Raw.csv', 'KIER_GAS_561-12-4_INST_01_10min.csv', 'KIER_GAS_561-13-1_ACCU_01_Raw.csv', 'KIER_GAS_561-13-1_INST_01_10min.csv', 'KIER_GAS_561-13-2_ACCU_01_Raw.csv', 'KIER_GAS_561-13-2_INST_01_10min.csv', 'KIER_GAS_561-13-3_ACCU_01_Raw.csv', 'KIER_GAS_561-13-3_INST_01_10min.csv', 'KIER_GAS_561-13-4_ACCU_01_Raw.csv', 'KIER_GAS_561-13-4_INST_01_10min.csv', 'KIER_GAS_561-14-1_ACCU_01_Raw.csv', 'KIER_GAS_561-14-1_INST_01_10min.csv', 'KIER_GAS_561-14-2_ACCU_01_Raw.csv', 'KIER_GAS_561-14-2_INST_01_10min.csv', 'KIER_GAS_561-14-3_ACCU_01_Raw.csv', 'KIER_GAS_561-14-3_INST_01_10min.csv', 'KIER_GAS_561-14-4_ACCU_01_Raw.csv', 'KIER_GAS_561-14-4_INST_01_10min.csv', 'KIER_GAS_561-15-1_ACCU_01_Raw.csv', 'KIER_GAS_561-15-1_INST_01_10min.csv', 'KIER_GAS_561-15-2_ACCU_01_Raw.csv', 'KIER_GAS_561-15-2_INST_01_10min.csv', 'KIER_GAS_561-15-3_ACCU_01_Raw.csv', 'KIER_GAS_561-15-3_INST_01_10min.csv', 'KIER_GAS_561-15-4_ACCU_01_Raw.csv', 'KIER_GAS_561-15-4_INST_01_10min.csv', 'KIER_GAS_561-16-1_ACCU_01_Raw.csv', 'KIER_GAS_561-16-1_INST_01_10min.csv', 'KIER_GAS_561-16-2_ACCU_01_Raw.csv', 'KIER_GAS_561-16-2_INST_01_10min.csv', 'KIER_GAS_561-16-3_ACCU_01_Raw.csv', 'KIER_GAS_561-16-3_INST_01_10min.csv', 'KIER_GAS_561-16-4_ACCU_01_Raw.csv', 'KIER_GAS_561-16-4_INST_01_10min.csv', 'KIER_GAS_561-17-1_ACCU_01_Raw.csv', 'KIER_GAS_561-17-1_INST_01_10min.csv', 'KIER_GAS_561-17-2_ACCU_01_Raw.csv', 'KIER_GAS_561-17-2_INST_01_10min.csv', 'KIER_GAS_561-17-3_ACCU_01_Raw.csv', 'KIER_GAS_561-17-3_INST_01_10min.csv', 'KIER_GAS_561-17-4_ACCU_01_Raw.csv', 'KIER_GAS_561-17-4_INST_01_10min.csv', 'KIER_GAS_561-18-1_ACCU_01_Raw.csv', 'KIER_GAS_561-18-1_INST_01_10min.csv', 'KIER_GAS_561-18-2_ACCU_01_Raw.csv', 'KIER_GAS_561-18-2_INST_01_10min.csv', 'KIER_GAS_561-18-3_ACCU_01_Raw.csv', 'KIER_GAS_561-18-3_INST_01_10min.csv', 'KIER_GAS_561-18-4_ACCU_01_Raw.csv', 'KIER_GAS_561-18-4_INST_01_10min.csv', 'KIER_GAS_561-2-1_ACCU_01_Raw.csv', 'KIER_GAS_561-2-1_INST_01_10min.csv', 'KIER_GAS_561-2-2_ACCU_01_Raw.csv', 'KIER_GAS_561-2-2_INST_01_10min.csv', 'KIER_GAS_561-2-3_ACCU_01_Raw.csv', 'KIER_GAS_561-2-3_INST_01_10min.csv', 'KIER_GAS_561-2-4_ACCU_01_Raw.csv', 'KIER_GAS_561-2-4_INST_01_10min.csv', 'KIER_GAS_561-3-1_ACCU_01_Raw.csv', 'KIER_GAS_561-3-1_INST_01_10min.csv', 'KIER_GAS_561-3-2_ACCU_01_Raw.csv', 'KIER_GAS_561-3-2_INST_01_10min.csv', 'KIER_GAS_561-3-3_ACCU_01_Raw.csv', 'KIER_GAS_561-3-3_INST_01_10min.csv', 'KIER_GAS_561-3-4_ACCU_01_Raw.csv', 'KIER_GAS_561-3-4_INST_01_10min.csv', 'KIER_GAS_561-4-1_ACCU_01_Raw.csv', 'KIER_GAS_561-4-1_INST_01_10min.csv', 'KIER_GAS_561-4-2_ACCU_01_Raw.csv', 'KIER_GAS_561-4-2_INST_01_10min.csv', 'KIER_GAS_561-4-3_ACCU_01_Raw.csv', 'KIER_GAS_561-4-3_INST_01_10min.csv', 'KIER_GAS_561-4-4_ACCU_01_Raw.csv', 'KIER_GAS_561-4-4_INST_01_10min.csv', 'KIER_GAS_561-5-1_ACCU_01_Raw.csv', 'KIER_GAS_561-5-1_INST_01_10min.csv', 'KIER ...

# %%
## "KIER_01-01_Data_hList.ipynb"로부터 만들어진 Bld/F/H List
df_kier_hList = pd.read_csv(str_dir_raw + str_fileRaw_hList, index_col = 0)
list_h_id = df_kier_hList['HOUSE_ID'].drop_duplicates()
print(df_kier_hList.shape, " /// ", df_kier_hList.columns)
df_kier_hList
# Out:
# (348, 5)  ///  Index(['HOUSE_ID_DONG', 'HOUSE_ID_HO_PRE', 'HOUSE_ID_HO_INT', 'HOUSE_ID',
#        'HOUSE_ID_HO'],
#       dtype='object')
#      HOUSE_ID_DONG  HOUSE_ID_HO_PRE  HOUSE_ID_HO_INT  HOUSE_ID  \
# 1              561                1                1   561-1-1
# 2              561                1                2   561-1-2
# 3              561                1                3   561-1-3
# 4              561                1                4   561-1-4
# 5              561                2                1   561-2-1
# ..             ...              ...              ...       ...
# 344            563               23                2  563-23-2
# 345            563               23                3  563-23-3
# 346            563               23                4  563-23-4
# 347            563               24                1  563-24-1
# 348            563               24                2  563-24-2
#
#                                       HOUSE_ID_HO
# 1    NkI4M0EzNDYxQTE1MDJERjM4NURERTcyRjdGQTJDMDU=
# 2    ODBEOTE0QzZCMjg5RUMzNTRBQjM1NjE0RDNBNDE0NzU=
# 3    QTUwRUJDQTlBMkZENUQyNjg0RDRGREVFMTNGNDI3NUY=
# 4    RkRCQzY4OTlCMTRDQjgzNUZBREE3Njc2MkM2MUM2QjI=
# 5    MTQxNkQ1RDAzOTE5NTM5RUM3MzlDQkY3RTI2NERCQTM=
# ..                                            ...
# 344  QkJCQjQwOThFNjgwNjUwQzJGRUJFNDlCNTREOEUxNDU=
# 345  QUJENzFFMEFDRjM4MjY3NTRDQzJCRjdDNUQ3ODA0N0Y=
# 346  RUVENzZDNTc4MUY4NDg5MUREQjZEOUM1M0Q2RjYzMDE=
# 347  NEVENDc1OTFFNDBBRjBDQzkzMTlEMDgzMkMzMkZFQTg=
# 348  ODgwNDU1RUU0RUQ2OTQxQTBGMEI3MTE3NTkxODYxQ0U=
#
# [348 rows x 5 columns]

# %% [markdown]
# ## 01-02. Data Load (df_raw)

# %% [markdown]
# ### 01-02-01. KIER (Energy Usage)

# %% [markdown]
# ### 순시사용량

# %%
str_file = str('KIER_' + str_domain + '_INST_01_10min.csv')
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)
df_tmp['METER_DATE'] = pd.to_datetime(df_tmp['METER_DATE'])

list_tar_col = df_tmp.columns[0:]
df_tmp = df_tmp.reset_index()[list_tar_col] ## reset_index로 인해 발생한 index행 제거

# %%
## 정상적인 Time Period 외의 데이터는 삭제 (2022-07-17 ~ 2024-06-05)
df_period_tmp = pd.read_csv(str_dir_raw + "KIER_TIME_PERIOD.csv", index_col = 0)
df_period_tmp['METER_DATE'] = pd.to_datetime(df_period_tmp['METER_DATE'])

df_tmp = pd.merge(df_period_tmp['METER_DATE'], df_tmp, on = ['METER_DATE'], how = "left")
df_tmp
# Out:
#                METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0     2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1     2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2     2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3     2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4     2022-07-17 23:40:00          Sunday  2022      7   17    23      40
# ...                   ...             ...   ...    ...  ...   ...     ...
# 99166 2024-06-05 14:40:00       Wednesday  2024      6    5    14      40
# 99167 2024-06-05 14:50:00       Wednesday  2024      6    5    14      50
# 99168 2024-06-05 15:00:00       Wednesday  2024      6    5    15       0
# 99169 2024-06-05 15:10:00       Wednesday  2024      6    5    15      10
# 99170 2024-06-05 15:20:00       Wednesday  2024      6    5    15      20
#
#        code_day_of_the_week  GAS_INST_FLOW_561-1-1  GAS_INST_FLOW_561-1-2  \
# 0                         6                    NaN                    NaN
# 1                         6                    NaN                    NaN
# 2                         6                    NaN                    NaN
# 3                         6                    NaN                    NaN
# 4                         6                    NaN                    NaN
# ...                     ...                    ...                    ...
# 99166                     2                    NaN           0.0000000000
# 99167                     2                    NaN           0.0000000000
# 99168                     2                    NaN                    NaN
# 99169                     2                    NaN                    NaN
# 99170                     2           0.0000000000           0.0000000000
#
#        ...  GAS_INST_FLOW_563-22-5  GAS_INST_FLOW_563-22-6  \
# 0      ...                     NaN                     NaN
# 1      ...                     NaN                     NaN
# 2      ...                     NaN                     NaN
# 3      ...                     NaN                     NaN
# 4      ...                     NaN                     NaN
# ...    ...                     ...                     ...
# 99166  ...                     NaN                     NaN
# 99167  ...                     NaN                     NaN
# 99168  ...                     NaN                     NaN
# 99169  ...                     NaN                     NaN
# 99170  ...            0.0000000000            0.0000000000
#
#        GAS_INST_FLOW_563-23-1  GAS_INST_FLOW_563-23-2  GAS_INST_FLOW_563-23-3  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 99166                     NaN                     NaN                     NaN
# 99167                     NaN                     NaN                     NaN
# 99168                     NaN                     NaN                     NaN
# 99169                     NaN                     NaN                     NaN
# 99170            0.0000000000            0.0000000000            0.0000000000
#
#        GAS_INST_FLOW_563-23-4  GAS_INST_FLOW_563-24-1  GAS_INST_FLOW_563-24-2  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 99166                     NaN                     NaN                     NaN
# 99167                     NaN                     NaN                     NaN
# 99168                     NaN                     NaN                     NaN
# 99169                     NaN                     NaN                     NaN
# 99170            0.0000000000            0.0000000000            0.0000000000
#
#         MEAN_OF_INST     SUM_OF_INST
# 0     345.8333333333 2075.0000000000
# 1     347.5000000000 2085.0000000000
# 2     349.1666666667 2095.0000000000
# 3     350.8333333333 2105.0000000000
# 4     352.5000000000 2115.0000000000
# ...              ...             ...
# 99166 174.2500000000 2091.0000000000
# 99167  47.7500000000 2101.0000000000
# 99168 342.0000000000 2052.0000000000
# 99169  52.8717948718 2062.0000000000
# 99170   5.8531073446 2072.0000000000
#
# [99171 rows x 358 columns]

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Mean of Instantaneous Usage in ' + str_domain, fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'GAS_INST_FLOW_561-1-1',
#        'GAS_INST_FLOW_561-1-2',
#        ...
#        'GAS_INST_FLOW_563-22-5', 'GAS_INST_FLOW_563-22-6',
#        'GAS_INST_FLOW_563-23-1', 'GAS_INST_FLOW_563-23-2',
#        'GAS_INST_FLOW_563-23-3', 'GAS_INST_FLOW_563-23-4',
#        'GAS_INST_FLOW_563-24-1', 'GAS_INST_FLOW_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                    0
# day_of_the_week               0
# YEAR                          0
# MONTH                         0
# DAY                           0
#                           ...
# GAS_INST_FLOW_563-23-4    11898
# GAS_INST_FLOW_563-24-1    18551
# GAS_INST_FLOW_563-24-2    14523
# MEAN_OF_INST                  0
# SUM_OF_INST                   0
# Length: 358, dtype: int64

# %%
## 순시사용량이 음수인 경우 삭제
cnt_minus = 0
list_col_usage = list(df_tmp.columns[8:-2])

for i in range(0, len(df_tmp)) : 
    for col_tar in list_col_usage:
        if df_tmp[col_tar][i] < 0 : 
            print(col_tar, ' ///', df_tmp[col_tar][i])
            print(df_tmp[col_tar][i])
            cnt_minus = cnt_minus + 1
            df_tmp[col_tar][i] = np.nan

print(cnt_minus)

## 순시 사용량의 합계 및 평균 Column을 갱신
df_tmp['MEAN_OF_INST'] = df_tmp[list_col_usage].mean(axis = 1)
df_tmp['SUM_OF_INST'] = df_tmp[list_col_usage].sum(axis = 1)
# Out:
# 0

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage in certain household', fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'GAS_INST_FLOW_561-1-1',
#        'GAS_INST_FLOW_561-1-2',
#        ...
#        'GAS_INST_FLOW_563-22-5', 'GAS_INST_FLOW_563-22-6',
#        'GAS_INST_FLOW_563-23-1', 'GAS_INST_FLOW_563-23-2',
#        'GAS_INST_FLOW_563-23-3', 'GAS_INST_FLOW_563-23-4',
#        'GAS_INST_FLOW_563-24-1', 'GAS_INST_FLOW_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                    0
# day_of_the_week               0
# YEAR                          0
# MONTH                         0
# DAY                           0
#                           ...
# GAS_INST_FLOW_563-23-4    11898
# GAS_INST_FLOW_563-24-1    18551
# GAS_INST_FLOW_563-24-2    14523
# MEAN_OF_INST              10851
# SUM_OF_INST                   0
# Length: 358, dtype: int64

# %%
# df_tmp[['METER_DATE', 'MEAN_OF_INST', 'SUM_OF_INST']].to_csv(str_dir_raw + "KIER_TIME_PERIOD.csv")

# %% [markdown]
# #### 1차 보간 : 평균 대치법 (동일 시간대 전체 세대의 평균 순시 사용량)

# %%
for i in range(0, len(df_tmp)) : df_tmp.loc[i] = df_tmp.loc[i].fillna(df_tmp['MEAN_OF_INST'].loc[i])

## 순시 사용량의 합계 및 평균 Column을 갱신
df_tmp['MEAN_OF_INST'] = df_tmp[list_col_usage].mean(axis = 1)
df_tmp['SUM_OF_INST'] = df_tmp[list_col_usage].sum(axis = 1)

## 마지막값이 0이므로 제외
df_tmp = df_tmp[:-1]

str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp.to_csv(str_dirName_h + str_file)

print(df_tmp.isna().sum())
print(df_tmp.head(5))
plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + 'Usage : 1st - Mean of Inst', fontsize=30)
plt.show()
# Out:
# METER_DATE                    0
# day_of_the_week               0
# YEAR                          0
# MONTH                         0
# DAY                           0
#                           ...
# GAS_INST_FLOW_563-23-4    10851
# GAS_INST_FLOW_563-24-1    10851
# GAS_INST_FLOW_563-24-2    10851
# MEAN_OF_INST              10851
# SUM_OF_INST                   0
# Length: 358, dtype: int64
#            METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0 2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1 2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2 2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3 2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4 2022-07-17 23:40:00          Sunday  2022      7   17    23      40
#
#    code_day_of_the_week  GAS_INST_FLOW_561-1-1  GAS_INST_FLOW_561-1-2  ...  \
# 0                     6                    NaN                    NaN  ...
# 1                     6                    NaN                    NaN  ...
# 2                     6                    NaN                    NaN  ...
# 3                     6                    NaN                    NaN  ...
# 4                     6                    NaN                    NaN  ...
#
#    GAS_INST_FLOW_563-22-5  GAS_INST_FLOW_563-22-6  GAS_INST_FLOW_563-23-1  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    GAS_INST_FLOW_563-23-2  GAS_INST_FLOW_563-23-3  GAS_INST_FLOW_563-23-4  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    GAS_INST_FLOW_563-24-1  GAS_INST_FLOW_563-24-2  MEAN_OF_INST  SUM_OF_INST
# 0                     NaN                     NaN           NaN 0.0000000000
# 1                     NaN                     NaN           NaN 0.0000000000
# 2                     NaN                     NaN           NaN 0.0000000000
# 3                     NaN                     NaN           NaN 0.0000000000
# 4                     NaN                     NaN           NaN 0.0000000000
#
# [5 rows x 358 columns]

# %%
str_file = 'KIER_' + str_domain + '_INST_02_MeanInterpolated.csv'
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 2차 보간 : 선형 보간

# %% [markdown]
# 모든 값이 NaN이어서 평균 순시 사용량이 계산되지 않은 경우 존재 (ELEC 기준 약 1,372건)
# 해당 부분은 단순 선형 보간을 진행

# %%
## 사용량 컬럼에 대한 2차 보간 진행 (선형 보간)
df_linear_tmp, df_spline_tmp, df_polynomial_tmp, df_cubic_tmp = df_tmp.copy(), df_tmp.copy(), df_tmp.copy(), df_tmp.copy()
df_linear_tmp['MEAN_OF_INST'] = df_linear_tmp['MEAN_OF_INST'].interpolate('linear')
df_spline_tmp['MEAN_OF_INST'] = df_spline_tmp['MEAN_OF_INST'].interpolate('spline', order = 3) ## 3차 다항식 스플라인
# df_polynomial_tmp['MEAN_OF_INST'] = df_polynomial_tmp['MEAN_OF_INST'].interpolate('polynomian')
# df_cubic_tmp['MEAN_OF_INST'] = df_cubic_tmp['MEAN_OF_INST'].interpolate('cubicspline')

str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp.to_csv(str_dirName_h + str_file)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp.to_csv(str_dirName_h + str_file)

# %%
plt.figure(figsize=(20,4))
plt.plot(df_linear_tmp['METER_DATE'], df_linear_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-01 Linear', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.plot(df_spline_tmp['METER_DATE'], df_spline_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-02 Spline', fontsize=30)
plt.show()

# %%
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 이상치 제거 : IQR 방식으로 이상치 완화

# %%
## 여기서 IQR방식으로 전처리
list_col_usage = list(df_tmp.columns[8:-2])
for tar_col in list_col_usage:
    print(tar_col)
    df_h_tmp = df_tmp[['METER_DATE', tar_col]].copy()
    df_h_tmp = com_Prep.del_outlier_Usages(df_h_tmp, tar_col, 1)
    df_tmp[tar_col] = df_h_tmp[tar_col]
# Out:
# GAS_INST_FLOW_561-1-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 234
# 234
# GAS_INST_FLOW_561-1-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4536
# 4536
# GAS_INST_FLOW_561-1-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5131
# 5131
# GAS_INST_FLOW_561-1-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6119
# 6119
# GAS_INST_FLOW_561-2-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2286
# 2286
# GAS_INST_FLOW_561-2-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6125
# 6125
# GAS_INST_FLOW_561-2-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4164
# 4164
# GAS_INST_FLOW_561-2-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1408
# 1408
# GAS_INST_FLOW_561-3-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8333
# 8333
# GAS_INST_FLOW_561-3-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3996
# 3996
# GAS_INST_FLOW_561-3-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3931
# 3931
# GAS_INST_FLOW_561-3-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4953
# 4953
# GAS_INST_FLOW_561-4-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5044
# 5044
# GAS_INST_FLOW_561-4-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 188
# 188
# GAS_INST_FLOW_561-4-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2136
# 2136
# GAS_INST_FLOW_561-4-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3832
# 3832
# GAS_INST_FLOW_561-5-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5797
# 5797
# GAS_INST_FLOW_561-5-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5907
# 5907
# GAS_INST_FLOW_561-5-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4978
# 4978
# GAS_INST_FLOW_561-5-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 285
# 285
# GAS_INST_FLOW_561-6-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3745
# 3745
# GAS_INST_FLOW_561-6-2
# ===============  IQR Range ===============
# 0.0006269592476487499
# 0.0002507836990595
# 0.0002507836990595
# nan
# 0.0
# -0.00037617554858924995
# ===============  IQR Range ===============
# cnt_outlier = 5124
# 5124
# GAS_INST_FLOW_561-6-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5483
# 5483
# GAS_INST_FLOW_561-6-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5230
# 5230
# GAS_INST_FLOW_561-7-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2667
# 2667
# GAS_INST_FLOW_561-7-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7380
# 7380
# GAS_INST_FLOW_561-7-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5809
# 5809
# GAS_INST_FLOW_561-7-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4063
# 4063
# GAS_INST_FLOW_561-8-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7612
# 7612
# GAS_INST_FLOW_561-8-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1887
# 1887
# GAS_INST_FLOW_561-8-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1497
# 1497
# GAS_INST_FLOW_561-8-4
# ===============  IQR Range ===============
# 7.288629737613045e-05
# 2.9154518950452183e-05
# 2.9154518950452183e-05
# nan
# 0.0
# -4.373177842567828e-05
# ===============  IQR Range ===============
# cnt_outlier = 8414
# 8414
# GAS_INST_FLOW_561-9-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1968
# 1968
# GAS_INST_FLOW_561-9-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5462
# 5462
# GAS_INST_FLOW_561-9-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6858
# 6858
# GAS_INST_FLOW_561-9-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4898
# 4898
# GAS_INST_FLOW_561-10-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3220
# 3220
# GAS_INST_FLOW_561-10-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 565
# 565
# GAS_INST_FLOW_561-10-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4301
# 4301
# GAS_INST_FLOW_561-10-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4555
# 4555
# GAS_INST_FLOW_561-11-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3841
# 3841
# GAS_INST_FLOW_561-11-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3375
# 3375
# GAS_INST_FLOW_561-11-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3018
# 3018
# GAS_INST_FLOW_561-11-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4770
# 4770
# GAS_INST_FLOW_561-12-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4601
# 4601
# GAS_INST_FLOW_561-12-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5063
# 5063
# GAS_INST_FLOW_561-12-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1351
# 1351
# GAS_INST_FLOW_561-12-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 244
# 244
# GAS_INST_FLOW_561-13-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7588
# 7588
# GAS_INST_FLOW_561-13-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4999
# 4999
# GAS_INST_FLOW_561-13-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5261
# 5261
# GAS_INST_FLOW_561-13-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4702
# 4702
# GAS_INST_FLOW_561-14-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4168
# 4168
# GAS_INST_FLOW_561-14-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3576
# 3576
# GAS_INST_FLOW_561-14-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2266
# 2266
# GAS_INST_FLOW_561-14-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1399
# 1399
# GAS_INST_FLOW_561-15-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3365
# 3365
# GAS_INST_FLOW_561-15-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3768
# 3768
# GAS_INST_FLOW_561-15-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1143
# 1143
# GAS_INST_FLOW_561-15-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8096
# 8096
# GAS_INST_FLOW_561-16-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7302
# 7302
# GAS_INST_FLOW_561-16-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1657
# 1657
# GAS_INST_FLOW_561-16-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7339
# 7339
# GAS_INST_FLOW_561-16-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3268
# 3268
# GAS_INST_FLOW_561-17-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1303
# 1303
# GAS_INST_FLOW_561-17-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 341
# 341
# GAS_INST_FLOW_561-17-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2653
# 2653
# GAS_INST_FLOW_561-17-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6864
# 6864
# GAS_INST_FLOW_561-18-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4300
# 4300
# GAS_INST_FLOW_561-18-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 464
# 464
# GAS_INST_FLOW_561-18-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 226
# 226
# GAS_INST_FLOW_561-18-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3905
# 3905
# GAS_INST_FLOW_562-1-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 173
# 173
# GAS_INST_FLOW_562-1-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8033
# 8033
# GAS_INST_FLOW_562-1-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1023
# 1023
# GAS_INST_FLOW_562-1-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6724
# 6724
# GAS_INST_FLOW_562-1-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6633
# 6633
# GAS_INST_FLOW_562-1-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6626
# 6626
# GAS_INST_FLOW_562-2-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 576
# 576
# GAS_INST_FLOW_562-2-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7752
# 7752
# GAS_INST_FLOW_562-2-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5660
# 5660
# GAS_INST_FLOW_562-2-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 472
# 472
# GAS_INST_FLOW_562-2-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2858
# 2858
# GAS_INST_FLOW_562-2-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4082
# 4082
# GAS_INST_FLOW_562-3-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5432
# 5432
# GAS_INST_FLOW_562-3-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6797
# 6797
# GAS_INST_FLOW_562-3-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4577
# 4577
# GAS_INST_FLOW_562-3-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2783
# 2783
# GAS_INST_FLOW_562-3-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2841
# 2841
# GAS_INST_FLOW_562-3-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3883
# 3883
# GAS_INST_FLOW_562-4-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3139
# 3139
# GAS_INST_FLOW_562-4-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1604
# 1604
# GAS_INST_FLOW_562-4-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5313
# 5313
# GAS_INST_FLOW_562-4-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5277
# 5277
# GAS_INST_FLOW_562-4-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2488
# 2488
# GAS_INST_FLOW_562-4-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1887
# 1887
# GAS_INST_FLOW_562-5-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7877
# 7877
# GAS_INST_FLOW_562-5-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5912
# 5912
# GAS_INST_FLOW_562-5-3
# ===============  IQR Range ===============
# 0.00010838150289017715
# 4.335260115607086e-05
# 4.335260115607086e-05
# nan
# 0.0
# -6.502890173410629e-05
# ===============  IQR Range ===============
# cnt_outlier = 8305
# 8305
# GAS_INST_FLOW_562-5-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7576
# 7576
# GAS_INST_FLOW_562-5-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5161
# 5161
# GAS_INST_FLOW_562-5-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3160
# 3160
# GAS_INST_FLOW_562-6-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3360
# 3360
# GAS_INST_FLOW_562-6-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2354
# 2354
# GAS_INST_FLOW_562-6-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2741
# 2741
# GAS_INST_FLOW_562-6-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8814
# 8814
# GAS_INST_FLOW_562-6-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5812
# 5812
# GAS_INST_FLOW_562-6-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2200
# 2200
# GAS_INST_FLOW_562-7-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 276
# 276
# GAS_INST_FLOW_562-7-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2140
# 2140
# GAS_INST_FLOW_562-7-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 829
# 829
# GAS_INST_FLOW_562-7-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 356
# 356
# GAS_INST_FLOW_562-7-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3389
# 3389
# GAS_INST_FLOW_562-7-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1287
# 1287
# GAS_INST_FLOW_562-8-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6387
# 6387
# GAS_INST_FLOW_562-8-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4170
# 4170
# GAS_INST_FLOW_562-8-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6588
# 6588
# GAS_INST_FLOW_562-8-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2605
# 2605
# GAS_INST_FLOW_562-8-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 560
# 560
# GAS_INST_FLOW_562-8-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1569
# 1569
# GAS_INST_FLOW_562-9-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8453
# 8453
# GAS_INST_FLOW_562-9-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2353
# 2353
# GAS_INST_FLOW_562-9-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3384
# 3384
# GAS_INST_FLOW_562-9-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3901
# 3901
# GAS_INST_FLOW_562-9-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4477
# 4477
# GAS_INST_FLOW_562-9-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3309
# 3309
# GAS_INST_FLOW_562-10-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2328
# 2328
# GAS_INST_FLOW_562-10-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 719
# 719
# GAS_INST_FLOW_562-10-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7200
# 7200
# GAS_INST_FLOW_562-10-4
# ===============  IQR Range ===============
# 7.288629737613045e-05
# 2.9154518950452183e-05
# 2.9154518950452183e-05
# nan
# 0.0
# -4.373177842567828e-05
# ===============  IQR Range ===============
# cnt_outlier = 8428
# 8428
# GAS_INST_FLOW_562-10-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 714
# 714
# GAS_INST_FLOW_562-10-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1263
# 1263
# GAS_INST_FLOW_562-11-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 650
# 650
# GAS_INST_FLOW_562-11-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3966
# 3966
# GAS_INST_FLOW_562-11-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5679
# 5679
# GAS_INST_FLOW_562-11-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2411
# 2411
# GAS_INST_FLOW_562-11-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5264
# 5264
# GAS_INST_FLOW_562-11-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 383
# 383
# GAS_INST_FLOW_562-12-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 423
# 423
# GAS_INST_FLOW_562-12-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2643
# 2643
# GAS_INST_FLOW_562-12-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2326
# 2326
# GAS_INST_FLOW_562-12-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2941
# 2941
# GAS_INST_FLOW_562-12-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 300
# 300
# GAS_INST_FLOW_562-12-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4440
# 4440
# GAS_INST_FLOW_562-13-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2368
# 2368
# GAS_INST_FLOW_562-13-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3597
# 3597
# GAS_INST_FLOW_562-13-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7667
# 7667
# GAS_INST_FLOW_562-13-4
# ===============  IQR Range ===============
# 0.00030000000000000003
# 0.00012
# 0.00012
# nan
# 0.0
# -0.00018
# ===============  IQR Range ===============
# cnt_outlier = 7998
# 7998
# GAS_INST_FLOW_562-13-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 894
# 894
# GAS_INST_FLOW_562-13-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7283
# 7283
# GAS_INST_FLOW_562-14-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5723
# 5723
# GAS_INST_FLOW_562-14-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2353
# 2353
# GAS_INST_FLOW_562-14-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1887
# 1887
# GAS_INST_FLOW_562-14-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1627
# 1627
# GAS_INST_FLOW_562-14-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1153
# 1153
# GAS_INST_FLOW_562-14-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7406
# 7406
# GAS_INST_FLOW_562-15-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 350
# 350
# GAS_INST_FLOW_562-15-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 692
# 692
# GAS_INST_FLOW_562-15-3
# ===============  IQR Range ===============
# 0.000338983050847325
# 0.00013559322033893
# 0.00013559322033893
# nan
# 0.0
# -0.00020338983050839502
# ===============  IQR Range ===============
# cnt_outlier = 6532
# 6532
# GAS_INST_FLOW_562-15-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3566
# 3566
# GAS_INST_FLOW_562-15-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4150
# 4150
# GAS_INST_FLOW_562-15-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5344
# 5344
# GAS_INST_FLOW_562-16-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1995
# 1995
# GAS_INST_FLOW_562-16-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2142
# 2142
# GAS_INST_FLOW_562-16-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3547
# 3547
# GAS_INST_FLOW_562-16-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3001
# 3001
# GAS_INST_FLOW_562-16-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 701
# 701
# GAS_INST_FLOW_562-16-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 354
# 354
# GAS_INST_FLOW_562-17-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5536
# 5536
# GAS_INST_FLOW_562-17-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2123
# 2123
# GAS_INST_FLOW_562-17-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2938
# 2938
# GAS_INST_FLOW_562-17-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3314
# 3314
# GAS_INST_FLOW_562-17-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2761
# 2761
# GAS_INST_FLOW_562-17-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 204
# 204
# GAS_INST_FLOW_562-18-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2886
# 2886
# GAS_INST_FLOW_562-18-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1340
# 1340
# GAS_INST_FLOW_562-18-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1515
# 1515
# GAS_INST_FLOW_562-18-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2952
# 2952
# GAS_INST_FLOW_562-18-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7174
# 7174
# GAS_INST_FLOW_562-18-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6433
# 6433
# GAS_INST_FLOW_562-19-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6605
# 6605
# GAS_INST_FLOW_562-19-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1020
# 1020
# GAS_INST_FLOW_562-19-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4660
# 4660
# GAS_INST_FLOW_562-19-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1602
# 1602
# GAS_INST_FLOW_562-19-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6444
# 6444
# GAS_INST_FLOW_562-19-6
# ===============  IQR Range ===============
# 0.00014534883720928874
# 5.81395348837155e-05
# 5.81395348837155e-05
# nan
# 0.0
# -8.720930232557325e-05
# ===============  IQR Range ===============
# cnt_outlier = 8134
# 8134
# GAS_INST_FLOW_562-20-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5919
# 5919
# GAS_INST_FLOW_562-20-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5305
# 5305
# GAS_INST_FLOW_562-20-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2887
# 2887
# GAS_INST_FLOW_562-20-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2641
# 2641
# GAS_INST_FLOW_562-20-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1658
# 1658
# GAS_INST_FLOW_562-20-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3446
# 3446
# GAS_INST_FLOW_562-21-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5044
# 5044
# GAS_INST_FLOW_562-21-2
# ===============  IQR Range ===============
# 0.0001488095238095241
# 5.9523809523809646e-05
# 5.9523809523809646e-05
# nan
# 0.0
# -8.928571428571446e-05
# ===============  IQR Range ===============
# cnt_outlier = 8084
# 8084
# GAS_INST_FLOW_562-21-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2088
# 2088
# GAS_INST_FLOW_562-21-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4137
# 4137
# GAS_INST_FLOW_562-21-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5159
# 5159
# GAS_INST_FLOW_562-21-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1938
# 1938
# GAS_INST_FLOW_562-22-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2651
# 2651
# GAS_INST_FLOW_562-22-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 360
# 360
# GAS_INST_FLOW_562-22-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3307
# 3307
# GAS_INST_FLOW_562-22-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2192
# 2192
# GAS_INST_FLOW_562-22-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2370
# 2370
# GAS_INST_FLOW_562-22-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7599
# 7599
# GAS_INST_FLOW_562-23-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2263
# 2263
# GAS_INST_FLOW_562-23-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3097
# 3097
# GAS_INST_FLOW_562-23-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 236
# 236
# GAS_INST_FLOW_562-23-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1351
# 1351
# GAS_INST_FLOW_562-24-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1211
# 1211
# GAS_INST_FLOW_562-24-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2116
# 2116
# GAS_INST_FLOW_563-1-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 382
# 382
# GAS_INST_FLOW_563-1-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2479
# 2479
# GAS_INST_FLOW_563-1-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7756
# 7756
# GAS_INST_FLOW_563-1-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4584
# 4584
# GAS_INST_FLOW_563-1-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2974
# 2974
# GAS_INST_FLOW_563-1-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1846
# 1846
# GAS_INST_FLOW_563-2-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2331
# 2331
# GAS_INST_FLOW_563-2-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2754
# 2754
# GAS_INST_FLOW_563-2-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3485
# 3485
# GAS_INST_FLOW_563-2-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1081
# 1081
# GAS_INST_FLOW_563-2-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 667
# 667
# GAS_INST_FLOW_563-2-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 588
# 588
# GAS_INST_FLOW_563-3-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5063
# 5063
# GAS_INST_FLOW_563-3-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2083
# 2083
# GAS_INST_FLOW_563-3-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5061
# 5061
# GAS_INST_FLOW_563-3-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2831
# 2831
# GAS_INST_FLOW_563-3-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3655
# 3655
# GAS_INST_FLOW_563-3-6
# ===============  IQR Range ===============
# 0.02500000000011925
# 0.0100000000000477
# 0.0100000000000477
# nan
# 0.0
# -0.01500000000007155
# ===============  IQR Range ===============
# cnt_outlier = 5042
# 5042
# GAS_INST_FLOW_563-4-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2160
# 2160
# GAS_INST_FLOW_563-4-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5493
# 5493
# GAS_INST_FLOW_563-4-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 209
# 209
# GAS_INST_FLOW_563-4-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 599
# 599
# GAS_INST_FLOW_563-4-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2779
# 2779
# GAS_INST_FLOW_563-4-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 562
# 562
# GAS_INST_FLOW_563-5-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6792
# 6792
# GAS_INST_FLOW_563-5-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2758
# 2758
# GAS_INST_FLOW_563-5-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4133
# 4133
# GAS_INST_FLOW_563-5-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2821
# 2821
# GAS_INST_FLOW_563-5-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4907
# 4907
# GAS_INST_FLOW_563-5-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5757
# 5757
# GAS_INST_FLOW_563-6-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 603
# 603
# GAS_INST_FLOW_563-6-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4826
# 4826
# GAS_INST_FLOW_563-6-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2901
# 2901
# GAS_INST_FLOW_563-6-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2161
# 2161
# GAS_INST_FLOW_563-6-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3176
# 3176
# GAS_INST_FLOW_563-6-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2539
# 2539
# GAS_INST_FLOW_563-7-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2813
# 2813
# GAS_INST_FLOW_563-7-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3373
# 3373
# GAS_INST_FLOW_563-7-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4118
# 4118
# GAS_INST_FLOW_563-7-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 375
# 375
# GAS_INST_FLOW_563-7-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4731
# 4731
# GAS_INST_FLOW_563-7-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2840
# 2840
# GAS_INST_FLOW_563-8-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5788
# 5788
# GAS_INST_FLOW_563-8-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5657
# 5657
# GAS_INST_FLOW_563-8-3
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 3091
# 3091
# GAS_INST_FLOW_563-8-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2263
# 2263
# GAS_INST_FLOW_563-8-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1483
# 1483
# GAS_INST_FLOW_563-8-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1457
# 1457
# GAS_INST_FLOW_563-9-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3388
# 3388
# GAS_INST_FLOW_563-9-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1723
# 1723
# GAS_INST_FLOW_563-9-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2634
# 2634
# GAS_INST_FLOW_563-9-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5308
# 5308
# GAS_INST_FLOW_563-9-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5791
# 5791
# GAS_INST_FLOW_563-9-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3250
# 3250
# GAS_INST_FLOW_563-10-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1323
# 1323
# GAS_INST_FLOW_563-10-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 198
# 198
# GAS_INST_FLOW_563-10-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1041
# 1041
# GAS_INST_FLOW_563-10-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4449
# 4449
# GAS_INST_FLOW_563-10-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1788
# 1788
# GAS_INST_FLOW_563-10-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1823
# 1823
# GAS_INST_FLOW_563-11-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4889
# 4889
# GAS_INST_FLOW_563-11-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7463
# 7463
# GAS_INST_FLOW_563-11-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1155
# 1155
# GAS_INST_FLOW_563-11-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 581
# 581
# GAS_INST_FLOW_563-11-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 849
# 849
# GAS_INST_FLOW_563-11-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1596
# 1596
# GAS_INST_FLOW_563-12-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3628
# 3628
# GAS_INST_FLOW_563-12-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3301
# 3301
# GAS_INST_FLOW_563-12-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3233
# 3233
# GAS_INST_FLOW_563-12-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 715
# 715
# GAS_INST_FLOW_563-12-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3011
# 3011
# GAS_INST_FLOW_563-12-6
# ===============  IQR Range ===============
# 9.920634920639981e-05
# 3.968253968255992e-05
# 3.968253968255992e-05
# nan
# 0.0
# -5.952380952383988e-05
# ===============  IQR Range ===============
# cnt_outlier = 8442
# 8442
# GAS_INST_FLOW_563-13-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1470
# 1470
# GAS_INST_FLOW_563-13-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3100
# 3100
# GAS_INST_FLOW_563-13-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3683
# 3683
# GAS_INST_FLOW_563-13-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2183
# 2183
# GAS_INST_FLOW_563-13-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1027
# 1027
# GAS_INST_FLOW_563-13-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2029
# 2029
# GAS_INST_FLOW_563-14-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3705
# 3705
# GAS_INST_FLOW_563-14-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1144
# 1144
# GAS_INST_FLOW_563-14-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2642
# 2642
# GAS_INST_FLOW_563-14-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2433
# 2433
# GAS_INST_FLOW_563-14-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1019
# 1019
# GAS_INST_FLOW_563-14-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2837
# 2837
# GAS_INST_FLOW_563-15-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3829
# 3829
# GAS_INST_FLOW_563-15-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2146
# 2146
# GAS_INST_FLOW_563-15-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 184
# 184
# GAS_INST_FLOW_563-15-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3433
# 3433
# GAS_INST_FLOW_563-15-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3061
# 3061
# GAS_INST_FLOW_563-15-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5076
# 5076
# GAS_INST_FLOW_563-16-1
# ===============  IQR Range ===============
# 8.906329435680852e-05
# 3.5625317742723414e-05
# 3.5625317742723414e-05
# nan
# 0.0
# -5.343797661408512e-05
# ===============  IQR Range ===============
# cnt_outlier = 8561
# 8561
# GAS_INST_FLOW_563-16-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5806
# 5806
# GAS_INST_FLOW_563-16-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1790
# 1790
# GAS_INST_FLOW_563-16-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2166
# 2166
# GAS_INST_FLOW_563-16-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6003
# 6003
# GAS_INST_FLOW_563-16-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5949
# 5949
# GAS_INST_FLOW_563-17-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2217
# 2217
# GAS_INST_FLOW_563-17-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1847
# 1847
# GAS_INST_FLOW_563-17-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6659
# 6659
# GAS_INST_FLOW_563-17-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4755
# 4755
# GAS_INST_FLOW_563-17-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 3705
# 3705
# GAS_INST_FLOW_563-17-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8602
# 8602
# GAS_INST_FLOW_563-18-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1333
# 1333
# GAS_INST_FLOW_563-18-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 194
# 194
# GAS_INST_FLOW_563-18-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5418
# 5418
# GAS_INST_FLOW_563-18-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 872
# 872
# GAS_INST_FLOW_563-18-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2466
# 2466
# GAS_INST_FLOW_563-18-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 911
# 911
# GAS_INST_FLOW_563-19-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 731
# 731
# GAS_INST_FLOW_563-19-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5710
# 5710
# GAS_INST_FLOW_563-19-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 886
# 886
# GAS_INST_FLOW_563-19-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 166
# 166
# GAS_INST_FLOW_563-19-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7428
# 7428
# GAS_INST_FLOW_563-19-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1952
# 1952
# GAS_INST_FLOW_563-20-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2786
# 2786
# GAS_INST_FLOW_563-20-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 424
# 424
# GAS_INST_FLOW_563-20-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 559
# 559
# GAS_INST_FLOW_563-20-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5046
# 5046
# GAS_INST_FLOW_563-20-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5239
# 5239
# GAS_INST_FLOW_563-20-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2644
# 2644
# GAS_INST_FLOW_563-21-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1979
# 1979
# GAS_INST_FLOW_563-21-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2363
# 2363
# GAS_INST_FLOW_563-21-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7134
# 7134
# GAS_INST_FLOW_563-21-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 505
# 505
# GAS_INST_FLOW_563-21-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4561
# 4561
# GAS_INST_FLOW_563-21-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2474
# 2474
# GAS_INST_FLOW_563-22-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4400
# 4400
# GAS_INST_FLOW_563-22-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2310
# 2310
# GAS_INST_FLOW_563-22-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 5942
# 5942
# GAS_INST_FLOW_563-22-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 6889
# 6889
# GAS_INST_FLOW_563-22-5
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2749
# 2749
# GAS_INST_FLOW_563-22-6
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 1384
# 1384
# GAS_INST_FLOW_563-23-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4620
# 4620
# GAS_INST_FLOW_563-23-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2606
# 2606
# GAS_INST_FLOW_563-23-3
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 4225
# 4225
# GAS_INST_FLOW_563-23-4
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2684
# 2684
# GAS_INST_FLOW_563-24-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8823
# 8823
# GAS_INST_FLOW_563-24-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 2890
# 2890

# %%
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp.to_csv(str_dirName_h + str_file)

# %%
str_file = 'KIER_' + str_domain + '_INST_01_10min.csv'
df_tmp_00 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp_01 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_tmp_0201 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_tmp_0202 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp_03 = pd.read_csv(str_dirName_h + str_file, index_col = 0)

period_tmp = df_tmp_0201['METER_DATE']
period_tmp
# Out:
# 0        2022-07-17 23:00:00
# 1        2022-07-17 23:10:00
# 2        2022-07-17 23:20:00
# 3        2022-07-17 23:30:00
# 4        2022-07-17 23:40:00
#                 ...
# 99164    2024-06-05 14:20:00
# 99165    2024-06-05 14:30:00
# 99166    2024-06-05 14:40:00
# 99167    2024-06-05 14:50:00
# 99168    2024-06-05 15:00:00
# Name: METER_DATE, Length: 99169, dtype: object

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_01[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[-2:-1]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
df_tmp_01.columns
# Out:
# Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'GAS_INST_FLOW_561-1-1',
#        'GAS_INST_FLOW_561-1-2',
#        ...
#        'GAS_INST_FLOW_563-22-5', 'GAS_INST_FLOW_563-22-6',
#        'GAS_INST_FLOW_563-23-1', 'GAS_INST_FLOW_563-23-2',
#        'GAS_INST_FLOW_563-23-3', 'GAS_INST_FLOW_563-23-4',
#        'GAS_INST_FLOW_563-24-1', 'GAS_INST_FLOW_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)

# %%
tar_col = 'SUM_OF_INST'

fig, ax1 = plt.subplots(figsize = (30,5))
usage_A = df_tmp_01[tar_col].copy()[:-1]
usage_B = df_tmp_0201[tar_col].copy()[:-1]
ax1.plot(period_tmp, usage_A, color = 'red')
ax1.plot(period_tmp, usage_B, color = 'red')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 7
#       5 usage_B = df_tmp_0201[tar_col].copy()[:-1]
#       6 ax1.plot(period_tmp, usage_A, color = 'red')
# ----> 7 ax1.plot(period_tmp, usage_B, color = 'red')
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\matplotlib\axes\_axes.py:1688, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1445 """
#    1446 Plot y versus x as lines and/or markers.
#    1447
#    (...)
#    1685 (``'green'``) or hex strings (``'#008000'``).
#    1686 """
#    1687 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1688 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1689 for line in lines:
#    1690     self.add_line(line)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\matplotlib\axes\_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (99169,) and (99168,)

# %%
list_tar_col = df_tmp.columns[1:]
for tar_col in list_tar_col:
    print(tar_col)
    df_tmp[tar_col] = com_Prep.del_outlier_Usages(df_tmp, tar_col)

# %%
df_tmp

# %%
## 합계 순시량 다시 계산 
list_col = df_tmp.columns[7:-2]

df_kier_Calc = df_tmp[list_col]
df_kier_extract = df_tmp
df_kier_extract['SUM_OF_INST'] = df_kier_Calc.sum(axis = 1)

str_file = 'KIER_' + str_domain + '_INST_10MIN_MEANINTERPOLATED.csv'       
df_kier_extract.to_csv(str_dirName_h + str_file)

# %%
df_tmp.info()

# %%
# pd.set_option("display.max_columns", 999)
# # pd.set_option("display.max_seq_items", None)
# pd.set_option("display.max_rows", None)

# df_tmp.isnull().sum()

# %%
df_kier_extract
