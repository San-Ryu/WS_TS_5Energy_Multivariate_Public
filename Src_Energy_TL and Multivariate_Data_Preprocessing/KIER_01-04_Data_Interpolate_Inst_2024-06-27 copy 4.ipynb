# %% [markdown]
# ### Code Hist.

# %% [markdown]
# - CODE : KIER Data_전처리 (결측 제거)
# - DATE
# &ensp; 2023-10-12 Created
# &ensp; 2023-11-21 Code 최신화
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 기존 모듈화된 함수 사용
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 기존 KIER 변환 관련 코드를 모두 통합
# &ensp; 2024-01-19 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선, Raw로 저장
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) HOT (온수 사용량) 전용 Code 작성
# &ensp; 2024-01-30 Code 개선 후 백업
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (미완)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 백업 후 코드 최적화
# &ensp; 2024-02-05 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (Method 02 1차 완성)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; A. 순시값을 보간하는 방법은 3가지로 제안 가능
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) 단순 Linear 보간 (앞뒤 평균치)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; [Not Recommanded] 매우 긴 구간의 결측을 커버하기에 부적절
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; (양 끝이 0인 경우, 해당 구간을 제대로 보간 불가)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b) 직전 주 동일시간 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 직전 주의 데이터가 존재하지 않을 경우 보간 불가
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;(데이터 상 첫 주 케이스 등)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1) 해당 동일년도/동일월/동일요일/동일시간의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 과정이 조금 복잡해짐
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-2) 해당 동일 일시의 348 세대의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1보다 기대되는 적용 데이터량이 많음.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 한파/폭염/우천 등 예외적인 날씨에 따른 사용량 변동의 영향이 적어질 것으로 판단.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; B. 순시값을 보간하기 전 단계
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) Resample시, 시간이 NaN인 구간은 그 간격에서 비어있는 행이다.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-1) 시점 n의 적산량이 0이고 시점 n + 1의 적산량이 정상 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-2) 시점 n의 순시량이 음수인 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &ensp; 2024-02-07 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 결측 처리 부분 정확도 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) Raw Data 상 결측치가 15% 이상일 경우, 해당 데이터를 사용하지 않는 부분 추가
#
# - DESC
# &ensp; : int_Domain 코드의 변경에 따라,
# &emsp; KIER 에너지 사용량 데이터를 동/층/세대별로 분리
#
# &emsp; 또한, Raw Data과 세대별 데이터 추출 단계에서,
# &emsp; 아래와 같은 작업 진행
#
# &emsp; [수행 작업]
# &emsp; 1) Date Column에 대한 유효성 검사 및 이상 Data에 대한 소거
# &emsp; 1-1) Datetime 유효성 확인
# &emsp; 1-2) Datetime 이상치 제거
# &emsp; 2) HOUSE_ID_HO의 해시값을 int_house_num으로 변경 (용량 절감 목적)
# - DATA
# 1) Period :
# 2) Interval :
# - Link
# &ensp; :

# %% [markdown]
# ## 01. Code

# %% [markdown]
# ### 01-01. Init

# %% [markdown]
# #### 01-01-01. Init_Module Import

# %% [markdown]
# #### Module import

# %%
#region Basic_Import
## Basic
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.path.dirname(os.path.abspath('__file__'))
import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))

import warnings
warnings.filterwarnings('ignore')

import numpy as np, pandas as pd
from pandas import DataFrame, Series

import math, random

## Datetime
import time
import datetime as dt
from datetime import datetime, date, timedelta

import glob
from glob import glob
import requests
import json

## 시각화
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from scipy import stats

# K-Means 알고리즘
from sklearn.cluster import KMeans, MiniBatchKMeans

# CLustering 알고리즘의 성능 평가 측도
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score, adjusted_rand_score, silhouette_score, rand_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics.cluster import contingency_matrix

## 정규화
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import metrics

import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus

from selenium import webdriver
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

from tqdm.notebook import tqdm
import tqdm

## Init.
pd.options.display.float_format = '{:.10f}'.format
#endregion Basic_Import

# %%
## Import_DL
str_tar = "tf"
## For Torch
if str_tar == "torch":
    import torch
    import torch.nn as nn
    from torch.nn.utils import weight_norm
    print("Torch Imported")
## For TF
elif str_tar == "tf":
    import tensorflow as tf
    import tensorflow_addons as tfa
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    from keras.models import Sequential, load_model
    from keras_flops import get_flops
    print("Tensorflow Imported")
else:
    print("Error : Cannot be used except for Keywords")
    print(" : torch / tf")
# Out:
# Tensorflow Imported

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    print('Using GPU')
    tf.config.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
else : 
  print('Using CPU')
# Out:
# Using GPU

# %%
## Import_Local
from Src_Dev_Common import DEV_Common_Data_Datetime as com_date
# from Src_Dev_Common import DEV_KASI_Holiday as com_Holi
# from Src_Dev_Common import DEV_Common_Data_Analysis as com_Analysis
from Src_Dev_Common import DEV_Common_Data_Preprocessing as com_Prep
# from Src_Dev_Common import DEV_Common_Model as com_Model
# from Src_Dev_Common import DEV_Common_Data_Visualization as com_Visual
# from Src_Dev_Common import DEV_KMA_Weather_ASOS as com_ASOS
# from Src_Dev_Common import DEV_KDHC_Usage as com_KDHC
# from Src_Dev_Common import DEV_KIER_Usage as com_KIER

# %% [markdown]
# ### 01-01-02. Config (Directory, Params)

# %%
## Init_config
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = "1"
random.seed(SEED)

# %%
## Define Todate str
str_now_ymd = pd.datetime.now().date()
str_now_y, str_now_m, str_now_d = pd.datetime.now().year, pd.datetime.now().month, pd.datetime.now().day
str_now_hr, str_now_min = pd.datetime.now().hour, pd.datetime.now().minute

print(pd.datetime.now())
print(str(str_now_y) + " / " + str(str_now_m)  + " / " + str(str_now_d))
print(str(str_now_hr) + " : " + str(str_now_min))
# Out:
# 2024-07-04 10:54:35.508288
# 2024 / 7 / 4
# 10 : 54

# %%
## Dict_Domain
dict_domain = {0:"ELEC", 1:"HEAT", 2:"WATER", 3:"HOT_HEAT", 4:"HOT_FLOW", 5:"GAS"} ## GAS는 사용하지 않음.
int_domain = 4
str_domain = str(dict_domain[int_domain])

dict_col_accu = {0 : "ACTUAL_ACCU_EFF" ## ELEC
                 , 1 : "ACCU_HEAT" ## HEAT
                 , 2 : "ACCU_FLOW" ## WATER
                 , 3 : "ACCU_HEAT" ## HOT 열량
                 , 4 : "ACCU_FLOW" ## HOT 유량
                 , 5 : "ACCU_FLOW" ## GAS
                 }
str_col_accu = str(str_domain + "_" + str(dict_col_accu[int_domain]))

dict_col_inst = {0 : "INST_EFF" ## ELEC_INST_EFF
                , 1 : "INST_HEAT" ## HEAT_INST_HEAT
                , 2 : "INST_FLOW" ## WATER_INST_FLOW
                , 3 : "INST" ## HOT_HEAT_INST
                , 4 : "INST" ## HOT_FLOW_INST
                , 5 : "INST_FLOW" ## GAS_INST_FLOW
                } 
str_col_inst = str(str_domain + "_" + str(dict_col_inst[int_domain]))

## Directory Root
str_dirData = "../data/data_Energy_KIER/"
str_dir_raw = '../data/data_Energy_KIER/KIER_0_Raw/'
str_dirName_bld = '../data/data_Energy_KIER/KIER_1_BLD/'
str_dirName_h = '../data/data_Energy_KIER/KIER_2_H_' + str_domain + '/'

## File
str_fileRaw = str('KIER_RAW_' + str_domain + '_2024-06-07.csv')
str_fileRaw_hList = str('KIER_hList_Common.csv') 

print(str(os.listdir(str_dirData)) + "\n")
print(os.listdir(str_dirName_h))
# Out:
# ['.ipynb_checkpoints', 'BS_CONFIGURATION_202309251452.csv', 'DATE_1M_2023-10-20.csv', 'KIER 전처리 현황_2024-06-25.xlsx', 'KIER_0_Raw', 'KIER_1_BLD', 'KIER_2_H_ELEC', 'KIER_2_H_GAS', 'KIER_2_H_HEAT', 'KIER_2_H_HOT_FLOW', 'KIER_2_H_HOT_HEAT', 'KIER_2_H_WATER', 'KIER_ASOS_WEATHER_DAILY_202309251521.csv', 'KIER_ASOS_WEATHER_HOUR_202309251521.csv', 'KIER_DATA_OLD', 'KIER_ETC', 'KIER_hList_Comparison_2024-06-26.xlsx', 'KIER_List_Table_Column_2023-09-25.xlsx', 'KIER_Query_2023-09-25.txt', 'KMA_ASOS_119_2010_2023_1st_to CSV.csv', '[IITP] 데이터 테이블 정리 (공유 원본).docx']
#
# ['KIER_HOT_FLOW_561-1-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-1-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-1-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-1-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-1-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-1-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-1-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-1-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-10-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-10-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-10-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-10-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-10-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-10-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-10-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-10-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-11-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-11-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-11-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-11-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-11-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-11-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-11-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-11-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-12-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-12-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-12-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-12-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-12-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-12-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-12-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-12-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-13-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-13-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-13-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-13-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-13-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-13-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-13-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-13-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-14-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-14-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-14-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-14-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-14-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-14-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-14-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-14-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-15-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-15-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-15-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-15-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-15-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-15-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-15-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-15-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-16-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-16-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-16-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-16-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-16-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-16-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-16-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-16-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-17-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-17-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-17-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-17-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-17-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-17-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-17-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-17-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-18-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-18-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-18-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-18-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-18-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-18-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-18-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-18-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-2-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-2-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-2-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-2-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-2-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-2-3_INST_01_10min.csv', 'KIER_HOT_FLOW_561-2-4_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-2-4_INST_01_10min.csv', 'KIER_HOT_FLOW_561-3-1_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-3-1_INST_01_10min.csv', 'KIER_HOT_FLOW_561-3-2_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-3-2_INST_01_10min.csv', 'KIER_HOT_FLOW_561-3-3_ACCU_01_Raw.csv', 'KIER_HOT_FLOW_561-3-3 ...

# %%
## "KIER_01-01_Data_hList.ipynb"로부터 만들어진 Bld/F/H List
df_kier_hList = pd.read_csv(str_dir_raw + str_fileRaw_hList, index_col = 0)
list_h_id = df_kier_hList['HOUSE_ID'].drop_duplicates()
print(df_kier_hList.shape, " /// ", df_kier_hList.columns)
df_kier_hList
# Out:
# (348, 5)  ///  Index(['HOUSE_ID_DONG', 'HOUSE_ID_HO_PRE', 'HOUSE_ID_HO_INT', 'HOUSE_ID',
#        'HOUSE_ID_HO'],
#       dtype='object')
#      HOUSE_ID_DONG  HOUSE_ID_HO_PRE  HOUSE_ID_HO_INT  HOUSE_ID  \
# 1              561                1                1   561-1-1
# 2              561                1                2   561-1-2
# 3              561                1                3   561-1-3
# 4              561                1                4   561-1-4
# 5              561                2                1   561-2-1
# ..             ...              ...              ...       ...
# 344            563               23                2  563-23-2
# 345            563               23                3  563-23-3
# 346            563               23                4  563-23-4
# 347            563               24                1  563-24-1
# 348            563               24                2  563-24-2
#
#                                       HOUSE_ID_HO
# 1    NkI4M0EzNDYxQTE1MDJERjM4NURERTcyRjdGQTJDMDU=
# 2    ODBEOTE0QzZCMjg5RUMzNTRBQjM1NjE0RDNBNDE0NzU=
# 3    QTUwRUJDQTlBMkZENUQyNjg0RDRGREVFMTNGNDI3NUY=
# 4    RkRCQzY4OTlCMTRDQjgzNUZBREE3Njc2MkM2MUM2QjI=
# 5    MTQxNkQ1RDAzOTE5NTM5RUM3MzlDQkY3RTI2NERCQTM=
# ..                                            ...
# 344  QkJCQjQwOThFNjgwNjUwQzJGRUJFNDlCNTREOEUxNDU=
# 345  QUJENzFFMEFDRjM4MjY3NTRDQzJCRjdDNUQ3ODA0N0Y=
# 346  RUVENzZDNTc4MUY4NDg5MUREQjZEOUM1M0Q2RjYzMDE=
# 347  NEVENDc1OTFFNDBBRjBDQzkzMTlEMDgzMkMzMkZFQTg=
# 348  ODgwNDU1RUU0RUQ2OTQxQTBGMEI3MTE3NTkxODYxQ0U=
#
# [348 rows x 5 columns]

# %% [markdown]
# ## 01-02. Data Load (df_raw)

# %% [markdown]
# ### 01-02-01. KIER (Energy Usage)

# %% [markdown]
# ### 순시사용량

# %%
str_file = str('KIER_' + str_domain + '_INST_01_10min.csv')
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)
df_tmp['METER_DATE'] = pd.to_datetime(df_tmp['METER_DATE'])

list_tar_col = df_tmp.columns[0:]
df_tmp = df_tmp.reset_index()[list_tar_col] ## reset_index로 인해 발생한 index행 제거

# %%
## 정상적인 Time Period 외의 데이터는 삭제 (2022-07-17 ~ 2024-06-05)
df_period_tmp = pd.read_csv(str_dir_raw + "KIER_TIME_PERIOD.csv", index_col = 0)
df_period_tmp['METER_DATE'] = pd.to_datetime(df_period_tmp['METER_DATE'])

df_tmp = pd.merge(df_period_tmp['METER_DATE'], df_tmp, on = ['METER_DATE'], how = "left")
df_tmp
# Out:
#                METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0     2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1     2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2     2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3     2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4     2022-07-17 23:40:00          Sunday  2022      7   17    23      40
# ...                   ...             ...   ...    ...  ...   ...     ...
# 99166 2024-06-05 14:40:00       Wednesday  2024      6    5    14      40
# 99167 2024-06-05 14:50:00       Wednesday  2024      6    5    14      50
# 99168 2024-06-05 15:00:00       Wednesday  2024      6    5    15       0
# 99169 2024-06-05 15:10:00       Wednesday  2024      6    5    15      10
# 99170 2024-06-05 15:20:00       Wednesday  2024      6    5    15      20
#
#        code_day_of_the_week  HOT_FLOW_INST_561-1-1  HOT_FLOW_INST_561-1-2  \
# 0                         6                    NaN                    NaN
# 1                         6                    NaN                    NaN
# 2                         6           0.0000000000           0.0000000000
# 3                         6           0.0000000000           0.0000000000
# 4                         6           0.0014000000           0.0000000000
# ...                     ...                    ...                    ...
# 99166                     2           0.0000000000           0.0000000000
# 99167                     2           0.0000000000           0.0000000000
# 99168                     2           0.0000000000           0.0000000000
# 99169                     2           0.0000000000           0.0000000000
# 99170                     2           0.0000000000           0.0000000000
#
#        ...  HOT_FLOW_INST_563-22-5  HOT_FLOW_INST_563-22-6  \
# 0      ...                     NaN                     NaN
# 1      ...                     NaN                     NaN
# 2      ...            0.0002000000            0.0000000000
# 3      ...            0.0001000000            0.0000000000
# 4      ...            0.0002000000            0.0000000000
# ...    ...                     ...                     ...
# 99166  ...            0.0003000000            0.0000000000
# 99167  ...            0.0001000000                     NaN
# 99168  ...            0.0002000000                     NaN
# 99169  ...            0.0000000000                     NaN
# 99170  ...            0.0000000000            0.0000000000
#
#        HOT_FLOW_INST_563-23-1  HOT_FLOW_INST_563-23-2  HOT_FLOW_INST_563-23-3  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                0.0000000000            0.0001000000            0.0000000000
# 3                0.0000000000            0.0000000000            0.0044000000
# 4                0.0000000000            0.0000000000            0.0000000000
# ...                       ...                     ...                     ...
# 99166            0.0000000000            0.0000000000            0.0000000000
# 99167                     NaN                     NaN                     NaN
# 99168                     NaN                     NaN                     NaN
# 99169                     NaN                     NaN                     NaN
# 99170            0.0000000000            0.0000000000            0.0000000000
#
#        HOT_FLOW_INST_563-23-4  HOT_FLOW_INST_563-24-1  HOT_FLOW_INST_563-24-2  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                0.0002000000            0.0001000000            0.0000000000
# 3                0.0001000000            0.0001000000            0.0000000000
# 4                0.0001000000            0.0000000000            0.0000000000
# ...                       ...                     ...                     ...
# 99166            0.0010000000            0.0000000000            0.0000000000
# 99167                     NaN                     NaN                     NaN
# 99168                     NaN                     NaN                     NaN
# 99169                     NaN                     NaN                     NaN
# 99170            0.0000000000            0.0000000000            0.0000000000
#
#         MEAN_OF_INST     SUM_OF_INST
# 0     296.4285714286 2075.0000000000
# 1      90.6551695652 2085.0689000000
# 2       6.0737657971 2095.4492000000
# 3       6.1201232558 2105.3224000000
# 4       6.1850950292 2115.3025000000
# ...              ...             ...
# 99166   5.9410852273 2091.2620000000
# 99167   8.9789324786 2101.0702000000
# 99168   8.7697662393 2052.1253000000
# 99169  10.1088671569 2062.2089000000
# 99170   5.8531073446 2072.0000000000
#
# [99171 rows x 358 columns]

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Mean of Instantaneous Usage in ' + str_domain, fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'HOT_FLOW_INST_561-1-1',
#        'HOT_FLOW_INST_561-1-2',
#        ...
#        'HOT_FLOW_INST_563-22-5', 'HOT_FLOW_INST_563-22-6',
#        'HOT_FLOW_INST_563-23-1', 'HOT_FLOW_INST_563-23-2',
#        'HOT_FLOW_INST_563-23-3', 'HOT_FLOW_INST_563-23-4',
#        'HOT_FLOW_INST_563-24-1', 'HOT_FLOW_INST_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                   0
# day_of_the_week              0
# YEAR                         0
# MONTH                        0
# DAY                          0
#                           ...
# HOT_FLOW_INST_563-23-4    3460
# HOT_FLOW_INST_563-24-1    3497
# HOT_FLOW_INST_563-24-2    3418
# MEAN_OF_INST                 0
# SUM_OF_INST                  0
# Length: 358, dtype: int64

# %%
## 순시사용량이 음수인 경우 삭제
cnt_minus = 0
list_col_usage = list(df_tmp.columns[8:-2])

for i in range(0, len(df_tmp)) : 
    for col_tar in list_col_usage:
        if df_tmp[col_tar][i] < 0 : 
            print(col_tar, ' ///', df_tmp[col_tar][i])
            print(df_tmp[col_tar][i])
            cnt_minus = cnt_minus + 1
            df_tmp[col_tar][i] = np.nan

print(cnt_minus)

## 순시 사용량의 합계 및 평균 Column을 갱신
df_tmp['MEAN_OF_INST'] = df_tmp[list_col_usage].mean(axis = 1)
df_tmp['SUM_OF_INST'] = df_tmp[list_col_usage].sum(axis = 1)
# Out:
# 0

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage in certain household', fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'HOT_FLOW_INST_561-1-1',
#        'HOT_FLOW_INST_561-1-2',
#        ...
#        'HOT_FLOW_INST_563-22-5', 'HOT_FLOW_INST_563-22-6',
#        'HOT_FLOW_INST_563-23-1', 'HOT_FLOW_INST_563-23-2',
#        'HOT_FLOW_INST_563-23-3', 'HOT_FLOW_INST_563-23-4',
#        'HOT_FLOW_INST_563-24-1', 'HOT_FLOW_INST_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                   0
# day_of_the_week              0
# YEAR                         0
# MONTH                        0
# DAY                          0
#                           ...
# HOT_FLOW_INST_563-23-4    3460
# HOT_FLOW_INST_563-24-1    3497
# HOT_FLOW_INST_563-24-2    3418
# MEAN_OF_INST              1654
# SUM_OF_INST                  0
# Length: 358, dtype: int64

# %%
# df_tmp[['METER_DATE', 'MEAN_OF_INST', 'SUM_OF_INST']].to_csv(str_dir_raw + "KIER_TIME_PERIOD.csv")

# %% [markdown]
# #### 1차 보간 : 평균 대치법 (동일 시간대 전체 세대의 평균 순시 사용량)

# %%
for i in range(0, len(df_tmp)) : df_tmp.loc[i] = df_tmp.loc[i].fillna(df_tmp['MEAN_OF_INST'].loc[i])

## 순시 사용량의 합계 및 평균 Column을 갱신
df_tmp['MEAN_OF_INST'] = df_tmp[list_col_usage].mean(axis = 1)
df_tmp['SUM_OF_INST'] = df_tmp[list_col_usage].sum(axis = 1)

## 마지막값이 0이므로 제외
df_tmp = df_tmp[:-1]

str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp.to_csv(str_dirName_h + str_file)

print(df_tmp.isna().sum())
print(df_tmp.head(5))
plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + 'Usage : 1st - Mean of Inst', fontsize=30)
plt.show()
# Out:
# METER_DATE                   0
# day_of_the_week              0
# YEAR                         0
# MONTH                        0
# DAY                          0
#                           ...
# HOT_FLOW_INST_563-23-4    1654
# HOT_FLOW_INST_563-24-1    1654
# HOT_FLOW_INST_563-24-2    1654
# MEAN_OF_INST              1654
# SUM_OF_INST                  0
# Length: 358, dtype: int64
#            METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0 2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1 2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2 2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3 2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4 2022-07-17 23:40:00          Sunday  2022      7   17    23      40
#
#    code_day_of_the_week  HOT_FLOW_INST_561-1-1  HOT_FLOW_INST_561-1-2  ...  \
# 0                     6           0.0000000000           0.0000000000  ...
# 1                     6           0.0040529412           0.0040529412  ...
# 2                     6           0.0000000000           0.0000000000  ...
# 3                     6           0.0000000000           0.0000000000  ...
# 4                     6           0.0014000000           0.0000000000  ...
#
#    HOT_FLOW_INST_563-22-5  HOT_FLOW_INST_563-22-6  HOT_FLOW_INST_563-23-1  \
# 0            0.0000000000            0.0000000000            0.0000000000
# 1            0.0040529412            0.0040529412            0.0040529412
# 2            0.0002000000            0.0000000000            0.0000000000
# 3            0.0001000000            0.0000000000            0.0000000000
# 4            0.0002000000            0.0000000000            0.0000000000
#
#    HOT_FLOW_INST_563-23-2  HOT_FLOW_INST_563-23-3  HOT_FLOW_INST_563-23-4  \
# 0            0.0000000000            0.0000000000            0.0000000000
# 1            0.0040529412            0.0040529412            0.0040529412
# 2            0.0001000000            0.0000000000            0.0002000000
# 3            0.0000000000            0.0044000000            0.0001000000
# 4            0.0000000000            0.0000000000            0.0001000000
#
#    HOT_FLOW_INST_563-24-1  HOT_FLOW_INST_563-24-2  MEAN_OF_INST  SUM_OF_INST
# 0            0.0000000000            0.0000000000  0.0000000000 0.0000000000
# 1            0.0040529412            0.0040529412  0.0040529412 1.4104235294
# 2            0.0001000000            0.0000000000  0.0013250737 0.4611256637
# 3            0.0001000000            0.0000000000  0.0009538462 0.3319384615
# 4            0.0000000000            0.0000000000  0.0009002976 0.3133035714
#
# [5 rows x 358 columns]

# %%
str_file = 'KIER_' + str_domain + '_INST_02_MeanInterpolated.csv'
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 2차 보간 : 선형 보간

# %% [markdown]
# 모든 값이 NaN이어서 평균 순시 사용량이 계산되지 않은 경우 존재 (ELEC 기준 약 1,372건)
# 해당 부분은 단순 선형 보간을 진행

# %%
## 사용량 컬럼에 대한 2차 보간 진행 (선형 보간)
df_linear_tmp, df_spline_tmp, df_polynomial_tmp, df_cubic_tmp = df_tmp.copy(), df_tmp.copy(), df_tmp.copy(), df_tmp.copy()
df_linear_tmp['MEAN_OF_INST'] = df_linear_tmp['MEAN_OF_INST'].interpolate('linear')
df_spline_tmp['MEAN_OF_INST'] = df_spline_tmp['MEAN_OF_INST'].interpolate('spline', order = 3) ## 3차 다항식 스플라인
# df_polynomial_tmp['MEAN_OF_INST'] = df_polynomial_tmp['MEAN_OF_INST'].interpolate('polynomian')
# df_cubic_tmp['MEAN_OF_INST'] = df_cubic_tmp['MEAN_OF_INST'].interpolate('cubicspline')

str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp.to_csv(str_dirName_h + str_file)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp.to_csv(str_dirName_h + str_file)

# %%
plt.figure(figsize=(20,4))
plt.plot(df_linear_tmp['METER_DATE'], df_linear_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-01 Linear', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.plot(df_spline_tmp['METER_DATE'], df_spline_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-02 Spline', fontsize=30)
plt.show()

# %%
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 이상치 제거 : IQR 방식으로 이상치 완화

# %%
## 여기서 IQR방식으로 전처리
list_col_usage = list(df_tmp.columns[8:-2])
for tar_col in list_col_usage:
    print(tar_col)
    df_h_tmp = df_tmp[['METER_DATE', tar_col]].copy()
    df_h_tmp = com_Prep.del_outlier_Usages(df_h_tmp, tar_col, 10)
    df_tmp[tar_col] = df_h_tmp[tar_col]
# Out:
# HOT_FLOW_INST_561-1-1
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 6918
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 6229
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5476
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5263
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5174
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5086
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5054
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5054
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5054
# ===============  IQR Range ===============
# 0.0009375000000132501
# 0.0003750000000053
# 0.0003750000000053
# nan
# 0.0
# -0.0005625000000079501
# ===============  IQR Range ===============
# cnt_outlier = 5054
# 19443
# HOT_FLOW_INST_561-1-2
# ===============  IQR Range ===============
# 0.00450000000000725
# 0.0018000000000029
# 0.0018000000000029
# nan
# 0.0
# -0.00270000000000435
# ===============  IQR Range ===============
# cnt_outlier = 5046
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 3711
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2755
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2354
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2009
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 1913
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 1851
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 1821
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 1817
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 1810
# 13277
# HOT_FLOW_INST_561-1-3
# ===============  IQR Range ===============
# 0.0035000000001159997
# 0.0014000000000464
# 0.0014000000000464
# nan
# 0.0
# -0.0021000000000696
# ===============  IQR Range ===============
# cnt_outlier = 5535
# ===============  IQR Range ===============
# 0.0030000000000995003
# 0.0012000000000398
# 0.0012000000000398
# nan
# 0.0
# -0.0018000000000597
# ===============  IQR Range ===============
# cnt_outlier = 4353
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 3730
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 3414
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 3101
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 2965
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 2884
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 2792
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 2775
# ===============  IQR Range ===============
# 0.0029999999999572504
# 0.0011999999999829
# 0.0011999999999829
# nan
# 0.0
# -0.0017999999999743501
# ===============  IQR Range ===============
# cnt_outlier = 2758
# 18527
# HOT_FLOW_INST_561-1-4
# ===============  IQR Range ===============
# 0.003499999999974
# 0.0013999999999896
# 0.0013999999999896
# nan
# 0.0
# -0.0020999999999844
# ===============  IQR Range ===============
# cnt_outlier = 5230
# ===============  IQR Range ===============
# 0.002835488814584738
# 0.0011341955258338953
# 0.0011341955258338953
# nan
# 0.0
# -0.0017012932887508429
# ===============  IQR Range ===============
# cnt_outlier = 3861
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 3108
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 2899
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 2755
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 2714
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 2700
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 2698
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 2696
# ===============  IQR Range ===============
# 0.00275000000002
# 0.001100000000008
# 0.001100000000008
# nan
# 0.0
# -0.001650000000012
# ===============  IQR Range ===============
# cnt_outlier = 2696
# 12315
# HOT_FLOW_INST_561-2-1
# ===============  IQR Range ===============
# 0.0031591644830233022
# 0.001263665793209321
# 0.001263665793209321
# nan
# 0.0
# -0.0018954986898139813
# ===============  IQR Range ===============
# cnt_outlier = 5645
# ===============  IQR Range ===============
# 0.0025000000000117498
# 0.0010000000000047
# 0.0010000000000047
# nan
# 0.0
# -0.00150000000000705
# ===============  IQR Range ===============
# cnt_outlier = 4331
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3636
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3395
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3230
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3174
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3160
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3146
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3142
# ===============  IQR Range ===============
# 0.00249999999994075
# 0.0009999999999763
# 0.0009999999999763
# nan
# 0.0
# -0.00149999999996445
# ===============  IQR Range ===============
# cnt_outlier = 3140
# 15777
# HOT_FLOW_INST_561-2-2
# ===============  IQR Range ===============
# 0.002081984256983603
# 0.0008327937027934414
# 0.0008327937027934414
# nan
# 0.0
# -0.001249190554190162
# ===============  IQR Range ===============
# cnt_outlier = 4349
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3332
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3121
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3062
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3055
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3052
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3052
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3052
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3052
# ===============  IQR Range ===============
# 0.00150000000001425
# 0.0006000000000057
# 0.0006000000000057
# nan
# 0.0
# -0.00090000000000855
# ===============  IQR Range ===============
# cnt_outlier = 3052
# 6982
# HOT_FLOW_INST_561-2-3
# ===============  IQR Range ===============
# 0.00424999999999875
# 0.0016999999999995
# 0.0016999999999995
# nan
# 0.0
# -0.00254999999999925
# ===============  IQR Range ===============
# cnt_outlier = 4520
# ===============  IQR Range ===============
# 0.00325000000003675
# 0.0013000000000147
# 0.0013000000000147
# nan
# 0.0
# -0.00195000000002205
# ===============  IQR Range ===============
# cnt_outlier = 3415
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2919
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2799
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2758
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2745
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2744
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2743
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2743
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2743
# 8193
# HOT_FLOW_INST_561-2-4
# ===============  IQR Range ===============
# 0.00324999999996575
# 0.0012999999999863
# 0.0012999999999863
# nan
# 0.0
# -0.00194999999997945
# ===============  IQR Range ===============
# cnt_outlier = 4889
# ===============  IQR Range ===============
# 0.002712780201269125
# 0.00108511208050765
# 0.00108511208050765
# nan
# 0.0
# -0.0016276681207614751
# ===============  IQR Range ===============
# cnt_outlier = 3349
# ===============  IQR Range ===============
# 0.0025625000000006875
# 0.001025000000000275
# 0.001025000000000275
# nan
# 0.0
# -0.0015375000000004127
# ===============  IQR Range ===============
# cnt_outlier = 2979
# ===============  IQR Range ===============
# 0.0025624999999984376
# 0.001024999999999375
# 0.001024999999999375
# nan
# 0.0
# -0.0015374999999990624
# ===============  IQR Range ===============
# cnt_outlier = 2784
# ===============  IQR Range ===============
# 0.0025624999999984376
# 0.001024999999999375
# 0.001024999999999375
# nan
# 0.0
# -0.0015374999999990624
# ===============  IQR Range ===============
# cnt_outlier = 2656
# ===============  IQR Range ===============
# 0.0025624999999984376
# 0.001024999999999375
# 0.001024999999999375
# nan
# 0.0
# -0.0015374999999990624
# ===============  IQR Range ===============
# cnt_outlier = 2629
# ===============  IQR Range ===============
# 0.0025624999999984376
# 0.001024999999999375
# 0.001024999999999375
# nan
# 0.0
# -0.0015374999999990624
# ===============  IQR Range ===============
# cnt_outlier = 2623
# ===============  IQR Range ===============
# 0.0025624999999984376
# 0.001024999999999375
# 0.001024999999999375
# nan
# 0.0
# -0.0015374999999990624
# ===============  IQR Range ===============
# cnt_outlier = 2622
# ===============  IQR Range ===============
# 0.0025624999999984376
# 0.001024999999999375
# 0.001024999999999375
# nan
# 0.0
# -0.0015374999999990624
# ===============  IQR Range ===============
# cnt_outlier = 2621
# ===============  IQR Range ===============
# 0.0025624999999984376
# 0.001024999999999375
# 0.001024999999999375
# nan
# 0.0
# -0.0015374999999990624
# ===============  IQR Range ===============
# cnt_outlier = 2621
# 10008
# HOT_FLOW_INST_561-3-1
# ===============  IQR Range ===============
# 0.00624999999999425
# 0.0024999999999977
# 0.0024999999999977
# nan
# 0.0
# -0.0037499999999965495
# ===============  IQR Range ===============
# cnt_outlier = 3592
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 2340
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1893
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1769
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1732
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1722
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1721
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1721
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1721
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 1721
# 6708
# HOT_FLOW_INST_561-3-2
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 8528
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7545
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7541
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7539
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7539
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7539
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7539
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7539
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7539
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7539
# 76387
# HOT_FLOW_INST_561-3-3
# ===============  IQR Range ===============
# 0.00324999999996575
# 0.0012999999999863
# 0.0012999999999863
# nan
# 0.0
# -0.00194999999997945
# ===============  IQR Range ===============
# cnt_outlier = 5687
# ===============  IQR Range ===============
# 0.0023170173068255513
# 0.0009268069227302205
# 0.0009268069227302205
# nan
# 0.0
# -0.0013902103840953309
# ===============  IQR Range ===============
# cnt_outlier = 4695
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 4251
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 4087
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 3991
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 3982
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 3972
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 3967
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 3967
# ===============  IQR Range ===============
# 0.0023075296435318754
# 0.0009230118574127501
# 0.0009230118574127501
# nan
# 0.0
# -0.0013845177861191251
# ===============  IQR Range ===============
# cnt_outlier = 3967
# 14130
# HOT_FLOW_INST_561-3-4
# ===============  IQR Range ===============
# 0.00374999999998225
# 0.0014999999999929
# 0.0014999999999929
# nan
# 0.0
# -0.00224999999998935
# ===============  IQR Range ===============
# cnt_outlier = 5592
# ===============  IQR Range ===============
# 0.0030000000000285
# 0.0012000000000114
# 0.0012000000000114
# nan
# 0.0
# -0.0018000000000171
# ===============  IQR Range ===============
# cnt_outlier = 4127
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 3413
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 3143
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 3008
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 2973
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 2961
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 2957
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 2954
# ===============  IQR Range ===============
# 0.0029999999999930005
# 0.0011999999999972
# 0.0011999999999972
# nan
# 0.0
# -0.0017999999999958002
# ===============  IQR Range ===============
# cnt_outlier = 2953
# 14203
# HOT_FLOW_INST_561-4-1
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7150
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7080
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7076
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7074
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7073
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7073
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7073
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7073
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7073
# ===============  IQR Range ===============
# 0.0
# 0.0
# 0.0
# nan
# 0.0
# 0.0
# ===============  IQR Range ===============
# cnt_outlier = 7073
# 70818
# HOT_FLOW_INST_561-4-2
# ===============  IQR Range ===============
# 0.007749999999973
# 0.0030999999999892
# 0.0030999999999892
# nan
# 0.0
# -0.0046499999999838
# ===============  IQR Range ===============
# cnt_outlier = 3956
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2768
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2381
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2264
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2237
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2229
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2227
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2226
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2225
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2225
# 9016
# HOT_FLOW_INST_561-4-3
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 8838
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 6516
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 4572
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 3684
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 3190
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 2800
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 2412
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 2139
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 1954
# ===============  IQR Range ===============
# 0.00025000000000825
# 0.0001000000000033
# 0.0001000000000033
# nan
# 0.0
# -0.00015000000000495
# ===============  IQR Range ===============
# cnt_outlier = 1797
# 37902
# HOT_FLOW_INST_561-4-4
# ===============  IQR Range ===============
# 0.00424999999999875
# 0.0016999999999995
# 0.0016999999999995
# nan
# 0.0
# -0.00254999999999925
# ===============  IQR Range ===============
# cnt_outlier = 4547
# ===============  IQR Range ===============
# 0.0035000000001159997
# 0.0014000000000464
# 0.0014000000000464
# nan
# 0.0
# -0.0021000000000696
# ===============  IQR Range ===============
# cnt_outlier = 2999
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2458
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2303
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2211
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2188
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2178
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2177
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2175
# ===============  IQR Range ===============
# 0.003500000000045
# 0.001400000000018
# 0.001400000000018
# nan
# 0.0
# -0.002100000000027
# ===============  IQR Range ===============
# cnt_outlier = 2175
# 8447
# HOT_FLOW_INST_561-5-1
# ===============  IQR Range ===============
# 0.00799999999998125
# 0.0031999999999925
# 0.0031999999999925
# nan
# 0.0
# -0.00479999999998875
# ===============  IQR Range ===============
# cnt_outlier = 3750
# ===============  IQR Range ===============
# 0.006815067427389437
# 0.002726026970955775
# 0.002726026970955775
# nan
# 0.0
# -0.004089040456433662
# ===============  IQR Range ===============
# cnt_outlier = 2331
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 2050
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 1870
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 1813
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 1796
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 1793
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 1793
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 1793
# ===============  IQR Range ===============
# 0.006750000000010751
# 0.0027000000000043
# 0.0027000000000043
# nan
# 0.0
# -0.00405000000000645
# ===============  IQR Range ===============
# cnt_outlier = 1793
# 6673
# HOT_FLOW_INST_561-5-2
# ===============  IQR Range ===============
# 0.0065000000000025
# 0.002600000000001
# 0.002600000000001
# nan
# 0.0
# -0.0039000000000015
# ===============  IQR Range ===============
# cnt_outlier = 3249
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 2030
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1597
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1310
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1168
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1108
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1083
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1073
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1068
# ===============  IQR Range ===============
# 0.006000000000057
# 0.0024000000000228
# 0.0024000000000228
# nan
# 0.0
# -0.0036000000000342
# ===============  IQR Range ===============
# cnt_outlier = 1066
# 7476
# HOT_FLOW_INST_561-5-3
# ===============  IQR Range ===============
# 0.0037499999999112497
# 0.0014999999999645
# 0.0014999999999645
# nan
# 0.0
# -0.00224999999994675
# ===============  IQR Range ===============
# cnt_outlier = 6148
# ===============  IQR Range ===============
# 0.0026249999999983123
# 0.001049999999999325
# 0.001049999999999325
# nan
# 0.0
# -0.0015749999999989874
# ===============  IQR Range ===============
# cnt_outlier = 4419
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 4087
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 3963
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 3943
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 3941
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 3941
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 3941
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 3941
# ===============  IQR Range ===============
# 0.0025775585347429476
# 0.0010310234138971792
# 0.0010310234138971792
# nan
# 0.0
# -0.0015465351208457686
# ===============  IQR Range ===============
# cnt_outlier = 3941
# 10706
# HOT_FLOW_INST_561-5-4
# ===============  IQR Range ===============
# 0.035250000000104253
# 0.0141000000000417
# 0.0141000000000417
# nan
# 0.0
# -0.02115000000006255
# ===============  IQR Range ===============
# cnt_outlier = 2211
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 969
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 714
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 647
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 631
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 629
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 627
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 627
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 627
# ===============  IQR Range ===============
# 0.03399999999999175
# 0.0135999999999967
# 0.0135999999999967
# nan
# 0.0
# -0.02039999999999505
# ===============  IQR Range ===============
# cnt_outlier = 627
# 3270
# HOT_FLOW_INST_561-6-1
# ===============  IQR Range ===============
# 0.0026249999999804997
# 0.0010499999999922
# 0.0010499999999922
# nan
# 0.0
# -0.0015749999999883
# ===============  IQR Range ===============
# cnt_outlier = 5106
# ===============  IQR Range ===============
# 0.002000000000059175
# 0.00080000000002367
# 0.00080000000002367
# nan
# 0.0
# -0.0012000000000355051
# ===============  IQR Range ===============
# cnt_outlier = 4037
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 3358
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 3121
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 2968
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 2925
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 2914
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 2908
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 2908
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 2908
# 11404
# HOT_FLOW_INST_561-6-2
# ===============  IQR Range ===============
# 0.00412499999995915
# 0.00164999999998366
# 0.00164999999998366
# nan
# 0.0
# -0.00247499999997549
# ===============  IQR Range ===============
# cnt_outlier = 4868
# ===============  IQR Range ===============
# 0.0033749999999972006
# 0.00134999999999888
# 0.00134999999999888
# nan
# 0.0
# -0.0020249999999983202
# ===============  IQR Range ===============
# cnt_outlier = 3310
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2812
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2623
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2587
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2573
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2573
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2573
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2573
# ===============  IQR Range ===============
# 0.0033125000000033752
# 0.00132500000000135
# 0.00132500000000135
# nan
# 0.0
# -0.001987500000002025
# ===============  IQR Range ===============
# cnt_outlier = 2573
# 9040
# HOT_FLOW_INST_561-6-3
# ===============  IQR Range ===============
# 0.0052499999999965005
# 0.0020999999999986
# 0.0020999999999986
# nan
# 0.0
# -0.0031499999999979
# ===============  IQR Range ===============
# cnt_outlier = 3698
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 2292
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1881
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1763
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1731
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1720
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1717
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1717
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1717
# ===============  IQR Range ===============
# 0.0047500000000155
# 0.0019000000000062
# 0.0019000000000062
# nan
# 0.0
# -0.0028500000000093
# ===============  IQR Range ===============
# cnt_outlier = 1717
# 8925
# HOT_FLOW_INST_561-6-4
# ===============  IQR Range ===============
# 0.007749999999973
# 0.0030999999999892
# 0.0030999999999892
# nan
# 0.0
# -0.0046499999999838
# ===============  IQR Range ===============
# cnt_outlier = 4617
# ===============  IQR Range ===============
# 0.0061249999999545
# 0.0024499999999818
# 0.0024499999999818
# nan
# 0.0
# -0.0036749999999727
# ===============  IQR Range ===============
# cnt_outlier = 3583
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3319
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3088
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3048
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3032
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3031
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3031
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3031
# ===============  IQR Range ===============
# 0.006062500000005749
# 0.0024250000000023
# 0.0024250000000023
# nan
# 0.0
# -0.0036375000000034496
# ===============  IQR Range ===============
# cnt_outlier = 3031
# 9174
# HOT_FLOW_INST_561-7-1
# ===============  IQR Range ===============
# 0.023750000000006752
# 0.0095000000000027
# 0.0095000000000027
# nan
# 0.0
# -0.014250000000004051
# ===============  IQR Range ===============
# cnt_outlier = 2304
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ===============  IQR Range ===============
# cnt_outlier = 999
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ===============  IQR Range ===============
# cnt_outlier = 877
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ===============  IQR Range ===============
# cnt_outlier = 845
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ===============  IQR Range ===============
# cnt_outlier = 840
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ===============  IQR Range ===============
# cnt_outlier = 840
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ===============  IQR Range ===============
# cnt_outlier = 840
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ===============  IQR Range ===============
# cnt_outlier = 840
# ===============  IQR Range ===============
# 0.022000000000019754
# 0.0088000000000079
# 0.0088000000000079
# nan
# 0.0
# -0.013200000000011852
# ...
# 0.0002999999999957
# 0.0002999999999957
# nan
# 0.0
# -0.00044999999999354996
# ===============  IQR Range ===============
# cnt_outlier = 7589
# ===============  IQR Range ===============
# 0.0003749999999768602
# 0.00014999999999074407
# 0.00014999999999074407
# nan
# 0.0
# -0.0002249999999861161
# ===============  IQR Range ===============
# cnt_outlier = 7613
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 7058
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 6694
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 6694
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 6694
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 6694
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 6694
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 6694
# ===============  IQR Range ===============
# 0.00037499999997675
# 0.0001499999999907
# 0.0001499999999907
# nan
# 0.0
# -0.00022499999998605
# ===============  IQR Range ===============
# cnt_outlier = 6694
# 26289
# HOT_FLOW_INST_561-10-4
# ===============  IQR Range ===============
# 0.0055000000000402505
# 0.0022000000000161
# 0.0022000000000161
# nan
# 0.0
# -0.00330000000002415
# ===============  IQR Range ===============
# cnt_outlier = 3703
# ===============  IQR Range ===============
# 0.0049062499999940005
# 0.0019624999999976003
# 0.0019624999999976003
# nan
# 0.0
# -0.0029437499999964006
# ===============  IQR Range ===============
# cnt_outlier = 2240
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1999
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1891
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1856
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1853
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1853
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1853
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1853
# ===============  IQR Range ===============
# 0.00489765624999975
# 0.0019590624999999
# 0.0019590624999999
# nan
# 0.0
# -0.00293859374999985
# ===============  IQR Range ===============
# cnt_outlier = 1853
# 7196
# HOT_FLOW_INST_561-11-1
# ===============  IQR Range ===============
# 0.00450000000000725
# 0.0018000000000029
# 0.0018000000000029
# nan
# 0.0
# -0.00270000000000435
# ===============  IQR Range ===============
# cnt_outlier = 4756
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 3429
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2911
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2619
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2472
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2372
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2336
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2322
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2319
# ===============  IQR Range ===============
# 0.0039999999999905
# 0.0015999999999962
# 0.0015999999999962
# nan
# 0.0
# -0.0023999999999943
# ===============  IQR Range ===============
# cnt_outlier = 2315
# 14946
# HOT_FLOW_INST_561-11-2
# ===============  IQR Range ===============
# 0.00325000000000125
# 0.0013000000000005
# 0.0013000000000005
# nan
# 0.0
# -0.00195000000000075
# ===============  IQR Range ===============
# cnt_outlier = 4898
# ===============  IQR Range ===============
# 0.0026992949007258286
# 0.0010797179602903314
# 0.0010797179602903314
# nan
# 0.0
# -0.001619576940435497
# ===============  IQR Range ===============
# cnt_outlier = 3787
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 3323
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 3094
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 3018
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 2995
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 2982
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 2976
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 2974
# ===============  IQR Range ===============
# 0.002656250000008125
# 0.00106250000000325
# 0.00106250000000325
# nan
# 0.0
# -0.0015937500000048751
# ===============  IQR Range ===============
# cnt_outlier = 2974
# 12418
# HOT_FLOW_INST_561-11-3
# ===============  IQR Range ===============
# 0.00799999999998125
# 0.0031999999999925
# 0.0031999999999925
# nan
# 0.0
# -0.00479999999998875
# ===============  IQR Range ===============
# cnt_outlier = 2395
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1618
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1496
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1467
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1462
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1462
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1462
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1462
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1462
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 1462
# 3676
# HOT_FLOW_INST_561-11-4
# ===============  IQR Range ===============
# 0.007000000000019
# 0.0028000000000076
# 0.0028000000000076
# nan
# 0.0
# -0.0042000000000113995
# ===============  IQR Range ===============
# cnt_outlier = 4671
# ===============  IQR Range ===============
# 0.00600000000005675
# 0.0024000000000227
# 0.0024000000000227
# nan
# 0.0
# -0.00360000000003405
# ===============  IQR Range ===============
# cnt_outlier = 3353
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2717
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2444
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2402
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2391
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2388
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2387
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2387
# ===============  IQR Range ===============
# 0.005999999999986001
# 0.0023999999999944
# 0.0023999999999944
# nan
# 0.0
# -0.0035999999999916004
# ===============  IQR Range ===============
# cnt_outlier = 2387
# 9746
# HOT_FLOW_INST_561-12-1
# ===============  IQR Range ===============
# 0.00199999999999525
# 0.0007999999999981
# 0.0007999999999981
# nan
# 0.0
# -0.00119999999999715
# ===============  IQR Range ===============
# cnt_outlier = 5786
# ===============  IQR Range ===============
# 0.00174999999998675
# 0.0006999999999947
# 0.0006999999999947
# nan
# 0.0
# -0.00104999999999205
# ===============  IQR Range ===============
# cnt_outlier = 4271
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3847
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3545
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3379
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3310
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3267
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3250
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3241
# ===============  IQR Range ===============
# 0.0016250000000182499
# 0.0006500000000073
# 0.0006500000000073
# nan
# 0.0
# -0.00097500000001095
# ===============  IQR Range ===============
# cnt_outlier = 3240
# 18349
# HOT_FLOW_INST_561-12-2
# ===============  IQR Range ===============
# 0.001874999999991
# 0.0007499999999964
# 0.0007499999999964
# nan
# 0.0
# -0.0011249999999946
# ===============  IQR Range ===============
# cnt_outlier = 5313
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 6
#       4 print(tar_col)
#       5 df_h_tmp = df_tmp[['METER_DATE', tar_col]].copy()
# ----> 6 df_h_tmp = com_Prep.del_outlier_Usages(df_h_tmp, tar_col, 10)
#       7 df_tmp[tar_col] = df_h_tmp[tar_col]
#
# File d:\WS_DataScience\Src_Dev_Common\DEV_Common_Data_Preprocessing.py:91, in del_outlier_Usages(df_tar, col_tar, int_cnt_process)
#      87 outlier_usage = df_tar[col_tar].iloc[row]
#      88 if ((outlier_usage > (q3_df_raw + 1.5 * iqr_df_raw)) or (outlier_usage < q1_df_raw - 1.5 * iqr_df_raw)):
#      89     # print(outlier_usage)
#      90     ## Linear Regression
# ---> 91     df_tar[col_tar].iloc[row] = (df_tar[col_tar].iloc[row - 1] + df_tar[col_tar].iloc[row + 1]) / 2
#      92     cnt_outlier = cnt_outlier + 1
#      93 if outlier_usage < 0:
#      94     # print(outlier_usage)
#      95     ## 사용량이 음수일 수 없으므로 0으로 치환
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp.to_csv(str_dirName_h + str_file)

# %%
str_file = 'KIER_' + str_domain + '_INST_01_10min.csv'
df_tmp_00 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp_01 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_tmp_0201 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_tmp_0202 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp_03 = pd.read_csv(str_dirName_h + str_file, index_col = 0)

period_tmp = df_tmp_0201['METER_DATE']
period_tmp

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_01[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
df_tmp_01.columns

# %%
tar_col = 'SUM_OF_INST'

fig, ax1 = plt.subplots(figsize = (30,5))
usage_A = df_tmp_01[tar_col].copy()
usage_B = df_tmp_0201[tar_col].copy()
ax1.plot(period_tmp, usage_A, color = 'red')
ax1.plot(period_tmp, usage_B, color = 'red')

# %%
list_tar_col = df_tmp.columns[1:]
for tar_col in list_tar_col:
    print(tar_col)
    df_tmp[tar_col] = com_Prep.del_outlier_Usages(df_tmp, tar_col)

# %%
df_tmp

# %%
## 합계 순시량 다시 계산 
list_col = df_tmp.columns[7:-2]

df_kier_Calc = df_tmp[list_col]
df_kier_extract = df_tmp
df_kier_extract['SUM_OF_INST'] = df_kier_Calc.sum(axis = 1)

str_file = 'KIER_' + str_domain + '_INST_10MIN_MEANINTERPOLATED.csv'       
df_kier_extract.to_csv(str_dirName_h + str_file)

# %%
df_tmp.info()

# %%
# pd.set_option("display.max_columns", 999)
# # pd.set_option("display.max_seq_items", None)
# pd.set_option("display.max_rows", None)

# df_tmp.isnull().sum()

# %%
df_kier_extract
