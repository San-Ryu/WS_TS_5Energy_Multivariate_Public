# %% [markdown]
# ### Code Hist.

# %% [markdown]
# - CODE : KIER Data_전처리 (결측 제거)
# - DATE
# &ensp; 2023-10-12 Created
# &ensp; 2023-11-21 Code 최신화
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 기존 모듈화된 함수 사용
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 기존 KIER 변환 관련 코드를 모두 통합
# &ensp; 2024-01-19 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선, Raw로 저장
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) HOT (온수 사용량) 전용 Code 작성
# &ensp; 2024-01-30 Code 개선 후 백업
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (미완)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 백업 후 코드 최적화
# &ensp; 2024-02-05 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 순시사용량 보간 코드 작성 (Method 02 1차 완성)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; A. 순시값을 보간하는 방법은 3가지로 제안 가능
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) 단순 Linear 보간 (앞뒤 평균치)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; [Not Recommanded] 매우 긴 구간의 결측을 커버하기에 부적절
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; (양 끝이 0인 경우, 해당 구간을 제대로 보간 불가)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b) 직전 주 동일시간 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 직전 주의 데이터가 존재하지 않을 경우 보간 불가
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;(데이터 상 첫 주 케이스 등)
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1) 해당 동일년도/동일월/동일요일/동일시간의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 나쁘지 않은 방법이지만, 과정이 조금 복잡해짐
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-2) 해당 동일 일시의 348 세대의 평균 사용량
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; c-1보다 기대되는 적용 데이터량이 많음.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 한파/폭염/우천 등 예외적인 날씨에 따른 사용량 변동의 영향이 적어질 것으로 판단.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; B. 순시값을 보간하기 전 단계
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; a) Resample시, 시간이 NaN인 구간은 그 간격에서 비어있는 행이다.
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-1) 시점 n의 적산량이 0이고 시점 n + 1의 적산량이 정상 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; b-2) 시점 n의 순시량이 음수인 경우
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 해당 행의 순시값을 NaN으로 처리
# &ensp; 2024-02-07 Code 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 결측 처리 부분 정확도 개선
# &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) Raw Data 상 결측치가 15% 이상일 경우, 해당 데이터를 사용하지 않는 부분 추가
#
# - DESC
# &ensp; : int_Domain 코드의 변경에 따라,
# &emsp; KIER 에너지 사용량 데이터를 동/층/세대별로 분리
#
# &emsp; 또한, Raw Data과 세대별 데이터 추출 단계에서,
# &emsp; 아래와 같은 작업 진행
#
# &emsp; [수행 작업]
# &emsp; 1) Date Column에 대한 유효성 검사 및 이상 Data에 대한 소거
# &emsp; 1-1) Datetime 유효성 확인
# &emsp; 1-2) Datetime 이상치 제거
# &emsp; 2) HOUSE_ID_HO의 해시값을 int_house_num으로 변경 (용량 절감 목적)
# - DATA
# 1) Period :
# 2) Interval :
# - Link
# &ensp; :

# %% [markdown]
# ## 01. Code

# %% [markdown]
# ### 01-01. Init

# %% [markdown]
# #### 01-01-01. Init_Module Import

# %% [markdown]
# #### Module import

# %%
#region Basic_Import
## Basic
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.path.dirname(os.path.abspath('__file__'))
import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('__file__'))))

import warnings
warnings.filterwarnings('ignore')

import numpy as np, pandas as pd
from pandas import DataFrame, Series

import math, random

## Datetime
import time
import datetime as dt
from datetime import datetime, date, timedelta

import glob
from glob import glob
import requests
import json

## 시각화
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from scipy import stats

# K-Means 알고리즘
from sklearn.cluster import KMeans, MiniBatchKMeans

# CLustering 알고리즘의 성능 평가 측도
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score, adjusted_rand_score, silhouette_score, rand_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics.cluster import contingency_matrix

## 정규화
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import metrics

import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus

from selenium import webdriver
from selenium.webdriver.chrome.service import Service

from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

from tqdm.notebook import tqdm
import tqdm

## Init.
pd.options.display.float_format = '{:.10f}'.format
#endregion Basic_Import

# %%
## Import_DL
str_tar = "tf"
## For Torch
if str_tar == "torch":
    import torch
    import torch.nn as nn
    from torch.nn.utils import weight_norm
    print("Torch Imported")
## For TF
elif str_tar == "tf":
    import tensorflow as tf
    import tensorflow_addons as tfa
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    from keras.models import Sequential, load_model
    from keras_flops import get_flops
    print("Tensorflow Imported")
else:
    print("Error : Cannot be used except for Keywords")
    print(" : torch / tf")
# Out:
# Tensorflow Imported

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    print('Using GPU')
    tf.config.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
else : 
  print('Using CPU')
# Out:
# Using GPU

# %%
## Import_Local
from Src_Dev_Common import DEV_Common_Data_Datetime as com_date
# from Src_Dev_Common import DEV_KASI_Holiday as com_Holi
# from Src_Dev_Common import DEV_Common_Data_Analysis as com_Analysis
from Src_Dev_Common import DEV_Common_Data_Preprocessing as com_Prep
# from Src_Dev_Common import DEV_Common_Model as com_Model
# from Src_Dev_Common import DEV_Common_Data_Visualization as com_Visual
# from Src_Dev_Common import DEV_KMA_Weather_ASOS as com_ASOS
# from Src_Dev_Common import DEV_KDHC_Usage as com_KDHC
# from Src_Dev_Common import DEV_KIER_Usage as com_KIER

# %% [markdown]
# ### 01-01-02. Config (Directory, Params)

# %%
## Init_config
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = "1"
random.seed(SEED)

# %%
## Define Todate str
str_now_ymd = pd.datetime.now().date()
str_now_y, str_now_m, str_now_d = pd.datetime.now().year, pd.datetime.now().month, pd.datetime.now().day
str_now_hr, str_now_min = pd.datetime.now().hour, pd.datetime.now().minute

print(pd.datetime.now())
print(str(str_now_y) + " / " + str(str_now_m)  + " / " + str(str_now_d))
print(str(str_now_hr) + " : " + str(str_now_min))
# Out:
# 2024-07-04 10:54:51.268547
# 2024 / 7 / 4
# 10 : 54

# %%
## Dict_Domain
dict_domain = {0:"ELEC", 1:"HEAT", 2:"WATER", 3:"HOT_HEAT", 4:"HOT_FLOW", 5:"GAS"} ## GAS는 사용하지 않음.
int_domain = 2
str_domain = str(dict_domain[int_domain])

dict_col_accu = {0 : "ACTUAL_ACCU_EFF" ## ELEC
                 , 1 : "ACCU_HEAT" ## HEAT
                 , 2 : "ACCU_FLOW" ## WATER
                 , 3 : "ACCU_HEAT" ## HOT 열량
                 , 4 : "ACCU_FLOW" ## HOT 유량
                 , 5 : "ACCU_FLOW" ## GAS
                 }
str_col_accu = str(str_domain + "_" + str(dict_col_accu[int_domain]))

dict_col_inst = {0 : "INST_EFF" ## ELEC_INST_EFF
                , 1 : "INST_HEAT" ## HEAT_INST_HEAT
                , 2 : "INST_FLOW" ## WATER_INST_FLOW
                , 3 : "INST" ## HOT_HEAT_INST
                , 4 : "INST" ## HOT_FLOW_INST
                , 5 : "INST_FLOW" ## GAS_INST_FLOW
                } 
str_col_inst = str(str_domain + "_" + str(dict_col_inst[int_domain]))

## Directory Root
str_dirData = "../data/data_Energy_KIER/"
str_dir_raw = '../data/data_Energy_KIER/KIER_0_Raw/'
str_dirName_bld = '../data/data_Energy_KIER/KIER_1_BLD/'
str_dirName_h = '../data/data_Energy_KIER/KIER_2_H_' + str_domain + '/'

## File
str_fileRaw = str('KIER_RAW_' + str_domain + '_2024-06-07.csv')
str_fileRaw_hList = str('KIER_hList_Common.csv') 

print(str(os.listdir(str_dirData)) + "\n")
print(os.listdir(str_dirName_h))
# Out:
# ['.ipynb_checkpoints', 'BS_CONFIGURATION_202309251452.csv', 'DATE_1M_2023-10-20.csv', 'KIER 전처리 현황_2024-06-25.xlsx', 'KIER_0_Raw', 'KIER_1_BLD', 'KIER_2_H_ELEC', 'KIER_2_H_GAS', 'KIER_2_H_HEAT', 'KIER_2_H_HOT_FLOW', 'KIER_2_H_HOT_HEAT', 'KIER_2_H_WATER', 'KIER_ASOS_WEATHER_DAILY_202309251521.csv', 'KIER_ASOS_WEATHER_HOUR_202309251521.csv', 'KIER_DATA_OLD', 'KIER_ETC', 'KIER_hList_Comparison_2024-06-26.xlsx', 'KIER_List_Table_Column_2023-09-25.xlsx', 'KIER_Query_2023-09-25.txt', 'KMA_ASOS_119_2010_2023_1st_to CSV.csv', '[IITP] 데이터 테이블 정리 (공유 원본).docx']
#
# ['KIER_WATER_561-1-1_ACCU_01_Raw.csv', 'KIER_WATER_561-1-1_INST_01_10min.csv', 'KIER_WATER_561-1-2_ACCU_01_Raw.csv', 'KIER_WATER_561-1-2_INST_01_10min.csv', 'KIER_WATER_561-1-3_ACCU_01_Raw.csv', 'KIER_WATER_561-1-3_INST_01_10min.csv', 'KIER_WATER_561-1-4_ACCU_01_Raw.csv', 'KIER_WATER_561-1-4_INST_01_10min.csv', 'KIER_WATER_561-10-1_ACCU_01_Raw.csv', 'KIER_WATER_561-10-1_INST_01_10min.csv', 'KIER_WATER_561-10-2_ACCU_01_Raw.csv', 'KIER_WATER_561-10-2_INST_01_10min.csv', 'KIER_WATER_561-10-3_ACCU_01_Raw.csv', 'KIER_WATER_561-10-3_INST_01_10min.csv', 'KIER_WATER_561-10-4_ACCU_01_Raw.csv', 'KIER_WATER_561-10-4_INST_01_10min.csv', 'KIER_WATER_561-11-1_ACCU_01_Raw.csv', 'KIER_WATER_561-11-1_INST_01_10min.csv', 'KIER_WATER_561-11-2_ACCU_01_Raw.csv', 'KIER_WATER_561-11-2_INST_01_10min.csv', 'KIER_WATER_561-11-3_ACCU_01_Raw.csv', 'KIER_WATER_561-11-3_INST_01_10min.csv', 'KIER_WATER_561-11-4_ACCU_01_Raw.csv', 'KIER_WATER_561-11-4_INST_01_10min.csv', 'KIER_WATER_561-12-1_ACCU_01_Raw.csv', 'KIER_WATER_561-12-1_INST_01_10min.csv', 'KIER_WATER_561-12-2_ACCU_01_Raw.csv', 'KIER_WATER_561-12-2_INST_01_10min.csv', 'KIER_WATER_561-12-3_ACCU_01_Raw.csv', 'KIER_WATER_561-12-3_INST_01_10min.csv', 'KIER_WATER_561-12-4_ACCU_01_Raw.csv', 'KIER_WATER_561-12-4_INST_01_10min.csv', 'KIER_WATER_561-13-1_ACCU_01_Raw.csv', 'KIER_WATER_561-13-1_INST_01_10min.csv', 'KIER_WATER_561-13-2_ACCU_01_Raw.csv', 'KIER_WATER_561-13-2_INST_01_10min.csv', 'KIER_WATER_561-13-3_ACCU_01_Raw.csv', 'KIER_WATER_561-13-3_INST_01_10min.csv', 'KIER_WATER_561-13-4_ACCU_01_Raw.csv', 'KIER_WATER_561-13-4_INST_01_10min.csv', 'KIER_WATER_561-14-1_ACCU_01_Raw.csv', 'KIER_WATER_561-14-1_INST_01_10min.csv', 'KIER_WATER_561-14-2_ACCU_01_Raw.csv', 'KIER_WATER_561-14-2_INST_01_10min.csv', 'KIER_WATER_561-14-3_ACCU_01_Raw.csv', 'KIER_WATER_561-14-3_INST_01_10min.csv', 'KIER_WATER_561-14-4_ACCU_01_Raw.csv', 'KIER_WATER_561-14-4_INST_01_10min.csv', 'KIER_WATER_561-15-1_ACCU_01_Raw.csv', 'KIER_WATER_561-15-1_INST_01_10min.csv', 'KIER_WATER_561-15-2_ACCU_01_Raw.csv', 'KIER_WATER_561-15-2_INST_01_10min.csv', 'KIER_WATER_561-15-3_ACCU_01_Raw.csv', 'KIER_WATER_561-15-3_INST_01_10min.csv', 'KIER_WATER_561-15-4_ACCU_01_Raw.csv', 'KIER_WATER_561-15-4_INST_01_10min.csv', 'KIER_WATER_561-16-1_ACCU_01_Raw.csv', 'KIER_WATER_561-16-1_INST_01_10min.csv', 'KIER_WATER_561-16-2_ACCU_01_Raw.csv', 'KIER_WATER_561-16-2_INST_01_10min.csv', 'KIER_WATER_561-16-3_ACCU_01_Raw.csv', 'KIER_WATER_561-16-3_INST_01_10min.csv', 'KIER_WATER_561-16-4_ACCU_01_Raw.csv', 'KIER_WATER_561-16-4_INST_01_10min.csv', 'KIER_WATER_561-17-1_ACCU_01_Raw.csv', 'KIER_WATER_561-17-1_INST_01_10min.csv', 'KIER_WATER_561-17-2_ACCU_01_Raw.csv', 'KIER_WATER_561-17-2_INST_01_10min.csv', 'KIER_WATER_561-17-3_ACCU_01_Raw.csv', 'KIER_WATER_561-17-3_INST_01_10min.csv', 'KIER_WATER_561-17-4_ACCU_01_Raw.csv', 'KIER_WATER_561-17-4_INST_01_10min.csv', 'KIER_WATER_561-18-1_ACCU_01_Raw.csv', 'KIER_WATER_561-18-1_INST_01_10min.csv', 'KIER_WATER_561-18-2_ACCU_01_Raw.csv', 'KIER_WATER_561-18-2_INST_01_10min.csv', 'KIER_WATER_561-18-3_ACCU_01_Raw.csv', 'KIER_WATER_561-18-3_INST_01_10min.csv', 'KIER_WATER_561-18-4_ACCU_01_Raw.csv', 'KIER_WATER_561-18-4_INST_01_10min.csv', 'KIER_WATER_561-2-1_ACCU_01_Raw.csv', 'KIER_WATER_561-2-1_INST_01_10min.csv', 'KIER_WATER_561-2-2_ACCU_01_Raw.csv', 'KIER_WATER_561-2-2_INST_01_10min.csv', 'KIER_WATER_561-2-3_ACCU_01_Raw.csv', 'KIER_WATER_561-2-3_INST_01_10min.csv', 'KIER_WATER_561-2-4_ACCU_01_Raw.csv', 'KIER_WATER_561-2-4_INST_01_10min.csv', 'KIER_WATER_561-3-1_ACCU_01_Raw.csv', 'KIER_WATER_561-3-1_INST_01_10min.csv', 'KIER_WATER_561-3-2_ACCU_01_Raw.csv', 'KIER_WATER_561-3-2_INST_01_10min.csv', 'KIER_WATER_561-3-3_ACCU_01_Raw.csv', 'KIER_WATER_561-3-3_INST_01_10min.csv', 'KIER_WATER_561-3-4_ACCU_01_Raw.csv', 'KIER_WATER_561-3-4_INST_01_10min.csv', 'KIER_WATER_561-4-1_ACCU_01_Raw.csv', 'KIER_WATER_561-4-1_INST_01_10min.csv', 'KIER_WATER_561-4-2_ACCU_01_Raw.csv', 'KIER_WATER_561-4-2_INST_01_10min.csv', 'KIER_WATER_561-4-3_ACCU_01 ...

# %%
## "KIER_01-01_Data_hList.ipynb"로부터 만들어진 Bld/F/H List
df_kier_hList = pd.read_csv(str_dir_raw + str_fileRaw_hList, index_col = 0)
list_h_id = df_kier_hList['HOUSE_ID'].drop_duplicates()
print(df_kier_hList.shape, " /// ", df_kier_hList.columns)
df_kier_hList
# Out:
# (348, 5)  ///  Index(['HOUSE_ID_DONG', 'HOUSE_ID_HO_PRE', 'HOUSE_ID_HO_INT', 'HOUSE_ID',
#        'HOUSE_ID_HO'],
#       dtype='object')
#      HOUSE_ID_DONG  HOUSE_ID_HO_PRE  HOUSE_ID_HO_INT  HOUSE_ID  \
# 1              561                1                1   561-1-1
# 2              561                1                2   561-1-2
# 3              561                1                3   561-1-3
# 4              561                1                4   561-1-4
# 5              561                2                1   561-2-1
# ..             ...              ...              ...       ...
# 344            563               23                2  563-23-2
# 345            563               23                3  563-23-3
# 346            563               23                4  563-23-4
# 347            563               24                1  563-24-1
# 348            563               24                2  563-24-2
#
#                                       HOUSE_ID_HO
# 1    NkI4M0EzNDYxQTE1MDJERjM4NURERTcyRjdGQTJDMDU=
# 2    ODBEOTE0QzZCMjg5RUMzNTRBQjM1NjE0RDNBNDE0NzU=
# 3    QTUwRUJDQTlBMkZENUQyNjg0RDRGREVFMTNGNDI3NUY=
# 4    RkRCQzY4OTlCMTRDQjgzNUZBREE3Njc2MkM2MUM2QjI=
# 5    MTQxNkQ1RDAzOTE5NTM5RUM3MzlDQkY3RTI2NERCQTM=
# ..                                            ...
# 344  QkJCQjQwOThFNjgwNjUwQzJGRUJFNDlCNTREOEUxNDU=
# 345  QUJENzFFMEFDRjM4MjY3NTRDQzJCRjdDNUQ3ODA0N0Y=
# 346  RUVENzZDNTc4MUY4NDg5MUREQjZEOUM1M0Q2RjYzMDE=
# 347  NEVENDc1OTFFNDBBRjBDQzkzMTlEMDgzMkMzMkZFQTg=
# 348  ODgwNDU1RUU0RUQ2OTQxQTBGMEI3MTE3NTkxODYxQ0U=
#
# [348 rows x 5 columns]

# %% [markdown]
# ## 01-02. Data Load (df_raw)

# %% [markdown]
# ### 01-02-01. KIER (Energy Usage)

# %% [markdown]
# ### 순시사용량

# %%
str_file = str('KIER_' + str_domain + '_INST_01_10min.csv')
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)
df_tmp['METER_DATE'] = pd.to_datetime(df_tmp['METER_DATE'])

list_tar_col = df_tmp.columns[0:]
df_tmp = df_tmp.reset_index()[list_tar_col] ## reset_index로 인해 발생한 index행 제거

# %%
## 정상적인 Time Period 외의 데이터는 삭제 (2022-07-17 ~ 2024-06-05)
df_period_tmp = pd.read_csv(str_dir_raw + "KIER_TIME_PERIOD.csv", index_col = 0)
df_period_tmp['METER_DATE'] = pd.to_datetime(df_period_tmp['METER_DATE'])

df_tmp = pd.merge(df_period_tmp['METER_DATE'], df_tmp, on = ['METER_DATE'], how = "left")
df_tmp
# Out:
#                METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0     2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1     2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2     2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3     2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4     2022-07-17 23:40:00          Sunday  2022      7   17    23      40
# ...                   ...             ...   ...    ...  ...   ...     ...
# 99166 2024-06-05 14:40:00       Wednesday  2024      6    5    14      40
# 99167 2024-06-05 14:50:00       Wednesday  2024      6    5    14      50
# 99168 2024-06-05 15:00:00       Wednesday  2024      6    5    15       0
# 99169 2024-06-05 15:10:00       Wednesday  2024      6    5    15      10
# 99170 2024-06-05 15:20:00       Wednesday  2024      6    5    15      20
#
#        code_day_of_the_week  WATER_INST_FLOW_561-1-1  WATER_INST_FLOW_561-1-2  \
# 0                         6                      NaN                      NaN
# 1                         6                      NaN                      NaN
# 2                         6             0.0000000000             0.0000000000
# 3                         6             0.0000000000             0.0000000000
# 4                         6             0.0350000000             0.0000000000
# ...                     ...                      ...                      ...
# 99166                     2             0.0002000000             0.0000000000
# 99167                     2             0.0001000000             0.0000000000
# 99168                     2             0.0000000000             0.0000000000
# 99169                     2             0.0000000000             0.0000000000
# 99170                     2             0.0000000000             0.0000000000
#
#        ...  WATER_INST_FLOW_563-22-5  WATER_INST_FLOW_563-22-6  \
# 0      ...                       NaN                       NaN
# 1      ...                       NaN                       NaN
# 2      ...              0.0000000000              0.0000000000
# 3      ...              0.0001000000              0.0001000000
# 4      ...              0.0000000000              0.0000000000
# ...    ...                       ...                       ...
# 99166  ...              0.0000000000              0.0000000000
# 99167  ...              0.0001000000              0.0000000000
# 99168  ...              0.0003000000              0.0000000000
# 99169  ...              0.0103000000                       NaN
# 99170  ...              0.0000000000              0.0000000000
#
#        WATER_INST_FLOW_563-23-1  WATER_INST_FLOW_563-23-2  \
# 0                           NaN                       NaN
# 1                           NaN              0.0090000000
# 2                  0.0001000000              0.0176000000
# 3                  0.0002000000              0.0000000000
# 4                  0.0000000000              0.0000000000
# ...                         ...                       ...
# 99166                       NaN                       NaN
# 99167                       NaN                       NaN
# 99168                       NaN                       NaN
# 99169                       NaN                       NaN
# 99170              0.0000000000              0.0000000000
#
#        WATER_INST_FLOW_563-23-3  WATER_INST_FLOW_563-23-4  \
# 0                           NaN                       NaN
# 1                           NaN              0.0002000000
# 2                  0.0000000000              0.0000000000
# 3                  0.0201000000              0.0001000000
# 4                  0.0001000000                       NaN
# ...                         ...                       ...
# 99166                       NaN              0.0438000000
# 99167                       NaN              0.0189000000
# 99168                       NaN              0.0000000000
# 99169                       NaN                       NaN
# 99170              0.0000000000              0.0000000000
#
#        WATER_INST_FLOW_563-24-1  WATER_INST_FLOW_563-24-2   MEAN_OF_INST  \
# 0                           NaN                       NaN 109.2123052632
# 1                  0.0003000000              0.0000000000  13.1178069182
# 2                  0.0001000000              0.0000000000   6.6341838608
# 3                  0.0001000000              0.0001000000   6.8379792208
# 4                  0.0001000000              0.0000000000   6.5718704969
# ...                         ...                       ...            ...
# 99166                       NaN                       NaN   7.7464703704
# 99167                       NaN                       NaN   7.9308830189
# 99168                       NaN                       NaN   7.5189128205
# 99169                       NaN                       NaN   8.7774514894
# 99170              0.0000000000              0.0000000000   5.8531073446
#
#           SUM_OF_INST
# 0     2075.0338000000
# 1     2085.7313000000
# 2     2096.4021000000
# 3     2106.0976000000
# 4     2116.1423000000
# ...               ...
# 99166 2091.5470000000
# 99167 2101.6840000000
# 99168 2052.6632000000
# 99169 2062.7011000000
# 99170 2072.0000000000
#
# [99171 rows x 358 columns]

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Mean of Instantaneous Usage in ' + str_domain, fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'WATER_INST_FLOW_561-1-1',
#        'WATER_INST_FLOW_561-1-2',
#        ...
#        'WATER_INST_FLOW_563-22-5', 'WATER_INST_FLOW_563-22-6',
#        'WATER_INST_FLOW_563-23-1', 'WATER_INST_FLOW_563-23-2',
#        'WATER_INST_FLOW_563-23-3', 'WATER_INST_FLOW_563-23-4',
#        'WATER_INST_FLOW_563-24-1', 'WATER_INST_FLOW_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                     0
# day_of_the_week                0
# YEAR                           0
# MONTH                          0
# DAY                            0
#                             ...
# WATER_INST_FLOW_563-23-4    5200
# WATER_INST_FLOW_563-24-1    5588
# WATER_INST_FLOW_563-24-2    5325
# MEAN_OF_INST                   0
# SUM_OF_INST                    0
# Length: 358, dtype: int64

# %%
## 순시사용량이 음수인 경우 삭제
cnt_minus = 0
list_col_usage = list(df_tmp.columns[8:-2])

for i in range(0, len(df_tmp)) : 
    for col_tar in list_col_usage:
        if df_tmp[col_tar][i] < 0 : 
            print(col_tar, ' ///', df_tmp[col_tar][i])
            print(df_tmp[col_tar][i])
            cnt_minus = cnt_minus + 1
            df_tmp[col_tar][i] = np.nan

print(cnt_minus)

## 순시 사용량의 합계 및 평균 Column을 갱신
df_tmp['MEAN_OF_INST'] = df_tmp[list_col_usage].mean(axis = 1)
df_tmp['SUM_OF_INST'] = df_tmp[list_col_usage].sum(axis = 1)
# Out:
# 0

# %%
print(df_tmp.shape, " /// ", df_tmp.columns)
print(df_tmp.isna().sum())
# print(df_tmp.head(5))

plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage in certain household', fontsize=30)
plt.show()
# Out:
# (99171, 358)  ///  Index(['METER_DATE', 'day_of_the_week', 'YEAR', 'MONTH', 'DAY', 'HOUR',
#        'MINUTE', 'code_day_of_the_week', 'WATER_INST_FLOW_561-1-1',
#        'WATER_INST_FLOW_561-1-2',
#        ...
#        'WATER_INST_FLOW_563-22-5', 'WATER_INST_FLOW_563-22-6',
#        'WATER_INST_FLOW_563-23-1', 'WATER_INST_FLOW_563-23-2',
#        'WATER_INST_FLOW_563-23-3', 'WATER_INST_FLOW_563-23-4',
#        'WATER_INST_FLOW_563-24-1', 'WATER_INST_FLOW_563-24-2', 'MEAN_OF_INST',
#        'SUM_OF_INST'],
#       dtype='object', length=358)
# METER_DATE                     0
# day_of_the_week                0
# YEAR                           0
# MONTH                          0
# DAY                            0
#                             ...
# WATER_INST_FLOW_563-23-4    5200
# WATER_INST_FLOW_563-24-1    5588
# WATER_INST_FLOW_563-24-2    5325
# MEAN_OF_INST                3823
# SUM_OF_INST                    0
# Length: 358, dtype: int64

# %%
# df_tmp[['METER_DATE', 'MEAN_OF_INST', 'SUM_OF_INST']].to_csv(str_dir_raw + "KIER_TIME_PERIOD.csv")

# %% [markdown]
# #### 1차 보간 : 평균 대치법 (동일 시간대 전체 세대의 평균 순시 사용량)

# %%
for i in range(0, len(df_tmp)) : df_tmp.loc[i] = df_tmp.loc[i].fillna(df_tmp['MEAN_OF_INST'].loc[i])

## 순시 사용량의 합계 및 평균 Column을 갱신
df_tmp['MEAN_OF_INST'] = df_tmp[list_col_usage].mean(axis = 1)
df_tmp['SUM_OF_INST'] = df_tmp[list_col_usage].sum(axis = 1)

## 마지막값이 0이므로 제외
df_tmp = df_tmp[:-1]

str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp.to_csv(str_dirName_h + str_file)

print(df_tmp.isna().sum())
print(df_tmp.head(5))
plt.figure(figsize=(20,4))
plt.plot(df_tmp['METER_DATE'], df_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + 'Usage : 1st - Mean of Inst', fontsize=30)
plt.show()
# Out:
# METER_DATE                     0
# day_of_the_week                0
# YEAR                           0
# MONTH                          0
# DAY                            0
#                             ...
# WATER_INST_FLOW_563-23-4    3823
# WATER_INST_FLOW_563-24-1    3823
# WATER_INST_FLOW_563-24-2    3823
# MEAN_OF_INST                3823
# SUM_OF_INST                    0
# Length: 358, dtype: int64
#            METER_DATE day_of_the_week  YEAR  MONTH  DAY  HOUR  MINUTE  \
# 0 2022-07-17 23:00:00          Sunday  2022      7   17    23       0
# 1 2022-07-17 23:10:00          Sunday  2022      7   17    23      10
# 2 2022-07-17 23:20:00          Sunday  2022      7   17    23      20
# 3 2022-07-17 23:30:00          Sunday  2022      7   17    23      30
# 4 2022-07-17 23:40:00          Sunday  2022      7   17    23      40
#
#    code_day_of_the_week  WATER_INST_FLOW_561-1-1  WATER_INST_FLOW_561-1-2  \
# 0                     6             0.0026000000             0.0026000000
# 1                     6             0.0047797386             0.0047797386
# 2                     6             0.0000000000             0.0000000000
# 3                     6             0.0000000000             0.0000000000
# 4                     6             0.0350000000             0.0000000000
#
#    ...  WATER_INST_FLOW_563-22-5  WATER_INST_FLOW_563-22-6  \
# 0  ...              0.0026000000              0.0026000000
# 1  ...              0.0047797386              0.0047797386
# 2  ...              0.0000000000              0.0000000000
# 3  ...              0.0001000000              0.0001000000
# 4  ...              0.0000000000              0.0000000000
#
#    WATER_INST_FLOW_563-23-1  WATER_INST_FLOW_563-23-2  \
# 0              0.0026000000              0.0026000000
# 1              0.0047797386              0.0090000000
# 2              0.0001000000              0.0176000000
# 3              0.0002000000              0.0000000000
# 4              0.0000000000              0.0000000000
#
#    WATER_INST_FLOW_563-23-3  WATER_INST_FLOW_563-23-4  \
# 0              0.0026000000              0.0026000000
# 1              0.0047797386              0.0002000000
# 2              0.0000000000              0.0000000000
# 3              0.0201000000              0.0001000000
# 4              0.0001000000              0.0036148734
#
#    WATER_INST_FLOW_563-24-1  WATER_INST_FLOW_563-24-2  MEAN_OF_INST  \
# 0              0.0026000000              0.0026000000  0.0026000000
# 1              0.0003000000              0.0000000000  0.0047797386
# 2              0.0001000000              0.0000000000  0.0045229032
# 3              0.0001000000              0.0001000000  0.0036344371
# 4              0.0001000000              0.0000000000  0.0036148734
#
#    SUM_OF_INST
# 0 0.9048000000
# 1 1.6633490196
# 2 1.5739703226
# 3 1.2647841060
# 4 1.2579759494
#
# [5 rows x 358 columns]

# %%
str_file = 'KIER_' + str_domain + '_INST_02_MeanInterpolated.csv'
df_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 2차 보간 : 선형 보간

# %% [markdown]
# 모든 값이 NaN이어서 평균 순시 사용량이 계산되지 않은 경우 존재 (ELEC 기준 약 1,372건)
# 해당 부분은 단순 선형 보간을 진행

# %%
## 사용량 컬럼에 대한 2차 보간 진행 (선형 보간)
df_linear_tmp, df_spline_tmp, df_polynomial_tmp, df_cubic_tmp = df_tmp.copy(), df_tmp.copy(), df_tmp.copy(), df_tmp.copy()
df_linear_tmp['MEAN_OF_INST'] = df_linear_tmp['MEAN_OF_INST'].interpolate('linear')
df_spline_tmp['MEAN_OF_INST'] = df_spline_tmp['MEAN_OF_INST'].interpolate('spline', order = 3) ## 3차 다항식 스플라인
# df_polynomial_tmp['MEAN_OF_INST'] = df_polynomial_tmp['MEAN_OF_INST'].interpolate('polynomian')
# df_cubic_tmp['MEAN_OF_INST'] = df_cubic_tmp['MEAN_OF_INST'].interpolate('cubicspline')

str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp.to_csv(str_dirName_h + str_file)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp.to_csv(str_dirName_h + str_file)

# %%
plt.figure(figsize=(20,4))
plt.plot(df_linear_tmp['METER_DATE'], df_linear_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-01 Linear', fontsize=30)
plt.show()

# %%
plt.figure(figsize=(20,4))
plt.plot(df_spline_tmp['METER_DATE'], df_spline_tmp['MEAN_OF_INST'])
plt.title('Instantaneous ' + str_domain + ' Usage : 2nd-02 Spline', fontsize=30)
plt.show()

# %%
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_linear_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_spline_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0)

# %% [markdown]
# #### 이상치 제거 : IQR 방식으로 이상치 완화

# %%
## 여기서 IQR방식으로 전처리
list_col_usage = list(df_tmp.columns[8:-2])
for tar_col in list_col_usage:
    print(tar_col)
    df_h_tmp = df_tmp[['METER_DATE', tar_col]].copy()
    df_h_tmp = com_Prep.del_outlier_Usages(df_h_tmp, tar_col, 10)
    df_tmp[tar_col] = df_h_tmp[tar_col]
# Out:
# WATER_INST_FLOW_561-1-1
# ===============  IQR Range ===============
# 0.03624999999999525
# 0.0144999999999981
# 0.0144999999999981
# nan
# 0.0
# -0.02174999999999715
# ===============  IQR Range ===============
# cnt_outlier = 877
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 146
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 105
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 90
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 87
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 87
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 87
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 87
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 87
# ===============  IQR Range ===============
# 0.035999999999987
# 0.0143999999999948
# 0.0143999999999948
# nan
# 0.0
# -0.021599999999992202
# ===============  IQR Range ===============
# cnt_outlier = 87
# 1013
# WATER_INST_FLOW_561-1-2
# ===============  IQR Range ===============
# 0.0250000000000305
# 0.0100000000000122
# 0.0100000000000122
# nan
# 0.0
# -0.0150000000000183
# ===============  IQR Range ===============
# cnt_outlier = 423
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 27
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 15
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 12
# ===============  IQR Range ===============
# 0.02499999999997725
# 0.0099999999999909
# 0.0099999999999909
# nan
# 0.0
# -0.01499999999998635
# ===============  IQR Range ===============
# cnt_outlier = 12
# 441
# WATER_INST_FLOW_561-1-3
# ===============  IQR Range ===============
# 0.028250000000014003
# 0.0113000000000056
# 0.0113000000000056
# nan
# 0.0
# -0.016950000000008403
# ===============  IQR Range ===============
# cnt_outlier = 2343
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 466
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 257
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 230
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 227
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 227
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 227
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 227
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 227
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 227
# 2635
# WATER_INST_FLOW_561-1-4
# ===============  IQR Range ===============
# 0.024250000000023253
# 0.0097000000000093
# 0.0097000000000093
# nan
# 0.0
# -0.014550000000013951
# ===============  IQR Range ===============
# cnt_outlier = 2661
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 668
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 341
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 292
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 280
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 275
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 275
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 275
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 275
# ===============  IQR Range ===============
# 0.02324999999999
# 0.009299999999996
# 0.009299999999996
# nan
# 0.0
# -0.013949999999994002
# ===============  IQR Range ===============
# cnt_outlier = 275
# 3295
# WATER_INST_FLOW_561-2-1
# ===============  IQR Range ===============
# 0.029499999999984497
# 0.0117999999999938
# 0.0117999999999938
# nan
# 0.0
# -0.0176999999999907
# ===============  IQR Range ===============
# cnt_outlier = 3034
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 811
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 534
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 501
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 499
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 497
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 497
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 497
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 497
# ===============  IQR Range ===============
# 0.02800000000000575
# 0.0112000000000023
# 0.0112000000000023
# nan
# 0.0
# -0.01680000000000345
# ===============  IQR Range ===============
# cnt_outlier = 497
# 3479
# WATER_INST_FLOW_561-2-2
# ===============  IQR Range ===============
# 0.019500000000007747
# 0.0078000000000031
# 0.0078000000000031
# nan
# 0.0
# -0.01170000000000465
# ===============  IQR Range ===============
# cnt_outlier = 4088
# ===============  IQR Range ===============
# 0.017624999999982013
# 0.007049999999992805
# 0.007049999999992805
# nan
# 0.0
# -0.010574999999989208
# ===============  IQR Range ===============
# cnt_outlier = 2528
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2221
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2139
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2110
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2102
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2102
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2102
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2102
# ===============  IQR Range ===============
# 0.0175000000000125
# 0.007000000000005
# 0.007000000000005
# nan
# 0.0
# -0.0105000000000075
# ===============  IQR Range ===============
# cnt_outlier = 2102
# 12366
# WATER_INST_FLOW_561-2-3
# ===============  IQR Range ===============
# 0.02900000000003875
# 0.0116000000000155
# 0.0116000000000155
# nan
# 0.0
# -0.01740000000002325
# ===============  IQR Range ===============
# cnt_outlier = 1425
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 77
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 43
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 42
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 42
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 39
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 39
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 39
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 39
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 39
# 1473
# WATER_INST_FLOW_561-2-4
# ===============  IQR Range ===============
# 0.02074999999997825
# 0.0082999999999913
# 0.0082999999999913
# nan
# 0.0
# -0.01244999999998695
# ===============  IQR Range ===============
# cnt_outlier = 1589
# ===============  IQR Range ===============
# 0.01625000000000465
# 0.00650000000000186
# 0.00650000000000186
# nan
# 0.0
# -0.009750000000002791
# ===============  IQR Range ===============
# cnt_outlier = 1049
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 945
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 942
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 942
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 942
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 942
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 942
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 942
# ===============  IQR Range ===============
# 0.016249999999971
# 0.0064999999999884
# 0.0064999999999884
# nan
# 0.0
# -0.009749999999982599
# ===============  IQR Range ===============
# cnt_outlier = 942
# 1859
# WATER_INST_FLOW_561-3-1
# ===============  IQR Range ===============
# 0.03650000000000375
# 0.0146000000000015
# 0.0146000000000015
# nan
# 0.0
# -0.02190000000000225
# ===============  IQR Range ===============
# cnt_outlier = 1554
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 443
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 359
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 354
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 354
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 354
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 354
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 354
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 354
# ===============  IQR Range ===============
# 0.034749999999981
# 0.0138999999999924
# 0.0138999999999924
# nan
# 0.0
# -0.0208499999999886
# ===============  IQR Range ===============
# cnt_outlier = 354
# 1706
# WATER_INST_FLOW_561-3-2
# ===============  IQR Range ===============
# 0.013220534282276248
# 0.0052882137129105
# 0.0052882137129105
# nan
# 0.0
# -0.007932320569365749
# ===============  IQR Range ===============
# cnt_outlier = 3530
# ===============  IQR Range ===============
# 0.00974999999996825
# 0.0038999999999873
# 0.0038999999999873
# nan
# 0.0
# -0.00584999999998095
# ===============  IQR Range ===============
# cnt_outlier = 2922
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2742
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2723
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2721
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2721
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2721
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2721
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2721
# ===============  IQR Range ===============
# 0.009748245614008826
# 0.00389929824560353
# 0.00389929824560353
# nan
# 0.0
# -0.005848947368405295
# ===============  IQR Range ===============
# cnt_outlier = 2721
# 5556
# WATER_INST_FLOW_561-3-3
# ===============  IQR Range ===============
# 0.027249999999980748
# 0.0108999999999923
# 0.0108999999999923
# nan
# 0.0
# -0.01634999999998845
# ===============  IQR Range ===============
# cnt_outlier = 2417
# ===============  IQR Range ===============
# 0.0269999999999015
# 0.0107999999999606
# 0.0107999999999606
# nan
# 0.0
# -0.0161999999999409
# ===============  IQR Range ===============
# cnt_outlier = 683
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 313
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 205
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 175
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 163
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 159
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 155
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 155
# ===============  IQR Range ===============
# 0.02675000000010625
# 0.0107000000000425
# 0.0107000000000425
# nan
# 0.0
# -0.01605000000006375
# ===============  IQR Range ===============
# cnt_outlier = 155
# 3682
# WATER_INST_FLOW_561-3-4
# ===============  IQR Range ===============
# 0.020000000000024252
# 0.0080000000000097
# 0.0080000000000097
# nan
# 0.0
# -0.012000000000014551
# ===============  IQR Range ===============
# cnt_outlier = 3679
# ===============  IQR Range ===============
# 0.0185000000000455
# 0.0074000000000182
# 0.0074000000000182
# nan
# 0.0
# -0.0111000000000273
# ===============  IQR Range ===============
# cnt_outlier = 1112
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 719
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 668
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 658
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 657
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 656
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 656
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 656
# ===============  IQR Range ===============
# 0.018500000000009998
# 0.007400000000004
# 0.007400000000004
# nan
# 0.0
# -0.011100000000006
# ===============  IQR Range ===============
# cnt_outlier = 656
# 4827
# WATER_INST_FLOW_561-4-1
# ===============  IQR Range ===============
# 0.02600000000001025
# 0.0104000000000041
# 0.0104000000000041
# nan
# 0.0
# -0.01560000000000615
# ===============  IQR Range ===============
# cnt_outlier = 755
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 84
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 45
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 36
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 33
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 33
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 33
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 33
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 33
# ===============  IQR Range ===============
# 0.025750000000002
# 0.0103000000000008
# 0.0103000000000008
# nan
# 0.0
# -0.015450000000001199
# ===============  IQR Range ===============
# cnt_outlier = 33
# 840
# WATER_INST_FLOW_561-4-2
# ===============  IQR Range ===============
# 0.026999999999936998
# 0.0107999999999748
# 0.0107999999999748
# nan
# 0.0
# -0.0161999999999622
# ===============  IQR Range ===============
# cnt_outlier = 2655
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 958
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 646
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 607
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 597
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 594
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 592
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 591
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 591
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 591
# 3557
# WATER_INST_FLOW_561-4-3
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 2092
# ===============  IQR Range ===============
# 0.022000000000002
# 0.0088000000000008
# 0.0088000000000008
# nan
# 0.0
# -0.0132000000000012
# ===============  IQR Range ===============
# cnt_outlier = 1079
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 892
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 847
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 841
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 841
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 841
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 841
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 841
# ===============  IQR Range ===============
# 0.02194062499999436
# 0.008776249999997744
# 0.008776249999997744
# nan
# 0.0
# -0.013164374999996616
# ===============  IQR Range ===============
# cnt_outlier = 841
# 3632
# WATER_INST_FLOW_561-4-4
# ===============  IQR Range ===============
# 0.024750000000004255
# 0.0099000000000017
# 0.0099000000000017
# nan
# 0.0
# -0.014850000000002552
# ===============  IQR Range ===============
# cnt_outlier = 3221
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 1503
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 1100
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 869
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 639
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 546
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 509
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 492
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 477
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 473
# 7819
# WATER_INST_FLOW_561-5-1
# ===============  IQR Range ===============
# 0.03699999999994925
# 0.0147999999999797
# 0.0147999999999797
# nan
# 0.0
# -0.02219999999996955
# ===============  IQR Range ===============
# cnt_outlier = 1594
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 417
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 308
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 305
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 305
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 305
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 305
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 305
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 305
# ===============  IQR Range ===============
# 0.03574999999997875
# 0.0142999999999915
# 0.0142999999999915
# nan
# 0.0
# -0.02144999999998725
# ===============  IQR Range ===============
# cnt_outlier = 305
# 1711
# WATER_INST_FLOW_561-5-2
# ===============  IQR Range ===============
# 0.03325000000000225
# 0.0133000000000009
# 0.0133000000000009
# nan
# 0.0
# -0.01995000000000135
# ===============  IQR Range ===============
# cnt_outlier = 4060
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 2021
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1469
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1328
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1298
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1296
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1295
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1295
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1295
# ===============  IQR Range ===============
# 0.030750000000026
# 0.0123000000000104
# 0.0123000000000104
# nan
# 0.0
# -0.0184500000000156
# ===============  IQR Range ===============
# cnt_outlier = 1295
# 7414
# WATER_INST_FLOW_561-5-3
# ===============  IQR Range ===============
# 0.066750000000013
# 0.0267000000000052
# 0.0267000000000052
# nan
# 0.0
# -0.0400500000000078
# ===============  IQR Range ===============
# cnt_outlier = 2827
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1735
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# ===============  IQR Range ===============
# 0.05375000000000775
# 0.0215000000000031
# 0.0215000000000031
# nan
# 0.0
# -0.03225000000000465
# ===============  IQR Range ===============
# cnt_outlier = 1724
# 2863
# WATER_INST_FLOW_561-5-4
# ===============  IQR Range ===============
# 0.053000000000054004
# 0.0212000000000216
# 0.0212000000000216
# nan
# 0.0
# -0.0318000000000324
# ===============  IQR Range ===============
# cnt_outlier = 491
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 60
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 30
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 26
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 26
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 26
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 25
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 25
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 25
# ===============  IQR Range ===============
# 0.052500000000037496
# 0.021000000000015
# 0.021000000000015
# nan
# 0.0
# -0.031500000000022496
# ===============  IQR Range ===============
# cnt_outlier = 25
# 545
# WATER_INST_FLOW_561-6-1
# ===============  IQR Range ===============
# 0.028749999999995002
# 0.011499999999998
# 0.011499999999998
# nan
# 0.0
# -0.017249999999997
# ===============  IQR Range ===============
# cnt_outlier = 1807
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 175
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 60
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 51
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 51
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 49
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 47
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 47
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 47
# ===============  IQR Range ===============
# 0.028499999999951252
# 0.0113999999999805
# 0.0113999999999805
# nan
# 0.0
# -0.01709999999997075
# ===============  IQR Range ===============
# cnt_outlier = 47
# 1994
# WATER_INST_FLOW_561-6-2
# ===============  IQR Range ===============
# 0.02600000000001025
# 0.0104000000000041
# 0.0104000000000041
# nan
# 0.0
# -0.01560000000000615
# ===============  IQR Range ===============
# cnt_outlier = 2607
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 679
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 413
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 364
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 356
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 353
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 353
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 353
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 353
# ===============  IQR Range ===============
# 0.024999999999995
# 0.009999999999998
# 0.009999999999998
# nan
# 0.0
# -0.014999999999997
# ===============  IQR Range ===============
# cnt_outlier = 353
# 3173
# WATER_INST_FLOW_561-6-3
# ===============  IQR Range ===============
# 0.0252499999999855
# 0.0100999999999942
# 0.0100999999999942
# nan
# 0.0
# -0.0151499999999913
# ===============  IQR Range ===============
# cnt_outlier = 1234
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 414
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 246
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 197
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 187
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 182
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 180
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 178
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 178
# ===============  IQR Range ===============
# 0.024499999999996
# 0.0097999999999984
# 0.0097999999999984
# nan
# 0.0
# -0.0146999999999976
# ===============  IQR Range ===============
# cnt_outlier = 178
# 1905
# WATER_INST_FLOW_561-6-4
# ===============  IQR Range ===============
# 0.03787500000001363
# 0.01515000000000545
# 0.01515000000000545
# nan
# 0.0
# -0.022725000000008176
# ===============  IQR Range ===============
# cnt_outlier = 759
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 150
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 103
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 99
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 99
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 99
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 99
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 99
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 99
# ===============  IQR Range ===============
# 0.03699999999999362
# 0.01479999999999745
# 0.01479999999999745
# nan
# 0.0
# -0.022199999999996174
# ===============  IQR Range ===============
# cnt_outlier = 99
# 820
# WATER_INST_FLOW_561-7-1
# ===============  IQR Range ===============
# 0.03924999999998825
# 0.0156999999999953
# 0.0156999999999953
# nan
# 0.0
# -0.02354999999999295
# ===============  IQR Range ===============
# cnt_outlier = 1017
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 138
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 94
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 85
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 85
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 85
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 85
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 85
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 85
# ===============  IQR Range ===============
# 0.038499999999999
# 0.0153999999999996
# 0.0153999999999996
# nan
# 0.0
# -0.0230999999999994
# ===============  IQR Range ===============
# cnt_outlier = 85
# 1084
# WATER_INST_FLOW_561-7-2
# ===============  IQR Range ===============
# 0.01900000000002675
# 0.0076000000000107
# 0.0076000000000107
# nan
# 0.0
# -0.01140000000001605
# ===============  IQR Range ===============
# cnt_outlier = 2910
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 1081
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 689
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 528
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 432
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 408
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 381
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 358
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 347
# ===============  IQR Range ===============
# 0.018750000000053998
# 0.0075000000000216
# 0.0075000000000216
# nan
# 0.0
# -0.011250000000032399
# ===============  IQR Range ===============
# cnt_outlier = 342
# 6255
# WATER_INST_FLOW_561-7-3
# ===============  IQR Range ===============
# 0.03225000000000475
# 0.0129000000000019
# 0.0129000000000019
# nan
# 0.0
# -0.01935000000000285
# ===============  IQR Range ===============
# cnt_outlier = 3119
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 6
#       4 print(tar_col)
#       5 df_h_tmp = df_tmp[['METER_DATE', tar_col]].copy()
# ----> 6 df_h_tmp = com_Prep.del_outlier_Usages(df_h_tmp, tar_col, 10)
#       7 df_tmp[tar_col] = df_h_tmp[tar_col]
#
# File d:\WS_DataScience\Src_Dev_Common\DEV_Common_Data_Preprocessing.py:91, in del_outlier_Usages(df_tar, col_tar, int_cnt_process)
#      87 outlier_usage = df_tar[col_tar].iloc[row]
#      88 if ((outlier_usage > (q3_df_raw + 1.5 * iqr_df_raw)) or (outlier_usage < q1_df_raw - 1.5 * iqr_df_raw)):
#      89     # print(outlier_usage)
#      90     ## Linear Regression
# ---> 91     df_tar[col_tar].iloc[row] = (df_tar[col_tar].iloc[row - 1] + df_tar[col_tar].iloc[row + 1]) / 2
#      92     cnt_outlier = cnt_outlier + 1
#      93 if outlier_usage < 0:
#      94     # print(outlier_usage)
#      95     ## 사용량이 음수일 수 없으므로 0으로 치환
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\Admin\anaconda3\envs\dev-ts\lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp.to_csv(str_dirName_h + str_file)

# %%
str_file = 'KIER_' + str_domain + '_INST_01_10min.csv'
df_tmp_00 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_01_MeanIntp.csv'
df_tmp_01 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-01_SingleLinear.csv'
df_tmp_0201 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_02-02_Spline.csv'
df_tmp_0202 = pd.read_csv(str_dirName_h + str_file, index_col = 0)
str_file = 'KIER_' + str_domain + '_INST_03_IQR.csv'
df_tmp_03 = pd.read_csv(str_dirName_h + str_file, index_col = 0)

period_tmp = df_tmp_0201['METER_DATE']
period_tmp

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    # plt.xlim(0, 5000)
    # plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_01[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0201[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
list_tar_col = df_tmp.columns[1:5]
for tar_col in list_tar_col:
    plt.figure(figsize=(20,4))
    # plt.plot(df_tmp_01[tar_col], color='red', label='Raw')
    plt.plot(df_tmp_0202[tar_col], color='blue', label='Mean Interpolated')
    plt.plot(df_tmp_03[tar_col], color='green', label='IQR')
    # plt.xlim(0, 5000)
    plt.legend()
    plt.show()

# %%
df_tmp_01.columns

# %%
tar_col = 'SUM_OF_INST'

fig, ax1 = plt.subplots(figsize = (30,5))
usage_A = df_tmp_01[tar_col].copy()
usage_B = df_tmp_0201[tar_col].copy()
ax1.plot(period_tmp, usage_A, color = 'red')
ax1.plot(period_tmp, usage_B, color = 'red')

# %%
list_tar_col = df_tmp.columns[1:]
for tar_col in list_tar_col:
    print(tar_col)
    df_tmp[tar_col] = com_Prep.del_outlier_Usages(df_tmp, tar_col)

# %%
df_tmp

# %%
## 합계 순시량 다시 계산 
list_col = df_tmp.columns[7:-2]

df_kier_Calc = df_tmp[list_col]
df_kier_extract = df_tmp
df_kier_extract['SUM_OF_INST'] = df_kier_Calc.sum(axis = 1)

str_file = 'KIER_' + str_domain + '_INST_10MIN_MEANINTERPOLATED.csv'       
df_kier_extract.to_csv(str_dirName_h + str_file)

# %%
df_tmp.info()

# %%
# pd.set_option("display.max_columns", 999)
# # pd.set_option("display.max_seq_items", None)
# pd.set_option("display.max_rows", None)

# df_tmp.isnull().sum()

# %%
df_kier_extract
